# %% [markdown]
# # Stock Deep Recurrent Q-Network
# This notebook provides an implementation of a Deep Double Recurrent Q-Network which can solve Partially Observable Markov Decision Processes. This notebook applies the technique on time series.

# %%
import numpy as np
import random
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import csv
import itertools
# %matplotlib inline
import time
from sklearn.preprocessing import MinMaxScaler
from helper import *
from StockEnv import StockEnv
import pandas as pd
from GeometricBrownianMotion import * 
from MCSAmericanOptionPricing import *
import math

seed = 1 #time.time()
random.seed(seed)
print('Seed is:' + str(seed))
# Out:
# /misc/home/reco/fathanab/anaconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /misc/home/reco/fathanab/anaconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /misc/home/reco/fathanab/anaconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /misc/home/reco/fathanab/anaconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /misc/home/reco/fathanab/anaconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /misc/home/reco/fathanab/anaconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /misc/home/reco/fathanab/anaconda3/envs/tfenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /misc/home/reco/fathanab/anaconda3/envs/tfenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /misc/home/reco/fathanab/anaconda3/envs/tfenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /misc/home/reco/fathanab/anaconda3/envs/tfenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /misc/home/reco/fathanab/anaconda3/envs/tfenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /misc/home/reco/fathanab/anaconda3/envs/tfenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Seed is:1

# %% [markdown]
# ### Variable settings

# %%
risk_free_rate = 5/100
mu = risk_free_rate
sigma = 0.20
num_seeds = 200 #60

# %%
save_model_freq = 10000 #5000
Normalization = False
Window_Normalization = False
test_data_ratio = 0.2

architecture = 0
nbFilters = 32 #16 #1
paddingType = 'same' #'causal' # 'valid'
huber_loss = True #False
dueling_type = 'max' #'naive'
mask_type = 'default' #'maskFirstHalf' # 'maskByWeights' 'default'
apply_dropout = True
batch_size = 64 #How many experience traces to use for each training step.
memory_capacity = 3000 
learning_rate = 0.0025
apply_grad_clipping = True
grad_clipping = 5 # Maybe test with bigger values, e.g. 40 or 30
optimizer_type = 'Adam' # 'GradientDescent' 'RMSProp'

Colab = False
scriptDirectory = os.getcwd()

history_t = 15
option_T = 50
input_size = history_t + 2
is_training = True

# %%
#Generate stocks data
stocks_data, _ = GBM(num_seeds, is_training).generate_stock_paths(mu, sigma, 928, num_seeds, is_training)
stocks_train_data = []
stocks_test_data = []
real_stocks_train_data = []
real_stocks_test_data = []
for stock_data in stocks_data:
    train_data, test_data, real_train_data, real_test_data = prepare_company_stock(stock_data, Normalization, Window_Normalization, scriptDirectory, test_data_ratio)
    stocks_train_data.append(train_data)
    stocks_test_data.append(test_data)
    real_stocks_train_data.append(real_train_data)
    real_stocks_test_data.append(real_test_data)
    plt.plot(range(len(train_data)), train_data, color='b')
    plt.plot(range(len(train_data), len(train_data) + len(test_data)), test_data, color='r')
# Out:
# min value of data: 50.55108446618011, max value of data: 75.71320001340916
# train_size: 743
# test_size: 185
# min value of data: 160.41750891209688, max value of data: 232.0053569320216
# train_size: 743
# test_size: 185
# min value of data: 117.39052913848273, max value of data: 239.65281150191407
# train_size: 743
# test_size: 185
# min value of data: 61.68717100789021, max value of data: 93.3981808897496
# train_size: 743
# test_size: 185
# min value of data: 56.87545268912853, max value of data: 90.88754177619106
# train_size: 743
# test_size: 185
# min value of data: 94.06358565243866, max value of data: 245.37303421922587
# train_size: 743
# test_size: 185
# min value of data: 129.93675878153329, max value of data: 232.31137151669466
# train_size: 743
# test_size: 185
# min value of data: 129.9534825322404, max value of data: 258.1770676311054
# train_size: 743
# test_size: 185
# min value of data: 35.20913894154504, max value of data: 65.18331821536977
# train_size: 743
# test_size: 185
# min value of data: 101.39621501443278, max value of data: 159.54608974168164
# train_size: 743
# test_size: 185
# min value of data: 162.61745200633712, max value of data: 289.41747349894536
# train_size: 743
# test_size: 185
# min value of data: 74.1227187551618, max value of data: 146.9048689726847
# train_size: 743
# test_size: 185
# min value of data: 58.28755258481948, max value of data: 117.47007576272676
# train_size: 743
# test_size: 185
# min value of data: 120.73998326364462, max value of data: 248.91561167359893
# train_size: 743
# test_size: 185
# min value of data: 51.870723592789105, max value of data: 101.84733307434726
# train_size: 743
# test_size: 185
# min value of data: 61.763316116879416, max value of data: 114.14460153595954
# train_size: 743
# test_size: 185
# min value of data: 122.0976750411443, max value of data: 204.82192967437015
# train_size: 743
# test_size: 185
# min value of data: 172.8307076337207, max value of data: 277.7232810155937
# train_size: 743
# test_size: 185
# min value of data: 69.02469259777676, max value of data: 95.05863406211094
# train_size: 743
# test_size: 185
# min value of data: 80.30002210669456, max value of data: 155.22139996208327
# train_size: 743
# test_size: 185
# min value of data: 130.06822347846474, max value of data: 287.54747254546055
# train_size: 743
# test_size: 185
# min value of data: 192.35973116377357, max value of data: 299.9797803495469
# train_size: 743
# test_size: 185
# min value of data: 74.4695148777661, max value of data: 170.2562557086905
# train_size: 743
# test_size: 185
# min value of data: 104.18639662032017, max value of data: 167.74138657916143
# train_size: 743
# test_size: 185
# min value of data: 95.3582186897327, max value of data: 288.6465513661703
# train_size: 743
# test_size: 185
# min value of data: 142.2879579412418, max value of data: 240.86826761860183
# train_size: 743
# test_size: 185
# min value of data: 162.50628507972561, max value of data: 448.78829838423997
# train_size: 743
# test_size: 185
# min value of data: 72.42495029320605, max value of data: 113.77240785322473
# train_size: 743
# test_size: 185
# min value of data: 111.33461867597589, max value of data: 196.0581497082629
# train_size: 743
# test_size: 185
# min value of data: 101.12033624621186, max value of data: 277.0036094253246
# train_size: 743
# test_size: 185
# min value of data: 106.40327280958459, max value of data: 201.6937526111208
# train_size: 743
# test_size: 185
# min value of data: 120.03455410952766, max value of data: 197.23176456636926
# train_size: 743
# test_size: 185
# min value of data: 130.49515682501604, max value of data: 283.0980110838277
# train_size: 743
# test_size: 185
# min value of data: 110.10791571939971, max value of data: 157.0394416462132
# train_size: 743
# test_size: 185
# min value of data: 63.726343163387405, max value of data: 133.89338811114152
# train_size: 743
# test_size: 185
# min value of data: 135.087971896783, max value of data: 194.75921480190055
# train_size: 743
# test_size: 185
# min value of data: 57.43249393049274, max value of data: 83.55199124233059
# train_size: 743
# test_size: 185
# min value of data: 154.4395565331445, max value of data: 261.5228459633382
# train_size: 743
# test_size: 185
# min value of data: 108.18888569074292, max value of data: 182.3210159028102
# train_size: 743
# test_size: 185
# min value of data: 76.85304041530713, max value of data: 125.01599630803486
# train_size: 743
# test_size: 185
# min value of data: 122.48177590176051, max value of data: 314.0912345573345
# train_size: 743
# test_size: 185
# min value of data: 142.94089734569235, max value of data: 411.5629522805149
# train_size: 743
# test_size: 185
# min value of data: 87.57205619653513, max value of data: 123.25785528336135
# train_size: 743
# test_size: 185
# min value of data: 63.81624653030204, max value of data: 138.87407596076386
# train_size: 743
# test_size: 185
# min value of data: 81.83229963548187, max value of data: 114.3112220260568
# train_size: 743
# test_size: 185
# min value of data: 112.3339279668143, max value of data: 245.57090338983718
# train_size: 743
# test_size: 185
# min value of data: 69.97572612218099, max value of data: 133.39421698505217
# train_size: 743
# test_size: 185
# min value of data: 58.06493299398143, max value of data: 123.13471644287766
# train_size: 743
# test_size: 185
# min value of data: 136.3707382370677, max value of data: 189.2744250171474
# train_size: 743
# test_size: 185
# min value of data: 86.50076295759276, max value of data: 137.69370467523188
# train_size: 743
# test_size: 185
# min value of data: 50.29573981702655, max value of data: 90.95983649239555
# train_size: 743
# test_size: 185
# min value of data: 123.97395770807307, max value of data: 185.5400638329749
# train_size: 743
# test_size: 185
# min value of data: 155.8004299603986, max value of data: 269.3345070918139
# train_size: 743
# test_size: 185
# min value of data: 179.79847017885749, max value of data: 397.0678439031538
# train_size: 743
# test_size: 185
# min value of data: 79.95632709982871, max value of data: 152.84367833986036
# train_size: 743
# test_size: 185
# min value of data: 73.90494738148726, max value of data: 122.62091203225977
# train_size: 743
# test_size: 185
# min value of data: 90.05001226239112, max value of data: 160.38107390794187
# train_size: 743
# test_size: 185
# min value of data: 36.6303011149387, max value of data: 66.64377895337711
# train_size: 743
# test_size: 185
# min value of data: 45.52349361662141, max value of data: 90.01651126870374
# train_size: 743
# test_size: 185
# min value of data: 133.11741082696895, max value of data: 221.14951529776368
# train_size: 743
# test_size: 185
# min value of data: 145.08556883059236, max value of data: 224.77990369483206
# train_size: 743
# test_size: 185
# min value of data: 48.389693359738274, max value of data: 70.06650037407222
# train_size: 743
# test_size: 185
# min value of data: 117.22198590648556, max value of data: 166.89164415787218
# train_size: 743
# test_size: 185
# min value of data: 184.812590692264, max value of data: 385.47214129721283
# train_size: 743
# test_size: 185
# min value of data: 169.07258977252775, max value of data: 261.970059239397
# train_size: 743
# test_size: 185
# min value of data: 94.19382490679594, max value of data: 145.11832958569133
# train_size: 743
# test_size: 185
# min value of data: 166.94128617700014, max value of data: 236.1314973547528
# train_size: 743
# test_size: 185
# min value of data: 81.37252756500024, max value of data: 132.71741046568025
# train_size: 743
# test_size: 185
# min value of data: 74.51109034610072, max value of data: 111.82673040677788
# train_size: 743
# test_size: 185
# min value of data: 61.603231820672576, max value of data: 94.6047405628399
# train_size: 743
# test_size: 185
# min value of data: 127.61535572854977, max value of data: 302.970447130219
# train_size: 743
# test_size: 185
# min value of data: 51.95531481560235, max value of data: 161.7027155780683
# train_size: 743
# test_size: 185
# min value of data: 137.43718592964825, max value of data: 285.09556403775946
# train_size: 743
# test_size: 185
# min value of data: 55.34679634118422, max value of data: 79.18392902514401
# train_size: 743
# test_size: 185
# min value of data: 180.40201005025128, max value of data: 369.1862320082132
# train_size: 743
# test_size: 185
# min value of data: 39.61706656354847, max value of data: 72.02560199636807
# train_size: 743
# test_size: 185
# min value of data: 64.82147525262653, max value of data: 136.3944347975968
# train_size: 743
# test_size: 185
# min value of data: 46.71578322762698, max value of data: 70.06545747121811
# train_size: 743
# test_size: 185
# min value of data: 53.220619094506695, max value of data: 82.03012378550287
# train_size: 743
# test_size: 185
# min value of data: 40.71023490550947, max value of data: 53.92932110146881
# train_size: 743
# test_size: 185
# min value of data: 97.46683575996006, max value of data: 151.58854374833567
# train_size: 743
# test_size: 185
# min value of data: 100.72923239943299, max value of data: 276.08106247993646
# train_size: 743
# test_size: 185
# min value of data: 67.18755589377986, max value of data: 127.41377095363416
# train_size: 743
# test_size: 185
# min value of data: 112.74628904361093, max value of data: 366.867420031071
# train_size: 743
# test_size: 185
# min value of data: 151.68741205249185, max value of data: 421.2113843794178
# train_size: 743
# test_size: 185
# min value of data: 133.66576415623067, max value of data: 213.5506707289966
# train_size: 743
# test_size: 185
# min value of data: 95.80531789077246, max value of data: 221.4928961091726
# train_size: 743
# test_size: 185
# min value of data: 150.84702397328533, max value of data: 288.1759671929826
# train_size: 743
# test_size: 185
# min value of data: 83.8600982994072, max value of data: 154.9611055157746
# train_size: 743
# test_size: 185
# min value of data: 92.16941768632032, max value of data: 130.98141125511253
# train_size: 743
# test_size: 185
# min value of data: 48.04897910251737, max value of data: 72.03113313235542
# train_size: 743
# test_size: 185
# min value of data: 61.04035677738481, max value of data: 99.29858184854024
# train_size: 743
# test_size: 185
# min value of data: 91.54982992948514, max value of data: 177.3839579880631
# train_size: 743
# test_size: 185
# min value of data: 45.88885028736087, max value of data: 74.70256708722648
# train_size: 743
# test_size: 185
# min value of data: 69.12344144483173, max value of data: 113.70906495870797
# train_size: 743
# test_size: 185
# min value of data: 52.878777953340716, max value of data: 91.01764270078725
# train_size: 743
# test_size: 185
# min value of data: 155.71813521301254, max value of data: 472.07881403908044
# train_size: 743
# test_size: 185
# min value of data: 58.31649006535755, max value of data: 93.15843999971837
# train_size: 743
# test_size: 185
# min value of data: 36.53280690426879, max value of data: 98.92378215905383
# train_size: 743
# test_size: 185
# min value of data: 73.28904913671795, max value of data: 121.76404244613975
# train_size: 743
# test_size: 185
# min value of data: 144.8928914513805, max value of data: 312.50105623853807
# train_size: 743
# test_size: 185
# min value of data: 77.42582707068361, max value of data: 162.70533444551316
# train_size: 743
# test_size: 185
# min value of data: 119.90705869590275, max value of data: 211.21143696204788
# train_size: 743
# test_size: 185
# min value of data: 122.3962073980726, max value of data: 200.2756606432389
# train_size: 743
# test_size: 185
# min value of data: 133.8593729141564, max value of data: 236.77429909723827
# train_size: 743
# test_size: 185
# min value of data: 136.17394061139834, max value of data: 254.2470071026088
# train_size: 743
# test_size: 185
# min value of data: 177.19917202946374, max value of data: 325.9417751256182
# train_size: 743
# test_size: 185
# min value of data: 76.72518381525703, max value of data: 126.50502854244583
# train_size: 743
# test_size: 185
# min value of data: 62.43007473801602, max value of data: 81.43294577369316
# train_size: 743
# test_size: 185
# min value of data: 65.81878233954379, max value of data: 123.13336838242353
# train_size: 743
# test_size: 185
# min value of data: 129.75919449158962, max value of data: 297.5782815189494
# train_size: 743
# test_size: 185
# min value of data: 107.20941103954466, max value of data: 175.71647684991703
# train_size: 743
# test_size: 185
# min value of data: 113.55693080213581, max value of data: 203.7149842060761
# train_size: 743
# test_size: 185
# min value of data: 104.34672031943305, max value of data: 180.31041192358717
# train_size: 743
# test_size: 185
# min value of data: 160.99363232055768, max value of data: 249.0386496152161
# train_size: 743
# test_size: 185
# min value of data: 31.28416003503076, max value of data: 64.79461891409876
# train_size: 743
# test_size: 185
# min value of data: 110.25013747453391, max value of data: 215.74940391091883
# train_size: 743
# test_size: 185
# min value of data: 97.63925797801754, max value of data: 264.52166485449385
# train_size: 743
# test_size: 185
# min value of data: 176.16707811915666, max value of data: 333.06819287743
# train_size: 743
# test_size: 185
# min value of data: 50.31275750016771, max value of data: 90.47507798922747
# train_size: 743
# test_size: 185
# min value of data: 72.61507754267953, max value of data: 126.10243257825478
# train_size: 743
# test_size: 185
# min value of data: 37.66059137586361, max value of data: 84.42491508385788
# train_size: 743
# test_size: 185
# min value of data: 120.27641067941983, max value of data: 187.95133060324198
# train_size: 743
# test_size: 185
# min value of data: 78.26540749320638, max value of data: 132.09175503181794
# train_size: 743
# test_size: 185
# min value of data: 52.26130653266332, max value of data: 104.37908319099631
# train_size: 743
# test_size: 185
# min value of data: 145.06090276461327, max value of data: 270.3896765553696
# train_size: 743
# test_size: 185
# min value of data: 168.15603729029849, max value of data: 385.1328010889352
# train_size: 743
# test_size: 185
# min value of data: 179.6991059364167, max value of data: 301.8235053109573
# train_size: 743
# test_size: 185
# min value of data: 127.31481119807711, max value of data: 227.51434330967498
# train_size: 743
# test_size: 185
# min value of data: 170.91435824284528, max value of data: 366.12010683502103
# train_size: 743
# test_size: 185
# min value of data: 72.8811800158935, max value of data: 101.81813776996648
# train_size: 743
# test_size: 185
# min value of data: 54.31995795202487, max value of data: 101.68318219489177
# train_size: 743
# test_size: 185
# min value of data: 81.6310851509863, max value of data: 202.2912738770003
# train_size: 743
# test_size: 185
# min value of data: 69.20905576106334, max value of data: 210.3165386303053
# train_size: 743
# test_size: 185
# min value of data: 75.6601840657818, max value of data: 108.70903675111036
# train_size: 743
# test_size: 185
# min value of data: 83.96346817847505, max value of data: 148.30818831029856
# train_size: 743
# test_size: 185
# min value of data: 141.1347439101807, max value of data: 207.0661597349018
# train_size: 743
# test_size: 185
# min value of data: 170.51919325334157, max value of data: 454.96528249896966
# train_size: 743
# test_size: 185
# min value of data: 135.70918985287278, max value of data: 284.1525872986346
# train_size: 743
# test_size: 185
# min value of data: 139.235726554772, max value of data: 248.60763407018942
# train_size: 743
# test_size: 185
# min value of data: 113.44942137316572, max value of data: 239.72881025441276
# train_size: 743
# test_size: 185
# min value of data: 72.7540839562092, max value of data: 146.91714682809985
# train_size: 743
# test_size: 185
# min value of data: 126.4150876258856, max value of data: 277.3558053666696
# train_size: 743
# test_size: 185
# min value of data: 178.5390602760942, max value of data: 371.4252978345242
# train_size: 743
# test_size: 185
# min value of data: 180.87446172613406, max value of data: 326.208934870905
# train_size: 743
# test_size: 185
# min value of data: 44.19917717275642, max value of data: 76.59735269586632
# train_size: 743
# test_size: 185
# min value of data: 124.00698080554704, max value of data: 222.40760776175298
# train_size: 743
# test_size: 185
# min value of data: 74.44562809186398, max value of data: 165.77572077710965
# train_size: 743
# test_size: 185
# min value of data: 49.36151415728396, max value of data: 82.27239403263717
# train_size: 743
# test_size: 185
# min value of data: 101.2250203379136, max value of data: 284.9251888941833
# train_size: 743
# test_size: 185
# min value of data: 57.25295276371069, max value of data: 149.30368240652567
# train_size: 743
# test_size: 185
# min value of data: 90.93174790170883, max value of data: 157.59145096111465
# train_size: 743
# test_size: 185
# min value of data: 95.20020524911295, max value of data: 204.39357608093786
# train_size: 743
# test_size: 185
# min value of data: 89.58492685511544, max value of data: 155.3766771470686
# train_size: 743
# test_size: 185
# min value of data: 78.18590557616965, max value of data: 142.30321061999567
# train_size: 743
# test_size: 185
# min value of data: 106.29806168925282, max value of data: 174.8253565157384
# train_size: 743
# test_size: 185
# min value of data: 84.4976699234519, max value of data: 128.89113144650608
# train_size: 743
# test_size: 185
# min value of data: 108.77340731471352, max value of data: 185.48315448025463
# train_size: 743
# test_size: 185
# min value of data: 187.51106943870218, max value of data: 504.3618438694861
# train_size: 743
# test_size: 185
# min value of data: 123.16434530808712, max value of data: 193.36002889416167
# train_size: 743
# test_size: 185
# min value of data: 74.18599503832695, max value of data: 165.83354358919536
# train_size: 743
# test_size: 185
# min value of data: 60.76476316010792, max value of data: 149.72079441466028
# train_size: 743
# test_size: 185
# min value of data: 123.87433611486108, max value of data: 275.6959410499721
# train_size: 743
# test_size: 185
# min value of data: 138.35615080612948, max value of data: 302.1886985821918
# train_size: 743
# test_size: 185
# min value of data: 63.92391038750283, max value of data: 102.91124143555368
# train_size: 743
# test_size: 185
# min value of data: 136.79428448847708, max value of data: 284.95195360257793
# train_size: 743
# test_size: 185
# min value of data: 48.92477566865407, max value of data: 92.73684922573361
# train_size: 743
# test_size: 185
# min value of data: 87.73488510334046, max value of data: 142.43863610035052
# train_size: 743
# test_size: 185
# min value of data: 79.99340873489997, max value of data: 162.01807868049855
# train_size: 743
# test_size: 185
# min value of data: 190.08438769050454, max value of data: 337.4627862480816
# train_size: 743
# test_size: 185
# min value of data: 146.05649021468898, max value of data: 220.50590979475763
# train_size: 743
# test_size: 185
# min value of data: 45.97779356746825, max value of data: 87.4712925297993
# train_size: 743
# test_size: 185
# min value of data: 112.5783162659565, max value of data: 223.41064138423712
# train_size: 743
# test_size: 185
# min value of data: 104.14753088036113, max value of data: 291.6383024691855
# train_size: 743
# test_size: 185
# min value of data: 170.2822511166909, max value of data: 386.80505748990737
# train_size: 743
# test_size: 185
# min value of data: 109.29376831323926, max value of data: 160.8419739292777
# train_size: 743
# test_size: 185
# min value of data: 139.07143783838444, max value of data: 238.6354321123026
# train_size: 743
# test_size: 185
# min value of data: 145.0792526539348, max value of data: 493.71826439722554
# train_size: 743
# test_size: 185
# min value of data: 118.40554474445254, max value of data: 182.87014857771305
# train_size: 743
# test_size: 185
# min value of data: 107.17704560092749, max value of data: 205.28594510162122
# train_size: 743
# test_size: 185
# min value of data: 148.74371859296483, max value of data: 249.56245115139154
# train_size: 743
# test_size: 185
# min value of data: 70.69270851981415, max value of data: 119.76514614834507
# train_size: 743
# test_size: 185
# min value of data: 126.58989616423136, max value of data: 184.34192168675278
# train_size: 743
# test_size: 185
# min value of data: 99.09746015930872, max value of data: 207.61777792034073
# train_size: 743
# test_size: 185
# min value of data: 51.159381105556115, max value of data: 120.78578367376592
# train_size: 743
# test_size: 185
# min value of data: 59.33227364269413, max value of data: 123.0347989324063
# train_size: 743
# test_size: 185
# min value of data: 73.50629801869935, max value of data: 122.07448683759432
# train_size: 743
# test_size: 185
# min value of data: 185.00192071718854, max value of data: 329.98823613806996
# train_size: 743
# test_size: 185
# min value of data: 161.25001961997847, max value of data: 370.8190053661807
# train_size: 743
# test_size: 185
# min value of data: 143.0131741458352, max value of data: 236.9968829160791
# train_size: 743
# test_size: 185
# min value of data: 69.28625346925665, max value of data: 115.63522803531589
# train_size: 743
# test_size: 185
# min value of data: 92.73240157112161, max value of data: 123.60951155991822
# train_size: 743
# test_size: 185
# min value of data: 87.03709852281355, max value of data: 177.38143409886692
# train_size: 743
# test_size: 185
# min value of data: 101.2696130728169, max value of data: 203.14626914118196
# train_size: 743
# test_size: 185
# min value of data: 43.81193076015413, max value of data: 109.56940531644427
# train_size: 743
# test_size: 185
# min value of data: 89.0243542854382, max value of data: 153.03421267209765
# train_size: 743
# test_size: 185
# min value of data: 117.68866946678845, max value of data: 182.73931328362562
# train_size: 743
# test_size: 185
# min value of data: 105.99864066267097, max value of data: 182.91659679162893
# train_size: 743
# test_size: 185
# min value of data: 181.98674479880574, max value of data: 569.0112275945369
# train_size: 743
# test_size: 185
# min value of data: 125.64229401508895, max value of data: 229.2135004855168
# train_size: 743
# test_size: 185

# %% [markdown]
# ### Load the game environment

# %% [markdown]
# Setting our environment

# %%
env = StockEnv(stocks_train_data, real_stocks_train_data, risk_free_rate, history_t=history_t, option_T=option_T)
num_batch_episodes_per_epoch = env.get_total_num_episodes_per_epoch() // batch_size
build_warm_up_state_t = env.get_build_warm_up_state()
trace_length = option_T - build_warm_up_state_t
print('num_batch_episodes_per_epoch: ' + str(num_batch_episodes_per_epoch))
print('num_episodes_per_epoch: ' + str(env.get_total_num_episodes_per_epoch()))
print('min value of stock: '+str(min(train_data)) + ', max value of stock: '+str(max(train_data)))
plt.plot(range(len(train_data)), train_data, color='b')
# Out:
# ###############################
# option_T: 50
# history_t: 15
# build_warm_up_state_t: 12
# ###############################
# num_batch_episodes_per_epoch: 2118
# num_episodes_per_epoch: 135600
# min value of stock: 126.80873014680922, max value of stock: 229.2135004855168

# %%
num_actions = 2
num_atoms=51
vmax=float(10.)
vmin=float(-1.)
delta_z = (vmax - vmin) / float(num_atoms - 1)
_support = [vmin + i * delta_z for i in range(num_atoms)]

# %% [markdown]
# ### Implementing the network itself

# %%
class Qnetwork():
    def __init__(self,myScope):
        
        self._support = tf.linspace(vmin, vmax, num_atoms)
        
        self.scalarInput = tf.placeholder(shape=[None,input_size],dtype=tf.float32)
        
        # depending on the chosen architecture, data is processed through differents layers
        
        # convolutions are used in all type, except architecture 0 which only uses LSTM
        if architecture != 0:
          self.InputConvIn = tf.reshape(self.scalarInput,shape=[-1,input_size,1], name='InputConvIn')
          self.conv1 = tf.keras.layers.Conv1D(filters=nbFilters,
                                               kernel_size=3,
                                               strides=1,
                                               padding= paddingType, #'same',
                                               activation=tf.nn.relu)(inputs=self.InputConvIn)
        
        if architecture == 0: # LSTM only
          self.scalarInputFlattened = tf.keras.layers.Flatten()(self.scalarInput)
        elif architecture == 1: # only one convolution
          self.conv1flattened = tf.reshape(self.conv1,shape=[-1,self.conv1.shape[1]*self.conv1.shape[2]], name='conv1flattened')
        elif architecture == 2: # only one convolution followed by max pooling
          self.maxPooling1D = tf.keras.layers.MaxPool1D(pool_size=2, strides=2, padding='same')(inputs=self.conv1)
          self.maxPooling1Dflattened = tf.reshape(self.maxPooling1D,shape=[-1,self.maxPooling1D.shape[1]*self.maxPooling1D.shape[2]], name='maxPooling1Dflattened')
        elif architecture == 3: # only one convolution followed by average pooling
          self.AveragePooling1D = tf.keras.layers.AveragePooling1D(pool_size=2, strides=2, padding='same')(inputs=self.conv1)
          self.AveragePooling1Dflattened = tf.reshape(self.AveragePooling1D,shape=[-1,self.AveragePooling1D.shape[1]*self.AveragePooling1D.shape[2]], name='AveragePooling1Dflattened')  
        elif architecture == 4: #VGG (one block of 2 convolutions followed by avg pooling)
          self.conv2 = tf.keras.layers.Conv1D(filters=nbFilters,
                                               kernel_size=3,
                                               strides=1,
                                               padding= paddingType, #'same',
                                               activation=tf.nn.relu)(inputs=self.conv1)
          self.AveragePooling1D4 = tf.keras.layers.AveragePooling1D(pool_size=2, strides=2, padding='same')(inputs=self.conv2)
          self.AveragePooling1Dflattened4 = tf.reshape(self.AveragePooling1D4,shape=[-1,self.AveragePooling1D4.shape[1]*self.AveragePooling1D4.shape[2]], name='AveragePooling1Dflattened4')
        elif architecture == 5: #Lenet (conv, avg pooling, conv, avg pooling)
          self.AveragePooling1D = tf.keras.layers.AveragePooling1D(pool_size=2, strides=2, padding='same')(inputs=self.conv1)
          self.conv2 = tf.keras.layers.Conv1D(filters=nbFilters,
                                               kernel_size=3,#5, #3, #maybe unstable calculations because of 5 instead of 3
                                               strides=1,
                                               padding= paddingType, #'same',
                                               #activation=tf.keras.activations.hard_sigmoid
                                               #activation=tf.keras.activations.sigmoid
                                               #activation=tf.keras.activations.tanh
                                               activation=tf.nn.relu)(inputs=self.AveragePooling1D)
          self.AveragePooling1D5 = tf.keras.layers.AveragePooling1D(pool_size=2, strides=2, padding='same')(inputs=self.conv2)
          self.AveragePooling1Dflattened5 = tf.reshape(self.AveragePooling1D5,shape=[-1,self.AveragePooling1D5.shape[1]*self.AveragePooling1D5.shape[2]], name='AveragePooling1Dflattened5')
        elif architecture == 6: #Googlenet (Inception net: combine (conv&avgPooling) + conv1 + conv3 + conv5)
          self.AveragePooling1D = tf.keras.layers.AveragePooling1D(pool_size=2, strides=2, padding='same')(inputs=self.conv1)
          self.conv11 = tf.keras.layers.Conv1D(filters=5,
                                             kernel_size=1,
                                             strides=1,
                                             padding=paddingType,#'same',
                                             activation=tf.nn.relu)(inputs=self.AveragePooling1D)
          self.conv3 = tf.keras.layers.Conv1D(filters=5,
                                             kernel_size=3,
                                             strides=1,
                                             padding=paddingType,#'same',
                                             activation=tf.nn.relu)(inputs=self.AveragePooling1D)
          self.conv5 = tf.keras.layers.Conv1D(filters=5,
                                             kernel_size=5,
                                             strides=1,
                                             padding=paddingType,#'same',
                                             activation=tf.nn.relu)(inputs=self.AveragePooling1D)
          self.filterconcatenation = tf.concat([self.conv11, self.conv3, self.conv5, self.AveragePooling1D], 2, name = 'filterconcatenation')
          self.filterconcatenationflattened = tf.reshape(self.filterconcatenation,shape=[-1,self.filterconcatenation.shape[1]*self.filterconcatenation.shape[2]], name='filterconcatenationflattened')
        
        self.trainLength = tf.placeholder(dtype=tf.int32)
        self.batch_size = tf.placeholder(dtype=tf.int32,shape=[])
 
        #We take the output from the final convolutional layer and send it to a recurrent layer.
        #The input must be reshaped into [batch x trace x units] for rnn processing, 
        #and then returned to [batch x units] when sent through the upper levles.
        if architecture == 0:
          self.convFlat = tf.reshape(self.scalarInputFlattened,[self.batch_size,self.trainLength,input_size])
        elif architecture == 1:
          self.convFlat = tf.reshape(self.conv1flattened,[self.batch_size,self.trainLength,self.conv1flattened.shape[1]])
        elif architecture == 2:
          self.convFlat = tf.reshape(self.maxPooling1Dflattened,[self.batch_size,self.trainLength,self.maxPooling1Dflattened.shape[1]])
        elif architecture == 3:
          self.convFlat = tf.reshape(self.AveragePooling1Dflattened,[self.batch_size,self.trainLength,self.AveragePooling1Dflattened.shape[1]])
        elif architecture == 4:
          self.convFlat = tf.reshape(self.AveragePooling1Dflattened4,[self.batch_size,self.trainLength,self.AveragePooling1Dflattened4.shape[1]])
        elif architecture == 5:
          self.convFlat = tf.reshape(self.AveragePooling1Dflattened5,[self.batch_size,self.trainLength,self.AveragePooling1Dflattened5.shape[1]])
        elif architecture == 6:
          self.convFlat = tf.reshape(self.filterconcatenationflattened,[self.batch_size,self.trainLength,self.filterconcatenationflattened.shape[1]])
        
        # use cudnn-based cells to leverage Nvidia GPUs
        single_cell = lambda: tf.contrib.cudnn_rnn.CudnnCompatibleLSTMCell(h_size)
    
        # NOTE: Even if there's only one layer, the cell needs to be wrapped in MultiRNNCell.
        lstm_cells = [single_cell() for _ in range(num_layers)]
        if is_training and apply_dropout and dropout < 1:
            lstm_cells = [tf.contrib.rnn.DropoutWrapper(
                lstm, input_keep_prob=1.0, output_keep_prob=1.0 - dropout, state_keep_prob=1.0 - dropout
            ) for lstm in lstm_cells]
        multi_cell = tf.nn.rnn_cell.MultiRNNCell(lstm_cells, state_is_tuple=True)

        self.state_in = tf.placeholder(tf.float32, [num_layers, 2, None, h_size])
        state_per_layer_list = tf.unstack(self.state_in, axis=0)
        rnn_tuple_state = tuple(
            [tf.contrib.rnn.LSTMStateTuple(state_per_layer_list[idx][0], state_per_layer_list[idx][1])
             for idx in range(num_layers)]
        )
        
        # calculate the real length of each episode (since remaining states are filled with 0s after selling)
        # This is required by RNN 
        self.seq_len = length(self.convFlat)
        
        self.rnn,self.rnn_state = tf.nn.dynamic_rnn(\
                cell=multi_cell,
                inputs=self.convFlat,                                    
                dtype=tf.float32,
                initial_state=rnn_tuple_state, 
                sequence_length=self.seq_len,
                scope=myScope+'_lstm')
        

        self.rnn = tf.reshape(self.rnn,shape=[-1,h_size])
        
        self.weights_initializer = tf.contrib.slim.variance_scaling_initializer(factor=1.0 / np.sqrt(3.0), mode='FAN_IN', uniform=True)
        self.net = tf.contrib.slim.fully_connected(
              self.rnn, #self.net,
              num_actions * num_atoms,
              activation_fn=None,
              weights_initializer=self.weights_initializer)

        self.logits = tf.reshape(self.net, [-1, num_actions, num_atoms])
        self.probabilities = tf.contrib.layers.softmax(self.logits)
        self.q_values = tf.reduce_sum(self._support * self.probabilities, axis=2)
        
        self.predict = tf.argmax(self.q_values,1)
        
            
        self.actions = tf.placeholder(shape=[None],dtype=tf.int32)    
        # create placeholder for target_distribution
        self.target_distribution = tf.placeholder(shape=[None,num_atoms],dtype=tf.float32)

        # size of indices: batch_size x 1.
        self.indices = tf.range(tf.shape(self.logits)[0])[:, None]
        # size of reshaped_actions: batch_size x 2.
        self.reshaped_actions = tf.concat([self.indices, self.actions[:, None]], 1)
        # For each element of the batch, fetch the logits for its selected action.
        self.chosen_action_logits = tf.gather_nd(self.logits,
                                            self.reshaped_actions)

        self.td_error = tf.nn.softmax_cross_entropy_with_logits(labels=self.target_distribution,logits=self.chosen_action_logits)
        # In order to only propogate accurate gradients through the network, we can mask the first
        # half of the losses for each trace as per Lample & Chaplot 2016
        # We can also use gradual weights to avoid neglecting short episodes at the beginning
        # maybe seq_len used in averaging should also change subsequently !
        if mask_type == 'maskFirstHalf':
            self.maskA = tf.zeros([self.batch_size,self.trainLength//2])
            self.maskB = tf.ones([self.batch_size,self.trainLength//2])
            self.mask = tf.concat([self.maskA,self.maskB],1)
            self.mask = tf.reshape(self.mask,[-1])
            self.td_error = self.td_error * self.mask
        elif mask_type == 'maskByWeights': 
            #self.mask_weights = tf.range(start=0, limit=1, delta=1/self.trainLength)
            self.mask_weights = tf.range(start=0.1, limit=1, delta=0.9/tf.cast(self.trainLength, tf.float32))
            self.mask = tf.tile(self.mask_weights, [self.batch_size])
            self.td_error = tf.multiply(self.td_error, tf.cast(self.mask, tf.float32))
        elif mask_type == 'default':
            self.td_error = self.td_error
        
        # divide by the real length of episodes instead of averaging which is incorrect
        self.loss = tf.cast(tf.reduce_sum(self.td_error), tf.float64) / tf.cast(tf.reduce_sum(self.seq_len), tf.float64)
        self.check_ops = tf.debugging.check_numerics( self.loss, "self.loss contain Nan or Inf", name="self.check_ops")
        
        if optimizer_type == 'Adam':
            optimizer = tf.train.AdamOptimizer(learning_rate)
        elif optimizer_type == 'GradientDescent':
            optimizer = tf.train.GradientDescentOptimizer(learning_rate)
        elif optimizer_type == 'RMSProp':
            optimizer = tf.train.RMSPropOptimizer(learning_rate)
        
        if apply_grad_clipping:
            # calculate gradients and clip them to handle outliers
            tvars = tf.trainable_variables()
            grads, _ = tf.clip_by_global_norm(tf.gradients(self.loss, tvars), grad_clipping)
            self.updateModel = optimizer.apply_gradients(
                    zip(grads, tvars),
                    # global_step=tf.contrib.framework.get_or_create_global_step(),
                    name="updateModel")
        else:
            self.updateModel = optimizer.minimize(self.loss, name="updateModel")

# %% [markdown]
# ### Experience Replay

# %% [markdown]
# These classes allow us to store experies and sample then randomly to train the network.
# Episode buffer stores experiences for each individal episode.
# Experience buffer stores entire episodes of experience, and sample() allows us to get training batches needed from the network.

# %%
class experience_buffer():
    def __init__(self, buffer_size = memory_capacity, build_warm_up_state_t=build_warm_up_state_t):
        self.buffer = []
        self.buffer_size = buffer_size
    
    def add(self,experience):
        if len(self.buffer) + 1 >= self.buffer_size:
            self.buffer[0:(1+len(self.buffer))-self.buffer_size] = []
        self.buffer.append(experience)
    
    def sample(self,batch_size):
        sampled_episodes = random.sample(self.buffer,batch_size)
        #sampled_episodes = np.array(sampled_episodes)
        sampled_episodes = self.processEpisodes(sampled_episodes)
        return np.reshape(sampled_episodes,[-1,5])
    
    def processEpisodes(self,sampled_episodes):
        sampledTraces = []
        for episode in sampled_episodes:
            sampledTraces.append(episode[build_warm_up_state_t:])
        sampledTraces = np.array(sampledTraces)
        return sampledTraces

# %% [markdown]
# ### Training the network

# %%
#Setting the training parameters
num_layers = 3 # Number of layer of LSTM
h_size = 512 #256 #512 #128 #512 #256 #512 #The size of the final convolutional layer before splitting it into Advantage and Value streams.
keep_prob = 0.8
dropout = 1 - keep_prob  # dropout amount
update_freq = 5 #30 #10 #5 #How often to perform a training step.
update_online_freq = 5 #10 #5 #3 #5
update_target_freq = 30 #300 #30
#gamma = discount_factor #.99 #.95 #1 #Discount factor on the target Q-values
gamma = env.get_discount_factor(1) # discount for 1 day
startE = 1 #0.1 #1 #Starting chance of random action
endE = 0.1 #0.01 #0.1 #Final chance of random action
num_epochs = 5
num_episodes = env.get_total_num_episodes_per_epoch()*num_epochs #30 #50000 #20000 #100000 #20000 #3000 #20000 #30000 #10000 #4000 #100000 #40000
pre_train_episodes = int(memory_capacity * 0.1) # 0.25 300 #300 #200 #600 #200
annealing_episodes = int(num_episodes * 0.3) #4*memory_capacity #0.7*memory_capacity #400 #memory_capacity #400
pre_exploitation_episodes = int(num_episodes * 0.6)
annealing_exploitation_episodes = int(num_episodes * 0.25)
exploitationE =  0.01 #0.008 #0.02
load_model = False #Whether to load a saved model.
path = os.path.join(scriptDirectory, 'savedModel') #The path to save our model to.
max_epLength = option_T #env.get_max_episode_time() #option_T + build_warm_up_state_t
summaryLength = 100 #Number of epidoes to periodically save for analysis
summaryAverageReward = 5000
summaryEpoch = env.get_total_num_episodes_per_epoch()
tau = 0.001 # learning rate (also referred to as step size) for target network
softUpdate = False # use soft or hard updates
#trained_model_name = os.path.join(path, 'architecture' + str(architecture) + '-option_T' + str(option_T) + '-history_t' + str(history_t) + '-num_episodes' + str(num_episodes) + '-tau' + str(tau) + '-softUpdate' + str(softUpdate) + '-dropout' + str(dropout) + '-mask' + str(mask_type) + '-dueling_type' + str(dueling_type) + '-So' + str(So) + '-strike_price' + str(strike_price) + '-mu' + str(mu) + '-sigma' + str(sigma) + '-num_seeds' + str(num_seeds))
trained_model_name = os.path.join(path, 'C51_noSoft_arch' + str(architecture)\
                    + '-option_T' + str(option_T) + '-history_t' + str(history_t)\
                    + '-num_episodes' + str(num_episodes)\
                    + '-softUpdate' + str(softUpdate) + '-tau' + str(tau)\
                    + '-dropout' + str(dropout) + str(apply_dropout)\
                    + '-num_layers' + str(num_layers) #+ '-apply_dropout' + str(apply_dropout)\
                    + '-freq' + str(update_target_freq) + '-batch' + str(batch_size)\
                    + '-capacity' + str(memory_capacity) + '-lambda' + str(learning_rate))
final_trained_model_name = trained_model_name + '-final'
final_trained_model_name = os.path.join(path, final_trained_model_name)
exploration_type = 'Random'
print('#num_episodes: ' + str(num_episodes))
print('#trace_length: ' + str(trace_length))
print('#gamma: ' + str(gamma))
# Out:
# #num_episodes: 678000
# #trace_length: 38
# #gamma: 0.9998016069840849

# %%
begin_time = time.time()
tf.reset_default_graph()
#We define the primary and target q-networks
mainQN = Qnetwork('main')
targetQN = Qnetwork('target')


init = tf.global_variables_initializer()

saver = tf.train.Saver(max_to_keep=5)

trainables = tf.trainable_variables()

targetOps = updateTargetGraph(trainables,tau,softUpdate)

myBuffer = experience_buffer()

#Set the rate of random action decrease. 
e = startE
# amounts by which to anneal
episodeDrop = (startE - endE)/annealing_episodes

episodeDrop2 = (endE - exploitationE)/annealing_exploitation_episodes

#create lists to contain total rewards, steps per episode, sell time and epsilon
jList = []
rList = []
sTimeList = [] # sell time list
eList = []

percentage_rList = []
real_percentage_rList = []

NonRandom_percentage_rList = []
NonRandom_real_percentage_rList = []

option_percentage_rList = []
option_real_percentage_rList = []

NonRandom_option_percentage_rList = []
NonRandom_option_real_percentage_rList = []

#Non random day Lists
NonRandomrList = []
NonRandomsTimeList = [] # sell time list

# Average metrics per 100 episodes
AvgEpisodeList = []
AvgrList = []
AvgsTimeList = []
AvgEpisodeListEpoch = []
AvgrListEpoch = []
AvgsTimeListEpoch = []

AvgLossList = []
AvgQSellLossList = []

AvgLossListEpochTemp = [] # Temp
AvgLossListEpoch = [] # permanent

AvgMainQList = []
AvgTargetQList = []
AvgMainMaxQList = []
AvgMainHoldQList = []
AvgMainSellQList = []
maxPossiblerList = []

maxPossibleP_returnList = []
maxPossibleR_P_returnList = []

maxPossibleOptionP_returnList = []
maxPossibleOptionR_P_returnList = []

# Non random days
AvgNonRandomrList = []
AvgNonRandomsTimeList = []

#Make a path for our model to be saved in.
if not os.path.exists(path):
    os.makedirs(path)  

#Some config to parralelize and leverage the GPU capabilities.
config = tf.ConfigProto()
config.intra_op_parallelism_threads = 0 #16 #44
config.inter_op_parallelism_threads = 0 #16 #44
config.gpu_options.allow_growth = True
config.allow_soft_placement = True
#config.device_count = {"CPU": 4}, # limit to num_cpu_core CPU usage 
#config.log_device_placement = True
#tf.Session(config=config)

with tf.Session(config=config) as sess, tf.device('/gpu:1'):
    set_seed(seed)
    if load_model == True:
        print ('Loading Model...')
        saver.restore(sess,final_trained_model_name)
    else:
        sess.run(init)
   
    updateTarget(targetOps,sess) #Update the target network.
    for i in range(num_episodes):
        episodeBuffer = []
        #Reset environment and get first new observation
        sP = env.reset()
        s = processState(sP, input_size)
        d = False
        rAll = 0
        j = 0
        #Reset the lstm's hidden state
        state = np.zeros((num_layers, 2, 1, h_size))
        
        if exploration_type == 'Random' and np.random.rand(1) < e:
            sell_time = random.randint(build_warm_up_state_t,max_epLength - 1)
        else:
            sell_time = -1
            
        while j < max_epLength: 
            #Choose an action greedily (with e chance of random action) from the Q-network
            if env.is_episode_finished(): # fill with empty state till the end to have episodes of equal length to train
                a = 0 # arbitrary
                s1P,r,d = env.empty_step()
            else:
                if i < pre_train_episodes or env.get_time() < build_warm_up_state_t or sell_time != -1:    
                    #construct the state for following steps of same episode
                    if sell_time != -1:
                        state1 = np.zeros((num_layers, 2, 1, h_size))
                    else:
                        state1 = sess.run(mainQN.rnn_state,\
                            feed_dict={mainQN.scalarInput:[s],mainQN.trainLength:1,mainQN.state_in:state,mainQN.batch_size:1})
                    
                    if env.get_time() < build_warm_up_state_t or env.get_payoff() <= 0:
                        a = 0 #hold
                    elif sell_time != -1:
                        if j == sell_time and d == False:
                            a = 1
                        else:
                            a = 0
                    elif j == max_epLength - 1 and d == False:
                        a = 1
                    else:
                        a = np.random.randint(0,2)

                else:
                    a, state1 = sess.run([mainQN.predict,mainQN.rnn_state],\
                        feed_dict={mainQN.scalarInput:[s],mainQN.trainLength:1,mainQN.state_in:state,mainQN.batch_size:1})
                    a = a[0]
            
                s1P,r,d = env.step(a)
            
            s1 = processState(s1P, input_size)
            
            episodeBuffer.append(np.reshape(np.array([s,a,r,s1,d]),[1,5])) # store experience

            rAll += r
            s = s1
            sP = s1P
            state = state1
            j+=1 # episode length till selling or reaching last day of option
        
        myBuffer.add(episodeBuffer)
        jList.append(j)
        rList.append(rAll)
        sTimeList.append(env.get_sell_time() + 1)
        eList.append(e)
        best_reward, stock_percentage_return, option_percentage_return, stock_real_percentage_return,\
        option_real_percentage_return = env.get_best_possible_reward()
        
        maxPossiblerList.append(best_reward)
        maxPossibleP_returnList.append(stock_percentage_return)
        maxPossibleR_P_returnList.append(stock_real_percentage_return)
        maxPossibleOptionP_returnList.append(option_percentage_return)
        maxPossibleOptionR_P_returnList.append(option_real_percentage_return)
        stock_percentage_return, option_percentage_return = env.get_percentage_return()
        percentage_rList.append(stock_percentage_return)
        option_percentage_rList.append(option_percentage_return)
        stock_percentage_return, option_percentage_return = env.get_real_percentage_return()
        real_percentage_rList.append(stock_percentage_return)
        option_real_percentage_rList.append(option_percentage_return)
        
        if sell_time == -1:
            NonRandomrList.append(rAll)
            NonRandomsTimeList.append(env.get_sell_time() + 1)
            
            stock_percentage_return, option_percentage_return = env.get_percentage_return()
            NonRandom_percentage_rList.append(stock_percentage_return)
            NonRandom_option_percentage_rList.append(option_percentage_return)
            stock_percentage_return, option_percentage_return = env.get_real_percentage_return()
            NonRandom_real_percentage_rList.append(stock_percentage_return)
            NonRandom_option_real_percentage_rList.append(option_percentage_return)

        if i >= pre_train_episodes:
            #Reset the lstm's hidden state
            state_train = np.zeros((num_layers, 2, batch_size, h_size))
            #Get a random batch of experiences.
            trainBatch = myBuffer.sample(batch_size)
            #Below we perform the Double-DQN update to the target Q-values
            num_samples = batch_size*trace_length
            m_prob = np.zeros((num_samples, num_atoms))
            
            optimal_action_idxs = sess.run([mainQN.predict], feed_dict={\
                                mainQN.scalarInput:np.vstack(trainBatch[:,3]),\
                                mainQN.trainLength:trace_length,mainQN.state_in:state_train,mainQN.batch_size:batch_size})
            optimal_action_idxs = np.reshape(optimal_action_idxs, [-1, 1])
            probabilities = sess.run(targetQN.probabilities, feed_dict={\
                                targetQN.scalarInput:np.vstack(trainBatch[:,3]),\
                                targetQN.trainLength:trace_length,targetQN.state_in:state_train,targetQN.batch_size:batch_size})
            
            for s in range(num_samples):
                if trainBatch[s,4]:
                    # Distribution collapses to a single point
                    Tz = min(vmax, max(vmin, trainBatch[s,2]))
                    bj = (Tz - vmin) / delta_z 
                    m_l, m_u = math.floor(bj), math.ceil(bj)
                    m_prob[s, int(m_l)] += (m_u - bj)
                    m_prob[s, int(m_u)] += (bj - m_l)
                    
                else:
                    for j in range(num_atoms):
                        Tz = min(vmax, max(vmin, trainBatch[s,2] + gamma * _support[j]))
                        bj = (Tz - vmin) / delta_z 
                        m_l, m_u = math.floor(bj), math.ceil(bj)
                        m_prob[s, int(m_l)] += probabilities[s, optimal_action_idxs[s], j] * (m_u - bj)
                        m_prob[s, int(m_u)] += probabilities[s, optimal_action_idxs[s], j] * (bj - m_l)

            loss, _, _ = sess.run([mainQN.loss, mainQN.check_ops, mainQN.updateModel], \
                                feed_dict={mainQN.scalarInput:np.vstack(trainBatch[:,0]),mainQN.target_distribution:m_prob,\
                                mainQN.actions:trainBatch[:,1],mainQN.trainLength:trace_length,\
                                mainQN.state_in:state_train,mainQN.batch_size:batch_size})
            # perform soft/hard update frequently
            if i % update_target_freq == 0 or update_target_freq == 1 or softUpdate == True:
                updateTarget(targetOps,sess)
                

        #Periodically save the model and print metrics. 
        if i % save_model_freq == 0 and i != 0:
            saver.save(sess,trained_model_name, global_step=i)
            print ("Saved Model")
            inter_time = time.time()
            print('#Intermediate time to execute: '+ str((inter_time - begin_time)/60) + 'min')
        
        if len(rList) % summaryLength == 0 and len(rList) != 0:
            AvgR = np.mean(rList[-summaryLength:])
            AvgsT = np.mean(sTimeList[-summaryLength:])
            AvgEpisodeList.append(i+1)
            AvgrList.append(AvgR)
            AvgsTimeList.append(AvgsT)
            
            if i >= pre_train_episodes:
                AvgLossList.append(loss)
                
                #per epoch temporary array to store values per epoch then erase for new epochs
                AvgLossListEpochTemp.append(loss)
                
            print('episode ' + str(i+1) + ': \t' + str(AvgR) 
                  + '\t' + str(AvgsT)+ '\t'+ str(e))
        
        if len(NonRandomrList) % summaryLength == 0 and len(NonRandomrList) != 0:
            AvgNonRandomR = np.mean(NonRandomrList[-summaryLength:])
            AvgNonRandomsT = np.mean(NonRandomsTimeList[-summaryLength:])
            AvgNonRandomrList.append(AvgNonRandomR)
            AvgNonRandomsTimeList.append(AvgNonRandomsT)
                

        if i > pre_train_episodes:
            if e > endE:
                e -= episodeDrop
            if i >= pre_exploitation_episodes:
                if e > exploitationE:
                    e -= episodeDrop2
                
        if len(rList) % summaryAverageReward == 0 and len(rList) != 0:
            print ("#Average reward per episode " + str(i+1) + ": " + str(sum(rList)/len(rList)))
            
        if len(rList) % summaryEpoch == 0 and len(rList) != 0:
            AvgREpoch = np.mean(rList[-summaryEpoch:])
            AvgsTEpoch = np.mean(sTimeList[-summaryEpoch:])
            AvgEpisodeListEpoch.append(i+1)
            AvgrListEpoch.append(AvgREpoch)
            AvgsTimeListEpoch.append(AvgsTEpoch)
            
            #loss
            lossEpoch = np.mean(AvgLossListEpochTemp)
            AvgLossListEpoch.append(lossEpoch)
            AvgLossListEpochTemp = []
            
    # Do a final save        
    #saver.save(sess,path+'/model-'+str(i)+'.cptk')  
    saver.save(sess,final_trained_model_name)  
option_percentage_rList = [value for value in option_percentage_rList if not math.isnan(value)]
maxPossibleOptionP_returnList = [value for value in maxPossibleOptionP_returnList if not math.isnan(value)]

print ("#Total average reward per episode: " + str(sum(rList)/num_episodes))

print ("#Total average reward per non-random episode: " + str(np.mean(AvgNonRandomrList)))

print ("#Max possible average reward per episode: " + str(np.mean(maxPossiblerList)))

print ("#Confidence Interval with prob of 90%: " + str(env.getConfidenceInterval(rList)))

print ("#Confidence Interval with prob of 95%: " + str(env.getConfidenceInterval95(rList)))

print ("#Sell time entropy: " + str(env.getEntropy(sTimeList)))

print ("#Percentage of stock returns (Normalized): " + str(np.mean(percentage_rList)))

print ("#Percentage of stock returns (Real values): " + str(np.mean(real_percentage_rList)))

print ("#Percentage of option returns (Normalized): " + str(np.mean(option_percentage_rList)))

print ("#Percentage of option returns (Real values): " + str(np.mean(option_real_percentage_rList)))

print ("#Percentage of Non Random stock returns (Normalized): " + str(np.mean(NonRandom_percentage_rList)))

print ("#Percentage of Non Random stock returns (Real values): " + str(np.mean(NonRandom_real_percentage_rList)))

print ("#Percentage of Non Random option returns (Normalized): " + str(np.mean(NonRandom_option_percentage_rList)))

print ("#Percentage of Non Random option returns (Real values): " + str(np.mean(NonRandom_option_real_percentage_rList)))

print ("#Max possible average stock percentage return per episode: " + str(np.mean(maxPossibleP_returnList)))

print ("#Max possible average real stock percentage return per episode: " + str(np.mean(maxPossibleR_P_returnList)))

print ("#Max possible average option percentage return per episode: " + str(np.mean(maxPossibleOptionP_returnList)))

print ("#Max possible average real option percentage return per episode: " + str(np.mean(maxPossibleOptionR_P_returnList)))

print ("#Confidence Interval of Percentage of returns (Normalized) with prob of 90%: " + str(env.getConfidenceInterval(NonRandom_percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Normalized) with prob of 95%: " + str(env.getConfidenceInterval95(NonRandom_percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Real values) with prob of 90%: " + str(env.getConfidenceInterval(NonRandom_real_percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Real values) with prob of 95%: " + str(env.getConfidenceInterval95(NonRandom_real_percentage_rList)))


print ("#Confidence Interval of Percentage of option returns (Normalized) with prob of 90%: " + str(env.getConfidenceInterval(option_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Normalized) with prob of 95%: " + str(env.getConfidenceInterval95(option_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Real values) with prob of 90%: " + str(env.getConfidenceInterval(option_real_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Real values) with prob of 95%: " + str(env.getConfidenceInterval95(option_real_percentage_rList)))
    
end_time = time.time()
print('#Time to execute: '+ str((end_time - begin_time)/60) + 'min')

# %%
e=0

# %% [markdown]
# ### Testing the network on train set again

# %%
#e = 0.03 #0.01 #The chance of chosing a random action
load_model = True #Whether to load a saved model.
is_training = False

# %%
env = StockEnv(stocks_train_data, real_stocks_train_data, risk_free_rate, history_t=history_t, option_T=option_T)
#max_num_observations = env.max_num_observations
num_batch_episodes_per_epoch = env.get_total_num_episodes_per_epoch() // batch_size
num_episodes = env.get_total_num_episodes_per_epoch()
print('num_batch_episodes_per_epoch: ' + str(num_batch_episodes_per_epoch))
print('num_episodes_per_epoch: ' + str(env.get_total_num_episodes_per_epoch()))
print('min value of stock: '+str(min(train_data)) + ', max value of stock: '+str(max(train_data)))
plt.plot(range(len(test_data)), test_data, color='b')
# Out:
# ###############################
# option_T: 50
# history_t: 15
# build_warm_up_state_t: 12
# ###############################
# num_batch_episodes_per_epoch: 2118
# num_episodes_per_epoch: 135600
# min value of stock: 126.80873014680922, max value of stock: 229.2135004855168

# %%
begin_time = time.time()
tf.reset_default_graph()

mainQN = Qnetwork('main')
targetQN = Qnetwork('target')


init = tf.global_variables_initializer()

saver = tf.train.Saver(max_to_keep=2)

myBuffer = experience_buffer()

#create lists to contain total rewards and steps per episode
jList = []
rList = []
sTimeList = [] # sell time list

percentage_rList = []
real_percentage_rList = []

option_percentage_rList = []
option_real_percentage_rList = []

# Average metrics per 100 episodes
AvgEpisodeList = []
AvgrList = []
AvgsTimeList = []
maxPossiblerList = []

maxPossibleP_returnList = []
maxPossibleR_P_returnList = []

maxPossibleOptionP_returnList = []
maxPossibleOptionR_P_returnList = []

#num_short_sell = 0

#Make a path for our model to be saved in.
if not os.path.exists(path):
    os.makedirs(path) 
  

with tf.Session() as sess, tf.device('/gpu:1'):
    set_seed(seed)
    if load_model == True:
        print ('Loading Model...')
        #ckpt = tf.train.get_checkpoint_state(path)
        #saver.restore(sess,ckpt.model_checkpoint_path)
        saver.restore(sess,final_trained_model_name)
    else:
        sess.run(init)
    
    for i in range(num_episodes):
        episodeBuffer = []
        #Reset environment and get first new observation
        sP = env.reset()
        s = processState(sP, input_size)
        d = False
        rAll = 0
        j = 0
        #Reset the recurrent layer's hidden state
        state = np.zeros((num_layers, 2, 1, h_size))
        while j < max_epLength: 

            if j == max_epLength - 1 and env.is_episode_finished() == False:
                a = 1
            else:
                a, state1 = sess.run([mainQN.predict,mainQN.rnn_state],\
                        feed_dict={mainQN.scalarInput:[s],mainQN.trainLength:1,mainQN.state_in:state,mainQN.batch_size:1})
                if env.get_time() < build_warm_up_state_t:
                    a = 0 #hold
                elif env.get_payoff() <= 0:
                    a = 0 #hold
                    #num_short_sell += 1
                else:
                    a = a[0]
                
            s1P,r,d = env.step(a)
            
            s1 = processState(s1P, input_size)
            
            episodeBuffer.append(np.reshape(np.array([s,a,r,s1,d]),[1,5])) # store experience

            rAll += r
            s = s1
            sP = s1P
            state = state1
            j+=1 # episode length till selling or reaching last day of option

            if env.is_episode_finished():
                break
        
        myBuffer.add(episodeBuffer)
        jList.append(j)
        rList.append(rAll)
        sTimeList.append(env.get_sell_time() + 1)
        #maxPossiblerList.append(env.get_best_possible_reward())
        #best_reward, percentage_return, real_percentage_return = env.get_best_possible_reward()
        best_reward, stock_percentage_return, option_percentage_return, stock_real_percentage_return,\
        option_real_percentage_return = env.get_best_possible_reward()
        
        maxPossiblerList.append(best_reward)
        maxPossibleP_returnList.append(stock_percentage_return)
        maxPossibleR_P_returnList.append(stock_real_percentage_return)
        maxPossibleOptionP_returnList.append(option_percentage_return)
        maxPossibleOptionR_P_returnList.append(option_real_percentage_return)
        #real_percentage_rList.append(env.get_real_percentage_return())
        stock_percentage_return, option_percentage_return = env.get_percentage_return()
        percentage_rList.append(stock_percentage_return)
        option_percentage_rList.append(option_percentage_return)
        stock_percentage_return, option_percentage_return = env.get_real_percentage_return()
        real_percentage_rList.append(stock_percentage_return)
        option_real_percentage_rList.append(option_percentage_return)

        #Periodically print metrics. 
        if len(rList) % summaryLength == 0 and len(rList) != 0:
            AvgR = np.mean(rList[-summaryLength:])
            AvgsT = np.mean(sTimeList[-summaryLength:])
            AvgEpisodeList.append(i+1)
            AvgrList.append(AvgR)
            AvgsTimeList.append(AvgsT)
            print('episode ' + str(i+1) + ': \t' + str(AvgR) 
                  + '\t' + str(AvgsT))
            
        if len(rList) % summaryAverageReward == 0 and len(rList) != 0:
            print ("#Average reward per episode " + str(i+1) + ": " + str(sum(rList)/len(rList)))
                
option_percentage_rList = [value for value in option_percentage_rList if not math.isnan(value)]
maxPossibleOptionP_returnList = [value for value in maxPossibleOptionP_returnList if not math.isnan(value)]

print ("#Total average reward per episode: " + str(sum(rList)/num_episodes))

print ("#Max possible average reward per episode: " + str(np.mean(maxPossiblerList)))

print ("#Confidence Interval with prob of 90%: " + str(env.getConfidenceInterval(rList)))

print ("#Confidence Interval with prob of 95%: " + str(env.getConfidenceInterval95(rList)))

print ("#Sell time entropy: " + str(env.getEntropy(sTimeList)))

print ("#Percentage of stock returns (Normalized): " + str(np.mean(percentage_rList)))

print ("#Percentage of stock returns (Real values): " + str(np.mean(real_percentage_rList)))

print ("#Percentage of option returns (Normalized): " + str(np.mean(option_percentage_rList)))

print ("#Percentage of option returns (Real values): " + str(np.mean(option_real_percentage_rList)))

print ("#Max possible average stock percentage return per episode: " + str(np.mean(maxPossibleP_returnList)))

print ("#Max possible average real stock percentage return per episode: " + str(np.mean(maxPossibleR_P_returnList)))

print ("#Max possible average option percentage return per episode: " + str(np.mean(maxPossibleOptionP_returnList)))

print ("#Max possible average real option percentage return per episode: " + str(np.mean(maxPossibleOptionR_P_returnList)))

print ("#Confidence Interval of Percentage of returns (Normalized) with prob of 90%: " + str(env.getConfidenceInterval(percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Normalized) with prob of 95%: " + str(env.getConfidenceInterval95(percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Real values) with prob of 90%: " + str(env.getConfidenceInterval(real_percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Real values) with prob of 95%: " + str(env.getConfidenceInterval95(real_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Normalized) with prob of 90%: " + str(env.getConfidenceInterval(option_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Normalized) with prob of 95%: " + str(env.getConfidenceInterval95(option_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Real values) with prob of 90%: " + str(env.getConfidenceInterval(option_real_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Real values) with prob of 95%: " + str(env.getConfidenceInterval95(option_real_percentage_rList)))

#print ("#Number of short selling: " + str(num_short_sell))

#print ("#Discounted rewards:")

#print ("#Total average reward per episode: " + str(sum(rList)/num_episodes * discount_factor))

#print ("#Max possible average reward per episode: " + str(np.mean(maxPossiblerList) * discount_factor))

end_time = time.time()
print('#Time to execute: '+ str((end_time - begin_time)/60) + 'min')
# Out:
# WARNING:tensorflow:From <ipython-input-8-da976005959c>:99: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-8-da976005959c>:118: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d26845550>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d26845550>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d26845550>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d26845550>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From /misc/home/reco/fathanab/anaconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d26839890>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d26839890>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d26839890>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d26839890>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d268451d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d268451d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d268451d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d268451d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d267c5f10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d267c5f10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d267c5f10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d267c5f10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:From /misc/home/reco/fathanab/anaconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow/python/ops/rnn.py:244: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2d279fc250>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2d279fc250>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2d279fc250>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2d279fc250>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:From <ipython-input-8-da976005959c>:195: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d28575a50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d28575a50>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d28575a50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d28575a50>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d28402bd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d28402bd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d28402bd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d28402bd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d285ddb10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d285ddb10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d285ddb10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d285ddb10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d276ae0d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d276ae0d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d276ae0d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d276ae0d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2d2809afd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2d2809afd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2d2809afd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2d2809afd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:From /misc/scratch05/patx/fathanab/Experiments_RL/normalizeFirstDay_seed_corrected_2019_11_21_shuffled_GBM_version/helper.py:92: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# Loading Model...
# WARNING:tensorflow:From /misc/home/reco/fathanab/anaconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /misc/scratch05/patx/fathanab/Experiments_RL/normalizeFirstDay_seed_corrected_2019_11_21_shuffled_GBM_version/savedModel/C51_noSoft_arch0-option_T50-history_t15-num_episodes203400-softUpdateFalse-tau0.001-dropout0.19999999999999996True-num_layers3-freq30-batch64-capacity3000-lambda0.0025-final
# episode 100: 	0.02915856765749533	17.08
# episode 200: 	0.021251399800669483	15.85
# episode 300: 	0.03257842247876296	19.24
# episode 400: 	0.019373009751968914	11.5
# episode 500: 	0.022714464845044836	15.8
# episode 600: 	0.021849189870762897	15.33
# episode 700: 	0.029037345077279782	19.0
# episode 800: 	0.022857443601916837	15.0
# episode 900: 	0.02429519087924821	15.52
# episode 1000: 	0.022973496319197106	16.14
# episode 1100: 	0.024700228171487003	16.38
# episode 1200: 	0.027679282926394745	15.25
# episode 1300: 	0.027499718436610275	18.85
# episode 1400: 	0.025570895031619405	16.67
# episode 1500: 	0.029160527810662095	15.96
# episode 1600: 	0.026340548847427484	15.76
# episode 1700: 	0.024443898280037697	17.18
# episode 1800: 	0.023811625070466424	14.5
# episode 1900: 	0.026204479462149897	17.45
# episode 2000: 	0.024348239811975144	15.37
# episode 2100: 	0.03027376639276545	17.89
# episode 2200: 	0.03394743889914129	17.56
# episode 2300: 	0.024689639283510312	15.17
# episode 2400: 	0.023628851913932793	16.96
# episode 2500: 	0.028032526661248464	16.63
# episode 2600: 	0.027839342886367757	17.4
# episode 2700: 	0.026886100509260758	21.15
# episode 2800: 	0.027880266353709313	20.89
# episode 2900: 	0.02055448660051554	15.37
# episode 3000: 	0.023567871793208045	16.04
# episode 3100: 	0.020219805772940247	17.19
# episode 3200: 	0.02389431207821765	17.34
# episode 3300: 	0.030052882510570377	17.19
# episode 3400: 	0.027459554753182614	17.54
# episode 3500: 	0.025484214455010413	17.73
# episode 3600: 	0.02161533214183788	15.08
# episode 3700: 	0.031297950330468914	18.86
# episode 3800: 	0.021192390601504876	13.44
# episode 3900: 	0.02263340152085341	17.48
# episode 4000: 	0.02420278480171789	18.77
# episode 4100: 	0.02150841889720689	13.83
# episode 4200: 	0.022713852807844236	14.74
# episode 4300: 	0.018810469327581313	15.32
# episode 4400: 	0.019425411220036087	11.53
# episode 4500: 	0.024900251812304475	17.53
# episode 4600: 	0.02721245938771141	19.51
# episode 4700: 	0.031039238373756457	21.65
# episode 4800: 	0.027024152069365714	18.66
# episode 4900: 	0.029472390168340152	19.09
# episode 5000: 	0.024247553874034895	15.7
# #Average reward per episode 5000: 0.02535110184658644
# episode 5100: 	0.024810790055145436	17.03
# episode 5200: 	0.017806731978462415	13.04
# episode 5300: 	0.02383074371994891	15.43
# episode 5400: 	0.02956246383381453	18.28
# episode 5500: 	0.025676484293482512	16.59
# episode 5600: 	0.02626245998893541	16.65
# episode 5700: 	0.025127612597001622	17.26
# episode 5800: 	0.02392438506517208	16.82
# episode 5900: 	0.029991838842546203	19.46
# episode 6000: 	0.026805136395726376	18.12
# episode 6100: 	0.02552227649933998	15.76
# episode 6200: 	0.02988498465536918	18.19
# episode 6300: 	0.02612213049602243	18.18
# episode 6400: 	0.029142362627396275	17.0
# episode 6500: 	0.029585558611109196	16.38
# episode 6600: 	0.029726212912759228	16.91
# episode 6700: 	0.0298566956528018	16.94
# episode 6800: 	0.027121129644939828	15.91
# episode 6900: 	0.02365450238164603	15.93
# episode 7000: 	0.031700728831011306	17.62
# episode 7100: 	0.029160931563604522	16.93
# episode 7200: 	0.02608695208248868	18.06
# episode 7300: 	0.0243551322321262	15.76
# episode 7400: 	0.020518134751083186	17.09
# episode 7500: 	0.02671308755423469	14.03
# episode 7600: 	0.019438429074149947	14.82
# episode 7700: 	0.02201358182008988	14.21
# episode 7800: 	0.024266183142636136	16.78
# episode 7900: 	0.028699060818802913	17.31
# episode 8000: 	0.02048263689046774	13.85
# episode 8100: 	0.022161003701630797	14.89
# episode 8200: 	0.02471769399298085	18.48
# episode 8300: 	0.02703388981526073	16.2
# episode 8400: 	0.027946094318679768	18.14
# episode 8500: 	0.02655957442565047	14.19
# episode 8600: 	0.025582620446339223	17.49
# episode 8700: 	0.026019536542096905	15.76
# episode 8800: 	0.03015962663813305	17.38
# episode 8900: 	0.02351394513619498	16.12
# episode 9000: 	0.027719828862492513	16.3
# episode 9100: 	0.027299463478766075	17.83
# episode 9200: 	0.029613843142888573	17.8
# episode 9300: 	0.02857627152263972	17.08
# episode 9400: 	0.030984342843189853	19.57
# episode 9500: 	0.0180337628950982	14.72
# episode 9600: 	0.03514851952321459	18.76
# episode 9700: 	0.026738419578936523	14.99
# episode 9800: 	0.02250331630245956	14.8
# episode 9900: 	0.028403945601061548	18.85
# episode 10000: 	0.02529856111551916	16.1
# #Average reward per episode 10000: 0.025794187112248672
# episode 10100: 	0.025423609052227118	17.12
# episode 10200: 	0.03248191942349644	18.23
# episode 10300: 	0.026879541434171185	17.37
# episode 10400: 	0.02594318826879571	16.88
# episode 10500: 	0.021747019282073437	14.87
# episode 10600: 	0.03313646105922735	19.07
# episode 10700: 	0.023499047931024065	17.36
# episode 10800: 	0.026577171106662422	15.89
# episode 10900: 	0.028017331116894015	19.54
# episode 11000: 	0.030230547428298817	16.93
# episode 11100: 	0.02092169552628871	13.84
# episode 11200: 	0.026848291430835	16.9
# episode 11300: 	0.02830240971379577	15.66
# episode 11400: 	0.03324414485496069	21.84
# episode 11500: 	0.03651657000375529	19.23
# episode 11600: 	0.023457523997931436	17.28
# episode 11700: 	0.029144561797151077	18.37
# episode 11800: 	0.028945542935582488	17.29
# episode 11900: 	0.032370769654737876	18.84
# episode 12000: 	0.025694660235124768	15.8
# episode 12100: 	0.026180718984525803	16.96
# episode 12200: 	0.0231377128640244	15.76
# episode 12300: 	0.03158564718400824	17.85
# episode 12400: 	0.02725153604283633	15.47
# episode 12500: 	0.0328419543094919	19.21
# episode 12600: 	0.029270817941634424	17.66
# episode 12700: 	0.034295532786692	19.67
# episode 12800: 	0.027589944312318565	16.39
# episode 12900: 	0.028794153422229896	15.46
# episode 13000: 	0.02366878024665435	14.43
# episode 13100: 	0.026435385185401214	15.06
# episode 13200: 	0.025753231783118197	14.75
# episode 13300: 	0.029897103704029374	19.67
# episode 13400: 	0.03223379568046228	20.58
# episode 13500: 	0.02735234001765255	19.2
# episode 13600: 	0.028897327515866662	15.39
# episode 13700: 	0.019385888106066954	13.86
# episode 13800: 	0.03265855048651106	16.47
# episode 13900: 	0.026684742599989444	16.84
# episode 14000: 	0.026128446098099736	16.5
# episode 14100: 	0.02230590136663624	17.69
# episode 14200: 	0.023537319707915064	16.28
# episode 14300: 	0.027512262684562732	16.08
# episode 14400: 	0.024733944175812202	16.2
# episode 14500: 	0.027202997326125255	17.45
# episode 14600: 	0.03592861565076786	17.79
# episode 14700: 	0.03269575293333471	18.55
# episode 14800: 	0.02587177761720544	15.08
# episode 14900: 	0.026044586429617794	17.47
# episode 15000: 	0.028574102104119987	16.57
# #Average reward per episode 15000: 0.026488343911637287
# episode 15100: 	0.023140539082851984	12.8
# episode 15200: 	0.028017293317473876	17.18
# episode 15300: 	0.02967110358686411	16.96
# episode 15400: 	0.020435739192839253	17.4
# episode 15500: 	0.025506680264714077	17.42
# episode 15600: 	0.02776267181638167	18.63
# episode 15700: 	0.029852174298600605	19.17
# episode 15800: 	0.03178195408750698	18.25
# episode 15900: 	0.029644280844492804	18.23
# episode 16000: 	0.025413814706615603	16.07
# episode 16100: 	0.026174447071624148	16.36
# episode 16200: 	0.03359224199438383	19.89
# episode 16300: 	0.02748824018753138	19.67
# episode 16400: 	0.024801013412062735	17.83
# episode 16500: 	0.026657142563221582	17.39
# episode 16600: 	0.02671154425535898	16.62
# episode 16700: 	0.023547350081934145	16.63
# episode 16800: 	0.023840460384300512	15.5
# episode 16900: 	0.029645216490021456	17.59
# episode 17000: 	0.028728894434222704	17.17
# episode 17100: 	0.023941934937050196	17.23
# episode 17200: 	0.026130233778320914	17.67
# episode 17300: 	0.022249683408960053	14.03
# episode 17400: 	0.025427619932374492	17.29
# episode 17500: 	0.02676454901041005	15.38
# episode 17600: 	0.02855737676390867	16.05
# episode 17700: 	0.0301651491533827	17.68
# episode 17800: 	0.030464468946057276	18.22
# episode 17900: 	0.032899735055916805	17.64
# episode 18000: 	0.029722545982277256	17.74
# episode 18100: 	0.025736994547679283	15.31
# episode 18200: 	0.025607847667568934	14.5
# episode 18300: 	0.0319605287195284	17.9
# episode 18400: 	0.029760568882412075	16.83
# episode 18500: 	0.032533163785266515	19.65
# episode 18600: 	0.028452214969716647	17.04
# episode 18700: 	0.022392123718670564	14.25
# episode 18800: 	0.023606172360314922	13.26
# episode 18900: 	0.030538118275559092	17.16
# episode 19000: 	0.025386889396612215	16.09
# episode 19100: 	0.023641375971518292	15.82
# episode 19200: 	0.02749833630028513	17.73
# episode 19300: 	0.023987786965047286	16.22
# episode 19400: 	0.029961064377767386	16.82
# episode 19500: 	0.03067348517003186	17.52
# episode 19600: 	0.028796536115605367	17.63
# episode 19700: 	0.029212081880832828	17.18
# episode 19800: 	0.02972347393984868	19.52
# episode 19900: 	0.0244367632398529	17.24
# episode 20000: 	0.02459844902340915	17.32
# #Average reward per episode 20000: 0.026702458305473898
# episode 20100: 	0.021412548282354348	15.05
# episode 20200: 	0.029675868540785365	17.01
# episode 20300: 	0.027419086397660764	15.51
# episode 20400: 	0.020671137619421437	14.23
# episode 20500: 	0.02373966901066817	17.56
# episode 20600: 	0.02810436339528945	17.23
# episode 20700: 	0.024502206551327985	16.36
# episode 20800: 	0.026760424002113887	15.57
# episode 20900: 	0.032635212021629514	19.12
# episode 21000: 	0.030827947132658715	19.23
# episode 21100: 	0.029803152885908825	15.88
# episode 21200: 	0.027050013211780848	16.71
# episode 21300: 	0.01932891210610857	15.02
# episode 21400: 	0.027485921948027955	17.57
# episode 21500: 	0.023696335824675917	17.26
# episode 21600: 	0.02327302775301286	14.81
# episode 21700: 	0.02899920604386733	18.43
# episode 21800: 	0.029531926320347048	17.06
# episode 21900: 	0.025840297489418185	18.15
# episode 22000: 	0.029409947187533356	15.78
# episode 22100: 	0.02884805546980086	18.46
# episode 22200: 	0.028791538352495625	18.54
# episode 22300: 	0.025661908407654407	16.69
# episode 22400: 	0.029468213267081236	16.14
# episode 22500: 	0.021093993284837128	13.4
# episode 22600: 	0.018386551617436332	14.89
# episode 22700: 	0.025898404142641784	15.65
# episode 22800: 	0.023207038537572774	16.77
# episode 22900: 	0.027441445085817407	19.66
# episode 23000: 	0.024141024892268704	15.28
# episode 23100: 	0.03289019368245507	20.44
# episode 23200: 	0.03207526285407932	20.51
# episode 23300: 	0.021163730445479985	14.0
# episode 23400: 	0.03003234007424314	19.93
# episode 23500: 	0.020439847393468432	15.27
# episode 23600: 	0.029349328580214246	17.93
# episode 23700: 	0.027300214543586842	18.02
# episode 23800: 	0.024008930775651426	14.9
# episode 23900: 	0.029112157502599857	18.43
# episode 24000: 	0.020740738590127362	13.16
# episode 24100: 	0.02894928174250899	18.78
# episode 24200: 	0.02269250296220669	16.29
# episode 24300: 	0.026743205677249002	17.19
# episode 24400: 	0.031175079460708154	20.1
# episode 24500: 	0.025929264856015398	14.32
# episode 24600: 	0.03113916698778751	19.15
# episode 24700: 	0.03288434112102272	18.59
# episode 24800: 	0.02619670334666987	16.91
# episode 24900: 	0.02576501722281791	17.57
# episode 25000: 	0.025338123053255716	16.98
# #Average reward per episode 25000: 0.026670089874996406
# episode 25100: 	0.021135321894912212	17.37
# episode 25200: 	0.027652335037814505	17.75
# episode 25300: 	0.026156343525445755	16.42
# episode 25400: 	0.034987923418506976	19.04
# episode 25500: 	0.026422018844229317	15.58
# episode 25600: 	0.026547540576455746	15.94
# episode 25700: 	0.025784869686443584	17.56
# episode 25800: 	0.023433465174600286	16.01
# episode 25900: 	0.02365105882721533	14.28
# episode 26000: 	0.030238825098011336	18.01
# episode 26100: 	0.024573203034508148	16.71
# episode 26200: 	0.024346791559708102	16.41
# episode 26300: 	0.02293529040851023	17.12
# episode 26400: 	0.02892820385352819	17.87
# episode 26500: 	0.034987690245785144	18.52
# episode 26600: 	0.0324401688119159	17.12
# episode 26700: 	0.026819265102058634	13.58
# episode 26800: 	0.036826021609973086	21.24
# episode 26900: 	0.02277978571083243	13.99
# episode 27000: 	0.023751887223973086	15.61
# episode 27100: 	0.023902529766257466	16.76
# episode 27200: 	0.024054758698501842	16.1
# episode 27300: 	0.022768648709164663	15.67
# episode 27400: 	0.02364394266985466	16.88
# episode 27500: 	0.03440779271515419	19.78
# episode 27600: 	0.033479106371099195	19.32
# episode 27700: 	0.026197245215741648	17.63
# episode 27800: 	0.030100501121113135	16.88
# episode 27900: 	0.026964839361703036	16.25
# episode 28000: 	0.030444133405367998	19.49
# episode 28100: 	0.028524043510038184	18.5
# episode 28200: 	0.025760055854726557	16.49
# episode 28300: 	0.028129158118640685	15.65
# episode 28400: 	0.026467263426207262	16.6
# episode 28500: 	0.029931617997281813	17.96
# episode 28600: 	0.027229521952152416	18.2
# episode 28700: 	0.02396599694553363	15.83
# episode 28800: 	0.024405715921055622	14.87
# episode 28900: 	0.026183336396976977	16.73
# episode 29000: 	0.024844688077453256	14.26
# episode 29100: 	0.025260130384650862	18.3
# episode 29200: 	0.03449016133509549	20.06
# episode 29300: 	0.023775898088593504	16.82
# episode 29400: 	0.029945701037335765	18.09
# episode 29500: 	0.025768639415319813	16.09
# episode 29600: 	0.02433715676197553	14.72
# episode 29700: 	0.026224188872865404	16.85
# episode 29800: 	0.02395533259960378	15.61
# episode 29900: 	0.028298307226631333	17.71
# episode 30000: 	0.02525078702128086	14.4
# #Average reward per episode 30000: 0.026735438924569716
# episode 30100: 	0.030450936944404636	17.84
# episode 30200: 	0.025154096451005793	16.12
# episode 30300: 	0.026374642658773026	14.79
# episode 30400: 	0.0240745163261274	15.15
# episode 30500: 	0.028524635379163256	18.42
# episode 30600: 	0.021679796659297666	14.7
# episode 30700: 	0.030715742188273026	18.18
# episode 30800: 	0.02854378655460707	17.7
# episode 30900: 	0.02657562370149102	15.12
# episode 31000: 	0.023139103677946044	15.24
# episode 31100: 	0.026744714820018767	18.91
# episode 31200: 	0.020671416133505996	13.68
# episode 31300: 	0.02663799910547455	18.81
# episode 31400: 	0.026784330954721377	15.63
# episode 31500: 	0.025376712574921773	15.23
# episode 31600: 	0.024594277142576792	17.04
# episode 31700: 	0.020202105724287024	14.32
# episode 31800: 	0.025184142785752997	14.95
# episode 31900: 	0.02574807821409086	16.74
# episode 32000: 	0.027476091106950866	17.79
# episode 32100: 	0.025825253492495422	17.13
# episode 32200: 	0.025734120314850766	17.8
# episode 32300: 	0.023938924040858713	15.92
# episode 32400: 	0.027161319168137	17.72
# episode 32500: 	0.025906600300011007	18.16
# episode 32600: 	0.02932458606395792	17.26
# episode 32700: 	0.029391456319632882	17.74
# episode 32800: 	0.024594327785689672	16.83
# episode 32900: 	0.023463219016547396	17.7
# episode 33000: 	0.025882851173790716	16.53
# episode 33100: 	0.03011827996354872	20.33
# episode 33200: 	0.024930398004933838	17.03
# episode 33300: 	0.02297764027046788	14.49
# episode 33400: 	0.030625363580502843	17.03
# episode 33500: 	0.02557957181429422	17.72
# episode 33600: 	0.025537190418130136	16.65
# episode 33700: 	0.025770181188714734	16.31
# episode 33800: 	0.030083517844786987	17.32
# episode 33900: 	0.02934384657730005	17.43
# episode 34000: 	0.024857187113961628	16.74
# episode 34100: 	0.029202152955848194	16.72
# episode 34200: 	0.02377849935953488	15.18
# episode 34300: 	0.02869670820115926	18.15
# episode 34400: 	0.03084611517487611	15.19
# episode 34500: 	0.02486548974367242	16.81
# episode 34600: 	0.03256788079670267	18.91
# episode 34700: 	0.02296299145777724	15.64
# episode 34800: 	0.02104066551737389	15.14
# episode 34900: 	0.02561449404551267	17.7
# episode 35000: 	0.03189167033249838	18.81
# #Average reward per episode 35000: 0.02667941979574821
# episode 35100: 	0.02303027161236223	13.26
# episode 35200: 	0.028396486831868063	18.65
# episode 35300: 	0.03025570569491397	16.05
# episode 35400: 	0.02635003603121223	16.77
# episode 35500: 	0.027630752971831027	16.71
# episode 35600: 	0.02192079739141546	12.74
# episode 35700: 	0.02793702158832685	17.3
# episode 35800: 	0.022114271428039234	14.6
# episode 35900: 	0.02510177816425653	15.76
# episode 36000: 	0.020779302170882943	13.5
# episode 36100: 	0.02416629839110875	13.52
# episode 36200: 	0.03140684846726633	16.87
# episode 36300: 	0.022567268832300397	13.9
# episode 36400: 	0.03153558946724072	19.88
# episode 36500: 	0.023768606498606838	19.76
# episode 36600: 	0.027114657740176053	15.96
# episode 36700: 	0.025761163224534853	16.55
# episode 36800: 	0.025575334380924648	18.0
# episode 36900: 	0.027208311494132983	18.15
# episode 37000: 	0.031477419710873915	18.75
# episode 37100: 	0.025245165008959097	17.12
# episode 37200: 	0.023872412341108637	12.91
# episode 37300: 	0.028974921641230042	15.66
# episode 37400: 	0.025401091766864236	16.63
# episode 37500: 	0.026073953644085813	16.78
# episode 37600: 	0.022156588343762867	15.4
# episode 37700: 	0.02693453214873509	17.62
# episode 37800: 	0.026921740784071276	17.83
# episode 37900: 	0.02065442200389126	15.44
# episode 38000: 	0.027314578164406113	18.41
# episode 38100: 	0.023952969998870942	16.73
# episode 38200: 	0.027370293204940083	15.63
# episode 38300: 	0.020512837198693446	16.6
# episode 38400: 	0.025353187914017146	17.88
# episode 38500: 	0.023150613874912206	15.4
# episode 38600: 	0.025627538923045624	15.53
# episode 38700: 	0.030529712359385917	17.89
# episode 38800: 	0.029580269015931075	17.1
# episode 38900: 	0.026272171440081288	16.06
# episode 39000: 	0.027062545100483178	16.42
# episode 39100: 	0.02500977348876849	16.02
# episode 39200: 	0.024512557654941737	16.44
# episode 39300: 	0.025763696085397553	17.45
# episode 39400: 	0.02770549012683397	19.36
# episode 39500: 	0.026102458728729423	15.77
# episode 39600: 	0.026971466984378075	17.68
# episode 39700: 	0.02463428143451849	14.87
# episode 39800: 	0.025887121616398744	16.9
# episode 39900: 	0.02066160515193832	13.7
# episode 40000: 	0.024288424213825658	14.43
# #Average reward per episode 40000: 0.026565983177418453
# episode 40100: 	0.02613254286747675	16.31
# episode 40200: 	0.023780222694043916	16.89
# episode 40300: 	0.023090430092287947	18.24
# episode 40400: 	0.026486067250498523	17.16
# episode 40500: 	0.02763230673162473	16.56
# episode 40600: 	0.0237877101216727	16.62
# episode 40700: 	0.021588996644366774	16.37
# episode 40800: 	0.027748607624405147	15.48
# episode 40900: 	0.026129133691708703	17.76
# episode 41000: 	0.026357276236544474	17.45
# episode 41100: 	0.024384872606506867	15.83
# episode 41200: 	0.030857609362623616	18.25
# episode 41300: 	0.02150152387534115	14.69
# episode 41400: 	0.031895714894318535	16.37
# episode 41500: 	0.024621236297877422	14.48
# episode 41600: 	0.02272285793119051	13.77
# episode 41700: 	0.02724785714897319	18.35
# episode 41800: 	0.025296202078899245	17.65
# episode 41900: 	0.027881608892846153	14.3
# episode 42000: 	0.02561302867842552	16.29
# episode 42100: 	0.029440336809314266	18.64
# episode 42200: 	0.02418094669012351	14.09
# episode 42300: 	0.03224122682905557	19.66
# episode 42400: 	0.03038961444147551	19.02
# episode 42500: 	0.031207518761439932	18.37
# episode 42600: 	0.026427413080758005	18.92
# episode 42700: 	0.025398501596714054	18.35
# episode 42800: 	0.024346695568125024	16.34
# episode 42900: 	0.035321267961347394	20.3
# episode 43000: 	0.035021716521958096	19.75
# episode 43100: 	0.028714386401027765	18.57
# episode 43200: 	0.0242029121404747	16.09
# episode 43300: 	0.028230908115987035	18.45
# episode 43400: 	0.02639983381121651	16.45
# episode 43500: 	0.022543136895703024	15.6
# episode 43600: 	0.028175200860957806	17.62
# episode 43700: 	0.02470590583736254	14.8
# episode 43800: 	0.023208826796967407	17.95
# episode 43900: 	0.02710093242405314	18.27
# episode 44000: 	0.030856643404942766	16.45
# episode 44100: 	0.035639346793157	18.46
# episode 44200: 	0.033786372742040584	19.85
# episode 44300: 	0.021575004925747866	14.89
# episode 44400: 	0.028696557587057633	17.07
# episode 44500: 	0.029097021560757125	17.91
# episode 44600: 	0.032078727430899824	16.04
# episode 44700: 	0.030960788767652625	20.14
# episode 44800: 	0.02386929113369041	14.18
# episode 44900: 	0.026623466083600333	19.27
# episode 45000: 	0.02277385631608082	17.0
# #Average reward per episode 45000: 0.026631918744397114
# episode 45100: 	0.03010900630414661	16.48
# episode 45200: 	0.023991729097663925	16.51
# episode 45300: 	0.027750360967742048	17.0
# episode 45400: 	0.031074993179005975	17.62
# episode 45500: 	0.02086909775539265	14.42
# episode 45600: 	0.029859099780469755	18.0
# episode 45700: 	0.03184604138317768	16.46
# episode 45800: 	0.0269249514836304	16.03
# episode 45900: 	0.03034155552814119	18.79
# episode 46000: 	0.027519996489968862	17.15
# episode 46100: 	0.02797231760365999	17.57
# episode 46200: 	0.026056263838261994	15.6
# episode 46300: 	0.027185040483177124	16.11
# episode 46400: 	0.030255936935064218	16.5
# episode 46500: 	0.02393554022689978	15.23
# episode 46600: 	0.027867368082164706	16.56
# episode 46700: 	0.027161426970927174	16.61
# episode 46800: 	0.027767525085266573	18.74
# episode 46900: 	0.028491144466389846	16.18
# episode 47000: 	0.03479805563856338	21.02
# episode 47100: 	0.02196706840182099	14.49
# episode 47200: 	0.023914200761637763	14.89
# episode 47300: 	0.029662579506247642	18.06
# episode 47400: 	0.03310260100105567	20.24
# episode 47500: 	0.02465695895422403	15.73
# episode 47600: 	0.028046380787348762	18.16
# episode 47700: 	0.025044837471415414	16.31
# episode 47800: 	0.026466252244227873	14.96
# episode 47900: 	0.027096978734574905	18.61
# episode 48000: 	0.02567533956742764	17.73
# episode 48100: 	0.02563584554536344	17.53
# episode 48200: 	0.025415543956307487	15.79
# episode 48300: 	0.025804334748922915	17.03
# episode 48400: 	0.03633250497856603	21.61
# episode 48500: 	0.021316983790158374	14.65
# episode 48600: 	0.021921481336913674	14.4
# episode 48700: 	0.03012181895071951	17.43
# episode 48800: 	0.03294379157154732	14.76
# episode 48900: 	0.021149586129061468	15.4
# episode 49000: 	0.03307282978444495	18.43
# episode 49100: 	0.02623941644362057	15.75
# episode 49200: 	0.02946592744123712	17.51
# episode 49300: 	0.03577874614944156	20.5
# episode 49400: 	0.03277809273585788	17.54
# episode 49500: 	0.02575799146336912	17.71
# episode 49600: 	0.029592196451161224	16.87
# episode 49700: 	0.025729722925573354	16.09
# episode 49800: 	0.028195715164328488	18.49
# episode 49900: 	0.03215194851185008	17.66
# episode 50000: 	0.03335557186091341	20.25
# #Average reward per episode 50000: 0.026769068267295536
# episode 50100: 	0.02894414230501119	15.42
# episode 50200: 	0.0314500555936433	21.39
# episode 50300: 	0.027222466359888203	17.51
# episode 50400: 	0.028528726549278627	16.26
# episode 50500: 	0.026452009665853288	15.63
# episode 50600: 	0.03150931722483502	19.76
# episode 50700: 	0.02487471107472134	17.81
# episode 50800: 	0.020296389188345455	15.34
# episode 50900: 	0.01632400334885969	16.36
# episode 51000: 	0.026101339124025215	15.99
# episode 51100: 	0.025130536693410414	15.24
# episode 51200: 	0.0225258473032075	16.09
# episode 51300: 	0.02532641776046291	19.68
# episode 51400: 	0.024517340811740028	15.28
# episode 51500: 	0.02992104560320056	17.24
# episode 51600: 	0.025598058701693623	15.18
# episode 51700: 	0.02840540621657005	17.9
# episode 51800: 	0.023685612538558408	15.51
# episode 51900: 	0.024587307395962862	15.44
# episode 52000: 	0.033126044041892476	20.59
# episode 52100: 	0.031130200793876996	17.39
# episode 52200: 	0.02697159344064696	16.67
# episode 52300: 	0.027122442522290856	17.66
# episode 52400: 	0.02704562742483732	16.53
# episode 52500: 	0.02356307725003748	14.74
# episode 52600: 	0.03326152497959854	18.8
# episode 52700: 	0.024454290160578172	14.39
# episode 52800: 	0.030479478982083353	17.69
# episode 52900: 	0.02735430658516645	16.39
# episode 53000: 	0.035863189523860924	20.78
# episode 53100: 	0.030312180204245157	18.61
# episode 53200: 	0.022469706049719904	14.75
# episode 53300: 	0.026266765699082265	17.27
# episode 53400: 	0.028407066548994258	18.32
# episode 53500: 	0.029255025339808713	18.68
# episode 53600: 	0.027927354074251426	21.0
# episode 53700: 	0.021453683804217482	14.5
# episode 53800: 	0.01247355180150329	13.54
# episode 53900: 	0.022961162448595637	14.98
# episode 54000: 	0.02602555990019588	18.76
# episode 54100: 	0.025367453694178466	15.98
# episode 54200: 	0.028141944867870795	18.13
# episode 54300: 	0.027803780404596877	17.71
# episode 54400: 	0.02364559104620438	13.94
# episode 54500: 	0.029373165674195303	19.75
# episode 54600: 	0.021749157902768948	12.57
# episode 54700: 	0.027138141491441576	19.05
# episode 54800: 	0.025012224629484096	13.97
# episode 54900: 	0.029966394955224608	16.14
# episode 55000: 	0.025808623684694828	18.12
# #Average reward per episode 55000: 0.026741573049151222
# episode 55100: 	0.029294502115122332	18.67
# episode 55200: 	0.02353843803319424	15.71
# episode 55300: 	0.023974841731133432	16.05
# episode 55400: 	0.024426870676463926	14.23
# episode 55500: 	0.02236773076960745	14.66
# episode 55600: 	0.02674581835505131	17.39
# episode 55700: 	0.022272564039534263	15.35
# episode 55800: 	0.028170517999896016	16.55
# episode 55900: 	0.02771373120944744	16.97
# episode 56000: 	0.028143096543672804	19.99
# episode 56100: 	0.028409406377261113	16.93
# episode 56200: 	0.026703436042972782	19.5
# episode 56300: 	0.016918283894679108	14.56
# episode 56400: 	0.023260007375483026	14.72
# episode 56500: 	0.026501820696281375	16.76
# episode 56600: 	0.029620879765470575	17.73
# episode 56700: 	0.03021517461059108	16.81
# episode 56800: 	0.022921335794523424	13.68
# episode 56900: 	0.022342663893208686	12.88
# episode 57000: 	0.032976699686181866	18.57
# episode 57100: 	0.03249582354299686	18.75
# episode 57200: 	0.028685268097836992	19.11
# episode 57300: 	0.026724223071720666	17.09
# episode 57400: 	0.023389741182429296	17.26
# episode 57500: 	0.02783528031115242	15.33
# episode 57600: 	0.023507680097770066	14.69
# episode 57700: 	0.023979592370664424	17.58
# episode 57800: 	0.02765223324217665	18.66
# episode 57900: 	0.029941594273751527	15.99
# episode 58000: 	0.026260898841889594	17.78
# episode 58100: 	0.022712060000679858	15.33
# episode 58200: 	0.02391305638113279	18.95
# episode 58300: 	0.02591712240641455	16.4
# episode 58400: 	0.025650600576264653	15.6
# episode 58500: 	0.027232135592496758	16.06
# episode 58600: 	0.020741852116241136	14.62
# episode 58700: 	0.014592101548949632	13.83
# episode 58800: 	0.030963333677177195	18.25
# episode 58900: 	0.026990140879143705	18.18
# episode 59000: 	0.0301051594458294	21.4
# episode 59100: 	0.02173412209877254	13.1
# episode 59200: 	0.023750079559213915	20.59
# episode 59300: 	0.029956839254679693	17.31
# episode 59400: 	0.028681786934111376	15.87
# episode 59500: 	0.02421600878162977	15.74
# episode 59600: 	0.033893127955961055	17.6
# episode 59700: 	0.031764901412112176	18.97
# episode 59800: 	0.025082142924391166	15.61
# episode 59900: 	0.027491343933913247	15.81
# episode 60000: 	0.027680235124226224	17.67
# #Average reward per episode 60000: 0.02669653913713117
# episode 60100: 	0.023414944426084685	15.79
# episode 60200: 	0.03852548828614776	19.33
# episode 60300: 	0.026843818354131542	18.1
# episode 60400: 	0.022998350113989496	15.2
# episode 60500: 	0.025163469853990286	13.68
# episode 60600: 	0.024458737666759968	15.75
# episode 60700: 	0.03027470541977094	18.44
# episode 60800: 	0.028027942317310966	18.78
# episode 60900: 	0.030725718243673955	18.79
# episode 61000: 	0.02774248458096875	16.21
# episode 61100: 	0.02143385728967015	14.87
# episode 61200: 	0.02070469301565621	15.69
# episode 61300: 	0.02474683048233243	16.44
# episode 61400: 	0.030269205729334222	17.05
# episode 61500: 	0.029404662087850624	18.61
# episode 61600: 	0.024713645407782453	16.33
# episode 61700: 	0.02610926313878678	18.4
# episode 61800: 	0.028646428116175352	17.19
# episode 61900: 	0.03095827115134343	18.47
# episode 62000: 	0.028491326456904265	15.16
# episode 62100: 	0.0242609968345137	16.59
# episode 62200: 	0.026891935100588748	18.3
# episode 62300: 	0.03176428829105958	18.87
# episode 62400: 	0.02416761837274982	15.79
# episode 62500: 	0.02125050728196707	14.47
# episode 62600: 	0.0329403548420774	20.37
# episode 62700: 	0.02909169906752194	17.36
# episode 62800: 	0.03166739808131317	18.26
# episode 62900: 	0.026312183800343072	16.85
# episode 63000: 	0.020404842499882555	14.55
# episode 63100: 	0.032076887533063224	18.02
# episode 63200: 	0.025191504730677217	17.26
# episode 63300: 	0.030251250691500448	16.45
# episode 63400: 	0.02320786959417718	16.97
# episode 63500: 	0.03141006020650833	18.48
# episode 63600: 	0.029392193422184246	18.34
# episode 63700: 	0.02376140415224481	15.54
# episode 63800: 	0.027256274681049474	18.9
# episode 63900: 	0.022459093420910677	15.13
# episode 64000: 	0.025792782732109353	15.49
# episode 64100: 	0.027104361456475535	17.78
# episode 64200: 	0.025047982493951303	14.74
# episode 64300: 	0.02722930210193987	16.75
# episode 64400: 	0.029385479749969155	19.27
# episode 64500: 	0.024465744114406825	16.33
# episode 64600: 	0.024400314192401518	15.07
# episode 64700: 	0.026958339879627577	13.64
# episode 64800: 	0.024347972407704123	17.39
# episode 64900: 	0.027307773596927917	15.15
# episode 65000: 	0.03239252164196546	18.84
# #Average reward per episode 65000: 0.026722720402137183
# episode 65100: 	0.03497208399343324	18.11
# episode 65200: 	0.029571987245226136	17.57
# episode 65300: 	0.022199786884407116	15.23
# episode 65400: 	0.025406209537495443	16.51
# episode 65500: 	0.02373789277359515	15.97
# episode 65600: 	0.02843954521495624	17.98
# episode 65700: 	0.026591526399356056	15.36
# episode 65800: 	0.028998586710001183	17.58
# episode 65900: 	0.02775564039851923	16.15
# episode 66000: 	0.022924432111835303	15.85
# episode 66100: 	0.026610483098414045	17.46
# episode 66200: 	0.027724632549947472	17.48
# episode 66300: 	0.032597093534864514	17.01
# episode 66400: 	0.02701728934246074	17.65
# episode 66500: 	0.027222091293306706	14.75
# episode 66600: 	0.030192915250671092	16.37
# episode 66700: 	0.02474812747149692	15.47
# episode 66800: 	0.027161279018768893	16.93
# episode 66900: 	0.030124818900625377	15.58
# episode 67000: 	0.024686518615670637	13.66
# episode 67100: 	0.021228542810003127	17.12
# episode 67200: 	0.030821735171096067	16.2
# episode 67300: 	0.030509051656195378	19.75
# episode 67400: 	0.03496309898234494	19.86
# episode 67500: 	0.026755765047165286	15.66
# episode 67600: 	0.024755994113253722	14.39
# episode 67700: 	0.02644508809334456	15.12
# episode 67800: 	0.02366877446666991	14.12
# episode 67900: 	0.021288650582081892	15.26
# episode 68000: 	0.029490050295323655	14.97
# episode 68100: 	0.03127773694763466	17.58
# episode 68200: 	0.027447507271027627	18.66
# episode 68300: 	0.027678300375922484	15.55
# episode 68400: 	0.02787944221651129	16.75
# episode 68500: 	0.024320940929282164	15.34
# episode 68600: 	0.0228538873632727	16.45
# episode 68700: 	0.02895319440619835	16.34
# episode 68800: 	0.024183328192490278	16.58
# episode 68900: 	0.019757258713094354	15.47
# episode 69000: 	0.025515542388711468	18.49
# episode 69100: 	0.02555383992249177	16.81
# episode 69200: 	0.031176065947392397	19.52
# episode 69300: 	0.02078159687777341	16.3
# episode 69400: 	0.029386334703298333	18.29
# episode 69500: 	0.032008269702295596	18.54
# episode 69600: 	0.03002460684065181	16.63
# episode 69700: 	0.023498682982746426	14.97
# episode 69800: 	0.02318527106758657	15.47
# episode 69900: 	0.028557992405418467	17.7
# episode 70000: 	0.020006972479483263	14.41
# #Average reward per episode 70000: 0.026732035320978568
# episode 70100: 	0.028847446729713046	19.89
# episode 70200: 	0.032680375011041346	18.23
# episode 70300: 	0.029032343242544237	17.43
# episode 70400: 	0.029755503729185572	17.81
# episode 70500: 	0.03572728557392141	18.45
# episode 70600: 	0.03336848346985069	20.33
# episode 70700: 	0.02432494186011145	14.8
# episode 70800: 	0.02011622628941348	14.92
# episode 70900: 	0.02437723082924941	14.63
# episode 71000: 	0.03300229220191157	17.47
# episode 71100: 	0.024860988089493014	13.93
# episode 71200: 	0.02224049053429404	15.77
# episode 71300: 	0.023470175731280244	13.79
# episode 71400: 	0.03061477442051114	16.06
# episode 71500: 	0.03037382243650695	20.28
# episode 71600: 	0.025927119462980826	17.73
# episode 71700: 	0.023731283244684778	16.07
# episode 71800: 	0.025343912140654453	14.68
# episode 71900: 	0.02339014433682622	16.22
# episode 72000: 	0.024329348094597116	13.61
# episode 72100: 	0.03102899846306719	17.88
# episode 72200: 	0.023865728377446178	17.45
# episode 72300: 	0.029155395823427174	16.44
# episode 72400: 	0.028107026472082713	16.4
# episode 72500: 	0.029172071470775284	16.44
# episode 72600: 	0.020528734810703116	14.63
# episode 72700: 	0.024106523315269742	15.94
# episode 72800: 	0.0289697094140924	18.62
# episode 72900: 	0.02852328440690382	16.37
# episode 73000: 	0.026369198435763522	15.59
# episode 73100: 	0.024317759120131278	16.17
# episode 73200: 	0.03079945769700904	18.22
# episode 73300: 	0.02700737622929236	16.51
# episode 73400: 	0.027878764792877396	16.77
# episode 73500: 	0.023380726970645846	16.1
# episode 73600: 	0.032818756559028085	17.06
# episode 73700: 	0.022869942066179937	13.88
# episode 73800: 	0.029761809931412985	18.45
# episode 73900: 	0.029104899493957274	17.96
# episode 74000: 	0.027580158884705077	15.67
# episode 74100: 	0.022157402955649167	13.78
# episode 74200: 	0.02621908099770311	16.89
# episode 74300: 	0.026641897086517114	17.51
# episode 74400: 	0.028124293165192982	16.55
# episode 74500: 	0.030871949902707266	18.43
# episode 74600: 	0.01829720631153504	13.25
# episode 74700: 	0.03173777499924332	18.97
# episode 74800: 	0.021690521916875795	13.55
# episode 74900: 	0.025439707527103297	16.13
# episode 75000: 	0.032870649688157005	19.91
# #Average reward per episode 75000: 0.026756447625865647
# episode 75100: 	0.02961451742424492	16.66
# episode 75200: 	0.02271389546778009	16.28
# episode 75300: 	0.026102130113890253	18.45
# episode 75400: 	0.03381720731694307	19.49
# episode 75500: 	0.024785129954085883	17.63
# episode 75600: 	0.02495627105520937	17.35
# episode 75700: 	0.019767215447979467	15.59
# episode 75800: 	0.026757362015792232	15.16
# episode 75900: 	0.02644261258635503	16.09
# episode 76000: 	0.027950913670329043	16.02
# episode 76100: 	0.025392895515340012	16.61
# episode 76200: 	0.02413687935876303	14.97
# episode 76300: 	0.02567890467149191	16.41
# episode 76400: 	0.026926803059806197	18.01
# episode 76500: 	0.032058646020656466	19.2
# episode 76600: 	0.01968452496775719	14.27
# episode 76700: 	0.02083689923234731	16.5
# episode 76800: 	0.022883857554906163	13.97
# episode 76900: 	0.0230142304676115	14.23
# episode 77000: 	0.038491710883779486	18.75
# episode 77100: 	0.025840084901450545	16.16
# episode 77200: 	0.02651508905997403	17.31
# episode 77300: 	0.028521537444496453	16.05
# episode 77400: 	0.028531945728838465	17.36
# episode 77500: 	0.0316878046745239	17.25
# episode 77600: 	0.022965558927536073	16.33
# episode 77700: 	0.025205577614468587	16.46
# episode 77800: 	0.03267710024416923	19.92
# episode 77900: 	0.02445258634912704	17.53
# episode 78000: 	0.026831772046255815	16.3
# episode 78100: 	0.02533220827749251	14.68
# episode 78200: 	0.023513207105041997	15.2
# episode 78300: 	0.02815370184080322	17.1
# episode 78400: 	0.028387899344301405	17.04
# ...
# episode 103800: 	0.02448417850135228	18.02
# episode 103900: 	0.021222246802167576	12.59
# episode 104000: 	0.028287229607084817	17.44
# episode 104100: 	0.02669131389676647	17.64
# episode 104200: 	0.028151182667154453	16.12
# episode 104300: 	0.0233081526670565	16.83
# episode 104400: 	0.022255450478515848	15.87
# episode 104500: 	0.03335532034182906	20.61
# episode 104600: 	0.031849949692948826	20.33
# episode 104700: 	0.030793992789644026	16.91
# episode 104800: 	0.024597335722191364	16.08
# episode 104900: 	0.02725084564537311	16.55
# episode 105000: 	0.028894570688383036	16.89
# #Average reward per episode 105000: 0.026708754420018743
# episode 105100: 	0.022411311774072535	14.88
# episode 105200: 	0.02430009516675381	16.54
# episode 105300: 	0.02202784740337279	15.84
# episode 105400: 	0.02360412739758119	18.11
# episode 105500: 	0.015609139644429384	12.84
# episode 105600: 	0.034786219304333114	18.03
# episode 105700: 	0.027022385308198955	17.1
# episode 105800: 	0.028416131127032434	14.69
# episode 105900: 	0.02050280928019423	12.81
# episode 106000: 	0.029703200182950477	18.02
# episode 106100: 	0.02789444683488855	15.37
# episode 106200: 	0.03024063883443433	17.19
# episode 106300: 	0.02444157570928116	16.94
# episode 106400: 	0.029026368434588577	18.53
# episode 106500: 	0.0337793346403459	19.04
# episode 106600: 	0.02012093962313747	16.19
# episode 106700: 	0.020084260283839816	13.62
# episode 106800: 	0.023965924306081448	16.65
# episode 106900: 	0.020559042251699435	13.69
# episode 107000: 	0.02823916228770805	17.96
# episode 107100: 	0.033242635462503306	18.01
# episode 107200: 	0.024656399028696298	15.53
# episode 107300: 	0.021224597913590264	15.88
# episode 107400: 	0.03142443063772356	17.34
# episode 107500: 	0.023218674260323174	14.96
# episode 107600: 	0.0338479411214269	21.24
# episode 107700: 	0.025456267327809905	13.72
# episode 107800: 	0.023667067567453962	15.29
# episode 107900: 	0.03202162727163843	17.01
# episode 108000: 	0.025957329973087275	16.28
# episode 108100: 	0.028993141087742716	18.35
# episode 108200: 	0.03093254017772727	19.45
# episode 108300: 	0.026079193133905533	17.26
# episode 108400: 	0.022265836195063667	16.28
# episode 108500: 	0.03105952840762216	14.45
# episode 108600: 	0.02672297036559403	16.0
# episode 108700: 	0.030954785357373064	18.4
# episode 108800: 	0.02945402421729313	15.83
# episode 108900: 	0.03337631507607483	19.23
# episode 109000: 	0.02708774887919774	17.26
# episode 109100: 	0.02411973187027162	16.88
# episode 109200: 	0.030565862251683135	17.09
# episode 109300: 	0.025995890822898878	16.82
# episode 109400: 	0.02948021028921125	17.71
# episode 109500: 	0.02761772679349073	18.36
# episode 109600: 	0.02569314067529394	16.66
# episode 109700: 	0.020274876089261186	16.97
# episode 109800: 	0.02052230819554368	15.24
# episode 109900: 	0.028514600232152913	17.16
# episode 110000: 	0.02789209043957306	17.34
# #Average reward per episode 110000: 0.02670295144721432
# episode 110100: 	0.025386018033032295	15.02
# episode 110200: 	0.02439975681012506	17.1
# episode 110300: 	0.026120452189816033	17.75
# episode 110400: 	0.029412255187875255	17.77
# episode 110500: 	0.027914230007611972	16.1
# episode 110600: 	0.030368678619262034	18.68
# episode 110700: 	0.036242360027934704	19.26
# episode 110800: 	0.025230193419497667	16.19
# episode 110900: 	0.025154558992625798	16.62
# episode 111000: 	0.03201943821548522	18.35
# episode 111100: 	0.03397444516490269	19.85
# episode 111200: 	0.02274588336899663	16.16
# episode 111300: 	0.034469948524138615	18.76
# episode 111400: 	0.02805998793201655	18.18
# episode 111500: 	0.03092060081270804	16.7
# episode 111600: 	0.032106120160123756	18.41
# episode 111700: 	0.02369469542328075	14.65
# episode 111800: 	0.024575250463575143	16.11
# episode 111900: 	0.024400027938352848	15.92
# episode 112000: 	0.01949717702804091	13.98
# episode 112100: 	0.019650699913038396	14.57
# episode 112200: 	0.03341373608079286	18.64
# episode 112300: 	0.03417416838409628	16.61
# episode 112400: 	0.03363368971161359	19.19
# episode 112500: 	0.024894078467910315	16.35
# episode 112600: 	0.02464444430090781	15.58
# episode 112700: 	0.024651522686424596	15.55
# episode 112800: 	0.027249773280045218	17.06
# episode 112900: 	0.028320235318252025	17.25
# episode 113000: 	0.028384606280059756	16.75
# episode 113100: 	0.02915522855226812	17.3
# episode 113200: 	0.027645314755486074	17.47
# episode 113300: 	0.02373371776546884	17.15
# episode 113400: 	0.027464103479176917	16.87
# episode 113500: 	0.024647888162301124	17.03
# episode 113600: 	0.024166880469175606	14.49
# episode 113700: 	0.026771461199188832	14.17
# episode 113800: 	0.01860038879076993	13.21
# episode 113900: 	0.02609772694033287	15.73
# episode 114000: 	0.03437254841835844	23.73
# episode 114100: 	0.025810465923155567	17.1
# episode 114200: 	0.021993332391213847	15.92
# episode 114300: 	0.026945346345270724	17.32
# episode 114400: 	0.028224909663643633	17.31
# episode 114500: 	0.020440386856176516	15.38
# episode 114600: 	0.027074317859485778	15.81
# episode 114700: 	0.03264623286952898	17.9
# episode 114800: 	0.024603729593837567	14.59
# episode 114900: 	0.01779961077369554	12.42
# episode 115000: 	0.030600919165796613	15.63
# #Average reward per episode 115000: 0.02671978272578487
# episode 115100: 	0.030445313261762696	19.36
# episode 115200: 	0.023535583852387538	18.3
# episode 115300: 	0.022990320101522653	15.45
# episode 115400: 	0.02480494881672478	15.34
# episode 115500: 	0.02856266679604813	17.97
# episode 115600: 	0.02226683923332116	15.15
# episode 115700: 	0.022868750791244934	16.35
# episode 115800: 	0.023789659630646318	17.13
# episode 115900: 	0.026276686196679156	18.11
# episode 116000: 	0.026709767849338026	15.19
# episode 116100: 	0.024174653636061014	16.6
# episode 116200: 	0.03158461945416909	19.97
# episode 116300: 	0.027130959268745897	18.61
# episode 116400: 	0.02314151193184212	16.84
# episode 116500: 	0.02868296056540603	17.22
# episode 116600: 	0.032601087321377585	18.78
# episode 116700: 	0.028927926892292996	19.04
# episode 116800: 	0.031050544765518214	17.58
# episode 116900: 	0.025008745215587994	18.29
# episode 117000: 	0.025839306110765823	16.73
# episode 117100: 	0.019237871214985394	13.8
# episode 117200: 	0.02476595726429212	16.08
# episode 117300: 	0.02848742876481599	16.76
# episode 117400: 	0.025542787893763786	16.74
# episode 117500: 	0.027068423502660918	17.54
# episode 117600: 	0.02841986459474582	17.2
# episode 117700: 	0.024641401309857883	16.38
# episode 117800: 	0.027193245325000556	18.88
# episode 117900: 	0.023452173486529698	14.97
# episode 118000: 	0.0259620508306536	16.34
# episode 118100: 	0.03113946794155778	15.85
# episode 118200: 	0.031338358555168935	17.85
# episode 118300: 	0.024505526198109476	18.61
# episode 118400: 	0.023365915919373745	18.38
# episode 118500: 	0.03113864225139503	16.96
# episode 118600: 	0.028369453366661742	17.75
# episode 118700: 	0.024174036858412552	15.11
# episode 118800: 	0.025438700476760095	16.56
# episode 118900: 	0.026592193483398637	16.1
# episode 119000: 	0.023038354292837324	16.23
# episode 119100: 	0.0219086193440769	16.18
# episode 119200: 	0.023858137003245947	14.1
# episode 119300: 	0.029968409665144448	18.39
# episode 119400: 	0.028047675296317718	20.67
# episode 119500: 	0.01956614310105393	13.28
# episode 119600: 	0.03310941343248802	19.46
# episode 119700: 	0.028114917876576894	15.24
# episode 119800: 	0.03440791645983777	19.12
# episode 119900: 	0.022117561731138106	13.49
# episode 120000: 	0.02949157921314846	18.05
# #Average reward per episode 120000: 0.026710504344165102
# episode 120100: 	0.027629891372686666	16.86
# episode 120200: 	0.02004868975718062	14.9
# episode 120300: 	0.02393470426265208	15.47
# episode 120400: 	0.030744053304320083	19.49
# episode 120500: 	0.031192352251983236	19.04
# episode 120600: 	0.02430551477226482	14.96
# episode 120700: 	0.01945605077272094	13.78
# episode 120800: 	0.025968294896438194	18.69
# episode 120900: 	0.024309878667450425	19.6
# episode 121000: 	0.030614818959495697	18.02
# episode 121100: 	0.022211018656077143	14.48
# episode 121200: 	0.024846862558460567	15.23
# episode 121300: 	0.023683327623807236	13.42
# episode 121400: 	0.02153229821074638	15.47
# episode 121500: 	0.02571284156865536	15.99
# episode 121600: 	0.03170187264122785	18.55
# episode 121700: 	0.02756688851899439	15.46
# episode 121800: 	0.029540356444184745	16.36
# episode 121900: 	0.026259838883858667	17.53
# episode 122000: 	0.025428900273586262	16.3
# episode 122100: 	0.025970228662214007	16.06
# episode 122200: 	0.030319755584731423	17.43
# episode 122300: 	0.02653125504431388	16.68
# episode 122400: 	0.024684911284962256	15.75
# episode 122500: 	0.026343664494952967	19.65
# episode 122600: 	0.0250775104531286	15.05
# episode 122700: 	0.026224471032310178	18.33
# episode 122800: 	0.02710526510593576	17.44
# episode 122900: 	0.025676118705203116	16.55
# episode 123000: 	0.027724874558773604	16.76
# episode 123100: 	0.020860316879462618	15.6
# episode 123200: 	0.030659834665488477	16.81
# episode 123300: 	0.028441821015066423	16.13
# episode 123400: 	0.03265025450321132	16.84
# episode 123500: 	0.02262432889349721	14.29
# episode 123600: 	0.024172353579884523	15.25
# episode 123700: 	0.026122926555871038	15.17
# episode 123800: 	0.028324582490917134	19.93
# episode 123900: 	0.028590711800640153	17.77
# episode 124000: 	0.028039828721270733	17.06
# episode 124100: 	0.029204875927505872	17.15
# episode 124200: 	0.03125052461768102	17.32
# episode 124300: 	0.027007703731614784	18.52
# episode 124400: 	0.022814826625420698	18.13
# episode 124500: 	0.03157734684750167	17.37
# episode 124600: 	0.023827983730898946	14.63
# episode 124700: 	0.02966058294925367	18.24
# episode 124800: 	0.021624486226023882	18.27
# episode 124900: 	0.025862793452408227	16.63
# episode 125000: 	0.024475501809018127	14.24
# #Average reward per episode 125000: 0.026698196245875223
# episode 125100: 	0.02690329899379629	15.44
# episode 125200: 	0.03520257633916024	21.23
# episode 125300: 	0.03154562599788932	18.07
# episode 125400: 	0.027893654790913266	18.85
# episode 125500: 	0.02699334323359888	17.68
# episode 125600: 	0.024610782437618127	16.88
# episode 125700: 	0.024919574062481405	16.85
# episode 125800: 	0.02632910233902494	14.88
# episode 125900: 	0.032049955881911056	16.77
# episode 126000: 	0.0320268932949896	16.96
# episode 126100: 	0.022127730532386904	15.7
# episode 126200: 	0.028151644620548522	16.24
# episode 126300: 	0.0261435410498872	17.03
# episode 126400: 	0.027665083297435417	15.77
# episode 126500: 	0.029407410205260255	16.69
# episode 126600: 	0.0301316642272995	15.29
# episode 126700: 	0.028631908475555825	18.84
# episode 126800: 	0.030986213564394634	17.61
# episode 126900: 	0.02919244371757483	16.37
# episode 127000: 	0.023561199715391314	17.82
# episode 127100: 	0.022241430056541747	16.54
# episode 127200: 	0.025223263752845382	14.68
# episode 127300: 	0.026542486992206252	18.08
# episode 127400: 	0.02159762424498852	15.73
# episode 127500: 	0.03182540295129379	18.17
# episode 127600: 	0.026173381147915876	17.16
# episode 127700: 	0.022016092676759285	12.93
# episode 127800: 	0.02046203448994739	15.07
# episode 127900: 	0.03273503365004518	18.4
# episode 128000: 	0.03488614374716534	16.39
# episode 128100: 	0.019212155117737408	15.63
# episode 128200: 	0.023340999110656676	14.63
# episode 128300: 	0.028521744626812468	18.2
# episode 128400: 	0.030179944872741993	17.74
# episode 128500: 	0.019548344024338072	15.32
# episode 128600: 	0.03299150665636249	18.54
# episode 128700: 	0.029025491850134415	17.26
# episode 128800: 	0.017483724857599758	13.63
# episode 128900: 	0.024159093115475417	15.83
# episode 129000: 	0.031931653245122794	17.64
# episode 129100: 	0.028979256591222472	18.22
# episode 129200: 	0.02503683209746381	15.79
# episode 129300: 	0.022371170875842464	13.79
# episode 129400: 	0.0234842841912733	15.01
# episode 129500: 	0.026521510553274345	18.86
# episode 129600: 	0.03300632471728903	18.13
# episode 129700: 	0.029697121337112317	17.3
# episode 129800: 	0.02883574560183694	16.85
# episode 129900: 	0.025255139928055365	16.8
# episode 130000: 	0.03110342393474798	17.93
# #Average reward per episode 130000: 0.026716621011643023
# episode 130100: 	0.03496846325985448	16.96
# episode 130200: 	0.02949593403469935	17.38
# episode 130300: 	0.022960196076692276	18.88
# episode 130400: 	0.02802055964088782	19.46
# episode 130500: 	0.034627901427789584	19.73
# episode 130600: 	0.03126368955939593	17.9
# episode 130700: 	0.03427002009434165	19.38
# episode 130800: 	0.029656233948110903	17.76
# episode 130900: 	0.031065781215777834	21.75
# episode 131000: 	0.02847416576654017	18.6
# episode 131100: 	0.03092088125664921	17.86
# episode 131200: 	0.028580295732412185	19.09
# episode 131300: 	0.025442421599698048	16.97
# episode 131400: 	0.028260381995324598	18.52
# episode 131500: 	0.025506243750080336	18.09
# episode 131600: 	0.027382928094867812	19.39
# episode 131700: 	0.019129968111475788	13.1
# episode 131800: 	0.02536327272523675	19.23
# episode 131900: 	0.024182593429105895	17.1
# episode 132000: 	0.031047206467667354	19.09
# episode 132100: 	0.026674279731513737	15.89
# episode 132200: 	0.027952864442982898	17.09
# episode 132300: 	0.030144710002649774	18.49
# episode 132400: 	0.024252627110702717	14.75
# episode 132500: 	0.020735316538026512	14.32
# episode 132600: 	0.02735275541446019	15.92
# episode 132700: 	0.02384825414930525	14.59
# episode 132800: 	0.02285028841642169	16.95
# episode 132900: 	0.034134153084693024	18.84
# episode 133000: 	0.023914105949275757	16.44
# episode 133100: 	0.027577552847653442	16.15
# episode 133200: 	0.032014521737791506	18.8
# episode 133300: 	0.02597163365751141	16.66
# episode 133400: 	0.027704868495992175	15.85
# episode 133500: 	0.026673278767351163	18.36
# episode 133600: 	0.02604719988374125	18.86
# episode 133700: 	0.022680640290650443	17.48
# episode 133800: 	0.029647459482122232	17.48
# episode 133900: 	0.026761946630450097	16.8
# episode 134000: 	0.02703317597581252	16.63
# episode 134100: 	0.025896817585483498	17.58
# episode 134200: 	0.023369803395399888	14.75
# episode 134300: 	0.03110217369613171	18.75
# episode 134400: 	0.024109349426037124	14.59
# episode 134500: 	0.02671559653704706	15.5
# episode 134600: 	0.03000528901135411	17.69
# episode 134700: 	0.025958758857957908	18.87
# episode 134800: 	0.025397830806038513	15.37
# episode 134900: 	0.018059442359918982	13.87
# episode 135000: 	0.02736902207511635	16.92
# #Average reward per episode 135000: 0.026736431236801653
# episode 135100: 	0.024466716179647362	14.72
# episode 135200: 	0.028875059111039013	14.84
# episode 135300: 	0.027327045444907144	16.23
# episode 135400: 	0.024959504586854486	18.35
# episode 135500: 	0.02417088871524978	15.95
# episode 135600: 	0.02233330029291393	17.18
# #Total average reward per episode: 0.02673032056343128
# #Max possible average reward per episode: 0.04911317642062675
# #Confidence Interval with prob of 90%: 0.00017282775492510622
# #Confidence Interval with prob of 95%: 0.00020593697191763363
# #Sell time entropy: 1.6377013838361927
# #Percentage of stock returns (Normalized): 0.02912517211584669
# #Percentage of stock returns (Real values): 0.02912517211584669
# #Percentage of option returns (Normalized): 0.10667299763675966
# #Percentage of option returns (Real values): 0.10667299763675953
# #Max possible average stock percentage return per episode: 0.049352553563249135
# #Max possible average real stock percentage return per episode: 0.049352553563249135
# #Max possible average option percentage return per episode: 0.8768120716678929
# #Max possible average real option percentage return per episode: 0.8768120716678925
# #Confidence Interval of Percentage of returns (Normalized) with prob of 90%: 0.00016859144719907787
# #Confidence Interval of Percentage of returns (Normalized) with prob of 95%: 0.00020088909991589635
# #Confidence Interval of Percentage of returns (Real values) with prob of 90%: 0.00016859144719907787
# #Confidence Interval of Percentage of returns (Real values) with prob of 95%: 0.00020088909991589635
# #Confidence Interval of Percentage of option returns (Normalized) with prob of 90%: 0.0065456687345909845
# #Confidence Interval of Percentage of option returns (Normalized) with prob of 95%: 0.007799645369239108
# #Confidence Interval of Percentage of option returns (Real values) with prob of 90%: 0.0065456687345909845
# #Confidence Interval of Percentage of option returns (Real values) with prob of 95%: 0.007799645369239107
# #Time to execute: 399.92822645902635min

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, AvgrList, color='red', label='Episode reward')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward / Ep Length')
plt.legend(loc='best');

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, np.array(AvgrList)*20, color='red', label='Episode reward x20')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward x20 / Ep Length')
plt.legend(loc='best');

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, np.array(AvgrList)*100, color='red', label='Episode reward x100')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward x100 / Ep Length')
plt.legend(loc='best');

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(range(len(sTimeList)), sTimeList, color='blue', label='Sell time')
plt.title('Sell time over time')
plt.xlabel('episodes')
plt.ylabel('Sell time')
plt.legend(loc='best');

# %% [markdown]
# ### Testing the network

# %%
#e = 0.03 #0.01 #The chance of chosing a random action
load_model = True #Whether to load a saved model.
is_training = False

# %%
env = StockEnv(stocks_test_data, real_stocks_test_data, risk_free_rate, history_t=history_t, option_T=option_T)
#max_num_observations = env.max_num_observations
num_batch_episodes_per_epoch = env.get_total_num_episodes_per_epoch() // batch_size
num_episodes = env.get_total_num_episodes_per_epoch()
print('num_batch_episodes_per_epoch: ' + str(num_batch_episodes_per_epoch))
print('num_episodes_per_epoch: ' + str(env.get_total_num_episodes_per_epoch()))
print('min value of stock: '+str(min(test_data)) + ', max value of stock: '+str(max(test_data)))
plt.plot(range(len(test_data)), test_data, color='b')
# Out:
# ###############################
# option_T: 50
# history_t: 15
# build_warm_up_state_t: 12
# ###############################
# num_batch_episodes_per_epoch: 375
# num_episodes_per_epoch: 24000
# min value of stock: 125.64229401508895, max value of stock: 175.81496892998706

# %%
begin_time = time.time()
tf.reset_default_graph()

mainQN = Qnetwork('main')
targetQN = Qnetwork('target')


init = tf.global_variables_initializer()

saver = tf.train.Saver(max_to_keep=2)

myBuffer = experience_buffer()

#create lists to contain total rewards and steps per episode
jList = []
rList = []
sTimeList = [] # sell time list

percentage_rList = []
real_percentage_rList = []

option_percentage_rList = []
option_real_percentage_rList = []

# Average metrics per 100 episodes
AvgEpisodeList = []
AvgrList = []
AvgsTimeList = []
maxPossiblerList = []

maxPossibleP_returnList = []
maxPossibleR_P_returnList = []

maxPossibleOptionP_returnList = []
maxPossibleOptionR_P_returnList = []

#Make a path for our model to be saved in.
if not os.path.exists(path):
    os.makedirs(path) 
  

with tf.Session() as sess, tf.device('/gpu:1'):
    set_seed(seed)
    if load_model == True:
        print ('Loading Model...')
        saver.restore(sess,final_trained_model_name)
    else:
        sess.run(init)
    
    for i in range(num_episodes):
        episodeBuffer = []
        #Reset environment and get first new observation
        sP = env.reset()
        s = processState(sP, input_size)
        d = False
        rAll = 0
        j = 0
        #Reset the recurrent layer's hidden state
        state = np.zeros((num_layers, 2, 1, h_size))
        while j < max_epLength: 

            if j == max_epLength - 1 and env.is_episode_finished() == False:
                a = 1
            else:
                a, state1 = sess.run([mainQN.predict,mainQN.rnn_state],\
                        feed_dict={mainQN.scalarInput:[s],mainQN.trainLength:1,mainQN.state_in:state,mainQN.batch_size:1})
                if env.get_time() < build_warm_up_state_t:
                    a = 0 #hold
                elif env.get_payoff() <= 0:
                    a = 0 #hold
                else:
                    a = a[0]
                
            s1P,r,d = env.step(a)
            
            s1 = processState(s1P, input_size)
            
            episodeBuffer.append(np.reshape(np.array([s,a,r,s1,d]),[1,5])) # store experience

            rAll += r
            s = s1
            sP = s1P
            state = state1
            j+=1 # episode length till selling or reaching last day of option

            if env.is_episode_finished():
                break
        
        myBuffer.add(episodeBuffer)
        jList.append(j)
        rList.append(rAll)
        sTimeList.append(env.get_sell_time() + 1)
        best_reward, stock_percentage_return, option_percentage_return, stock_real_percentage_return,\
        option_real_percentage_return = env.get_best_possible_reward()
        
        maxPossiblerList.append(best_reward)
        maxPossibleP_returnList.append(stock_percentage_return)
        maxPossibleR_P_returnList.append(stock_real_percentage_return)
        maxPossibleOptionP_returnList.append(option_percentage_return)
        maxPossibleOptionR_P_returnList.append(option_real_percentage_return)
        stock_percentage_return, option_percentage_return = env.get_percentage_return()
        percentage_rList.append(stock_percentage_return)
        option_percentage_rList.append(option_percentage_return)
        stock_percentage_return, option_percentage_return = env.get_real_percentage_return()
        real_percentage_rList.append(stock_percentage_return)
        option_real_percentage_rList.append(option_percentage_return)

        #Periodically print metrics. 
        if len(rList) % summaryLength == 0 and len(rList) != 0:
            AvgR = np.mean(rList[-summaryLength:])
            AvgsT = np.mean(sTimeList[-summaryLength:])
            AvgEpisodeList.append(i+1)
            AvgrList.append(AvgR)
            AvgsTimeList.append(AvgsT)
            print('episode ' + str(i+1) + ': \t' + str(AvgR) 
                  + '\t' + str(AvgsT))
            
        if len(rList) % summaryAverageReward == 0 and len(rList) != 0:
            print ("#Average reward per episode " + str(i+1) + ": " + str(sum(rList)/len(rList)))
                
option_percentage_rList = [value for value in option_percentage_rList if not math.isnan(value)]
maxPossibleOptionP_returnList = [value for value in maxPossibleOptionP_returnList if not math.isnan(value)]

print ("#Total average reward per episode: " + str(sum(rList)/num_episodes))

print ("#Max possible average reward per episode: " + str(np.mean(maxPossiblerList)))

print ("#Confidence Interval with prob of 90%: " + str(env.getConfidenceInterval(rList)))

print ("#Confidence Interval with prob of 95%: " + str(env.getConfidenceInterval95(rList)))

print ("#Sell time entropy: " + str(env.getEntropy(sTimeList)))

print ("#Percentage of stock returns (Normalized): " + str(np.mean(percentage_rList)))

print ("#Percentage of stock returns (Real values): " + str(np.mean(real_percentage_rList)))

print ("#Percentage of option returns (Normalized): " + str(np.mean(option_percentage_rList)))

print ("#Percentage of option returns (Real values): " + str(np.mean(option_real_percentage_rList)))

print ("#Max possible average stock percentage return per episode: " + str(np.mean(maxPossibleP_returnList)))

print ("#Max possible average real stock percentage return per episode: " + str(np.mean(maxPossibleR_P_returnList)))

print ("#Max possible average option percentage return per episode: " + str(np.mean(maxPossibleOptionP_returnList)))

print ("#Max possible average real option percentage return per episode: " + str(np.mean(maxPossibleOptionR_P_returnList)))

print ("#Confidence Interval of Percentage of returns (Normalized) with prob of 90%: " + str(env.getConfidenceInterval(percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Normalized) with prob of 95%: " + str(env.getConfidenceInterval95(percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Real values) with prob of 90%: " + str(env.getConfidenceInterval(real_percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Real values) with prob of 95%: " + str(env.getConfidenceInterval95(real_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Normalized) with prob of 90%: " + str(env.getConfidenceInterval(option_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Normalized) with prob of 95%: " + str(env.getConfidenceInterval95(option_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Real values) with prob of 90%: " + str(env.getConfidenceInterval(option_real_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Real values) with prob of 95%: " + str(env.getConfidenceInterval95(option_real_percentage_rList)))

end_time = time.time()
print('#Time to execute: '+ str((end_time - begin_time)/60) + 'min')
# Out:
# WARNING:tensorflow:Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2c67eb5950>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2c67eb5950>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2c67eb5950>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2c67eb5950>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d2677d890>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d2677d890>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d2677d890>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d2677d890>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d26777850>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d26777850>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d26777850>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d26777850>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d26724f50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d26724f50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d26724f50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d26724f50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2d25c51890>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2d25c51890>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2d25c51890>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2d25c51890>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d26724490>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d26724490>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d26724490>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d26724490>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67ece410>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67ece410>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67ece410>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67ece410>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d25c95c50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d25c95c50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d25c95c50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d25c95c50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d25c78ed0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d25c78ed0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d25c78ed0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d25c78ed0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2c67f94810>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2c67f94810>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2c67f94810>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2c67f94810>>: AssertionError: Bad argument number for Name: 3, expecting 4
# Loading Model...
# INFO:tensorflow:Restoring parameters from /misc/scratch05/patx/fathanab/Experiments_RL/normalizeFirstDay_seed_corrected_2019_11_21_shuffled_GBM_version/savedModel/C51_noSoft_arch0-option_T50-history_t15-num_episodes203400-softUpdateFalse-tau0.001-dropout0.19999999999999996True-num_layers3-freq30-batch64-capacity3000-lambda0.0025-final
# episode 100: 	0.022938962917667897	16.95
# episode 200: 	0.02856373334516536	18.57
# episode 300: 	0.03408187393824964	19.97
# episode 400: 	0.02187843695902484	15.62
# episode 500: 	0.02979557097117953	18.67
# episode 600: 	0.028119775713597712	18.55
# episode 700: 	0.02880692643447364	16.99
# episode 800: 	0.029873926173350898	17.53
# episode 900: 	0.03192916554331897	18.25
# episode 1000: 	0.023006443702017522	16.17
# episode 1100: 	0.03534454164556658	17.12
# episode 1200: 	0.026164086662516635	18.79
# episode 1300: 	0.024823563298986336	13.4
# episode 1400: 	0.02765878718494569	16.92
# episode 1500: 	0.03277447581866375	20.33
# episode 1600: 	0.02547981070413476	15.7
# episode 1700: 	0.02482953059894182	16.35
# episode 1800: 	0.02269083551699712	16.75
# episode 1900: 	0.029012110839485218	17.36
# episode 2000: 	0.023795685827620774	14.78
# episode 2100: 	0.03751333575346588	22.32
# episode 2200: 	0.02983383035892046	19.46
# episode 2300: 	0.03364527124456564	19.34
# episode 2400: 	0.026767284730986995	18.84
# episode 2500: 	0.026206799207880525	15.16
# episode 2600: 	0.024086814997055637	16.42
# episode 2700: 	0.030018838246460934	18.65
# episode 2800: 	0.028997845820027433	17.94
# episode 2900: 	0.034314047077461794	18.85
# episode 3000: 	0.026918557894445826	15.08
# episode 3100: 	0.02761903659693221	17.39
# episode 3200: 	0.02513926017064167	16.53
# episode 3300: 	0.03248157072851312	18.44
# episode 3400: 	0.02254241196716638	15.6
# episode 3500: 	0.03299159408474105	18.15
# episode 3600: 	0.030215859059512015	18.67
# episode 3700: 	0.03435900735038821	18.24
# episode 3800: 	0.03133864736024403	16.82
# episode 3900: 	0.030097381846542533	17.52
# episode 4000: 	0.024495768043810193	16.64
# episode 4100: 	0.03201559288996059	15.49
# episode 4200: 	0.024634678069393127	15.2
# episode 4300: 	0.03633839732658424	19.77
# episode 4400: 	0.024042002116676064	15.94
# episode 4500: 	0.026099045389271446	17.07
# episode 4600: 	0.027535399400711754	15.25
# episode 4700: 	0.027975780443537414	17.48
# episode 4800: 	0.021773287906358893	17.85
# episode 4900: 	0.031045097430287768	18.1
# episode 5000: 	0.021724756743386316	14.99
# #Average reward per episode 5000: 0.02828670888103658
# episode 5100: 	0.03201033824228277	16.93
# episode 5200: 	0.025539632809507898	15.59
# episode 5300: 	0.026381497453366255	17.36
# episode 5400: 	0.024258651080466324	16.13
# episode 5500: 	0.02513679891798843	17.25
# episode 5600: 	0.02675179672326528	18.81
# episode 5700: 	0.030112408840814404	17.89
# episode 5800: 	0.02362516713276528	15.14
# episode 5900: 	0.023369391742987782	17.82
# episode 6000: 	0.021991804286010268	15.09
# episode 6100: 	0.027616823823534097	17.84
# episode 6200: 	0.022333744816299725	16.11
# episode 6300: 	0.026876698403717408	16.92
# episode 6400: 	0.027958191854378547	16.29
# episode 6500: 	0.02446375579603254	16.26
# episode 6600: 	0.02718333171625192	15.6
# episode 6700: 	0.024106260640894443	17.19
# episode 6800: 	0.027634660454571382	18.21
# episode 6900: 	0.03025745933028713	19.58
# episode 7000: 	0.027901792461056882	16.64
# episode 7100: 	0.026090178374096898	16.52
# episode 7200: 	0.02254160049401694	16.34
# episode 7300: 	0.026485596341020233	17.89
# episode 7400: 	0.021236766882773993	16.63
# episode 7500: 	0.027113733743202566	19.44
# episode 7600: 	0.02964722714000148	17.59
# episode 7700: 	0.027050567102075995	17.05
# episode 7800: 	0.027195863603537446	17.44
# episode 7900: 	0.033753388732838355	17.54
# episode 8000: 	0.02088350103394579	16.91
# episode 8100: 	0.028681676327172428	17.23
# episode 8200: 	0.026059735884339862	19.05
# episode 8300: 	0.02879115000699592	17.46
# episode 8400: 	0.02596640890320169	15.27
# episode 8500: 	0.03707717787634074	19.6
# episode 8600: 	0.025521488136964875	15.65
# episode 8700: 	0.03540600788092139	17.01
# episode 8800: 	0.026296340368709755	15.46
# episode 8900: 	0.03247719574374299	18.13
# episode 9000: 	0.02433627735600788	16.2
# episode 9100: 	0.03049477420972432	19.16
# episode 9200: 	0.023194621954869665	15.33
# episode 9300: 	0.032888938893178746	18.5
# episode 9400: 	0.028524666586067733	18.87
# episode 9500: 	0.028715611612885092	19.36
# episode 9600: 	0.02072021351739437	14.92
# episode 9700: 	0.03588459350864504	18.18
# episode 9800: 	0.022279453963631478	15.83
# episode 9900: 	0.030786261100101856	18.22
# episode 10000: 	0.021486109783865014	15.81
# #Average reward per episode 10000: 0.027674327776405754
# episode 10100: 	0.03115904120373925	15.99
# episode 10200: 	0.023334455964853215	14.39
# episode 10300: 	0.03003803264857357	16.55
# episode 10400: 	0.0288220606344149	17.21
# episode 10500: 	0.02762392090423041	17.72
# episode 10600: 	0.027328242573694657	17.51
# episode 10700: 	0.028740504000102383	16.77
# episode 10800: 	0.03134196917173825	17.67
# episode 10900: 	0.032103071736986656	18.88
# episode 11000: 	0.023167827535720734	14.45
# episode 11100: 	0.03240114630466709	18.09
# episode 11200: 	0.01864711294296001	15.25
# episode 11300: 	0.03533336089601064	19.02
# episode 11400: 	0.028735458086658328	17.43
# episode 11500: 	0.032086039471857515	19.36
# episode 11600: 	0.025282170027444605	16.45
# episode 11700: 	0.03195082672446227	18.17
# episode 11800: 	0.025328481211268183	15.49
# episode 11900: 	0.0306598214015806	18.43
# episode 12000: 	0.026416763459882215	17.3
# episode 12100: 	0.028682671594950353	15.86
# episode 12200: 	0.023572458895442662	16.74
# episode 12300: 	0.027170078252561566	18.3
# episode 12400: 	0.026908664345204655	15.55
# episode 12500: 	0.02991458501440856	15.6
# episode 12600: 	0.022719980336049113	15.74
# episode 12700: 	0.03314362827304143	18.09
# episode 12800: 	0.020981837850406134	16.58
# episode 12900: 	0.025598330676979555	16.61
# episode 13000: 	0.021572666840507272	15.28
# episode 13100: 	0.035344974214886415	18.44
# episode 13200: 	0.025959881501813272	16.86
# episode 13300: 	0.031485718545052714	17.95
# episode 13400: 	0.02036096424335189	12.61
# episode 13500: 	0.0287095337738988	16.46
# episode 13600: 	0.024818714452235192	16.69
# episode 13700: 	0.02768439959013168	16.95
# episode 13800: 	0.027787120230036377	15.87
# episode 13900: 	0.03263034221508716	18.99
# episode 14000: 	0.026187530145885696	16.93
# episode 14100: 	0.03267459912335129	17.81
# episode 14200: 	0.020845207529996666	14.47
# episode 14300: 	0.03568203497426855	18.31
# episode 14400: 	0.024006608067675485	15.43
# episode 14500: 	0.037260671517967026	19.18
# episode 14600: 	0.0245725144373875	15.64
# episode 14700: 	0.034218338887776825	18.03
# episode 14800: 	0.024820190226289552	16.57
# episode 14900: 	0.03187425780634277	17.13
# episode 15000: 	0.02290992726034712	16.62
# #Average reward per episode 15000: 0.027786876769098447
# episode 15100: 	0.03018454198123026	17.06
# episode 15200: 	0.02770761323229178	17.0
# episode 15300: 	0.03586597869136125	20.69
# episode 15400: 	0.024954043601935236	14.76
# episode 15500: 	0.03622965736654922	20.88
# episode 15600: 	0.028599339781007472	17.14
# episode 15700: 	0.02977486815962677	17.92
# episode 15800: 	0.026443167403896045	16.76
# episode 15900: 	0.029428330155293364	16.84
# episode 16000: 	0.02621977371322091	16.4
# episode 16100: 	0.027259761045966436	18.48
# episode 16200: 	0.02236527887029249	13.73
# episode 16300: 	0.030881296829585857	19.86
# episode 16400: 	0.027011098550231264	18.4
# episode 16500: 	0.03664928817256721	18.97
# episode 16600: 	0.02208788146075052	14.75
# episode 16700: 	0.03368566470240808	19.65
# episode 16800: 	0.025488315414979514	16.37
# episode 16900: 	0.02978202755673466	18.03
# episode 17000: 	0.022444663701697908	15.32
# episode 17100: 	0.030036302194943305	18.42
# episode 17200: 	0.025725588770461195	16.16
# episode 17300: 	0.027110032493194092	17.56
# episode 17400: 	0.02744709875617897	19.64
# episode 17500: 	0.023945649837282	16.22
# episode 17600: 	0.02224422571786422	13.89
# episode 17700: 	0.03193775461429025	19.65
# episode 17800: 	0.022488559389871984	14.91
# episode 17900: 	0.03275621122419057	18.37
# episode 18000: 	0.02359212078484993	14.42
# episode 18100: 	0.031716567541588525	19.24
# episode 18200: 	0.02832511027950026	16.87
# episode 18300: 	0.03041812274044924	16.74
# episode 18400: 	0.0243093585505022	15.09
# episode 18500: 	0.03315588943735732	18.87
# episode 18600: 	0.023318279794530775	15.7
# episode 18700: 	0.02848274557987602	17.5
# episode 18800: 	0.02524259515945667	15.94
# episode 18900: 	0.029577702760791434	17.62
# episode 19000: 	0.027422689269062824	16.68
# episode 19100: 	0.03239202471732591	17.04
# episode 19200: 	0.02242108280035975	15.19
# episode 19300: 	0.02726980034841446	17.05
# episode 19400: 	0.027259188280634852	17.64
# episode 19500: 	0.03106134793363811	19.54
# episode 19600: 	0.027639878117034354	15.32
# episode 19700: 	0.03866352240363446	20.24
# episode 19800: 	0.024783059190982913	15.7
# episode 19900: 	0.03355359714401117	19.33
# episode 20000: 	0.028485218848123564	17.78
# #Average reward per episode 20000: 0.027919377152183966
# episode 20100: 	0.031226097996836198	20.14
# episode 20200: 	0.021230258041926867	13.12
# episode 20300: 	0.02767376609389077	17.9
# episode 20400: 	0.0217332974120776	15.74
# episode 20500: 	0.03243881950640294	19.62
# episode 20600: 	0.02491500528320818	14.67
# episode 20700: 	0.030518586070631945	17.14
# episode 20800: 	0.023713120292932474	14.56
# episode 20900: 	0.027419784294966207	18.34
# episode 21000: 	0.023371330148896738	15.78
# episode 21100: 	0.030772413522366097	14.53
# episode 21200: 	0.02651179770369798	15.48
# episode 21300: 	0.03258717701282966	19.72
# episode 21400: 	0.025132777440026732	15.45
# episode 21500: 	0.03442081434949118	17.49
# episode 21600: 	0.0190138270888346	13.15
# episode 21700: 	0.03162781030000046	19.62
# episode 21800: 	0.025907868353126376	15.43
# episode 21900: 	0.03458514613631556	18.6
# episode 22000: 	0.024893846847720096	16.6
# episode 22100: 	0.03053703987923568	17.28
# episode 22200: 	0.025225161137712223	15.88
# episode 22300: 	0.03263249400267526	15.66
# episode 22400: 	0.02429933033658346	14.3
# episode 22500: 	0.03355928701346298	19.18
# episode 22600: 	0.028172680436552727	15.73
# episode 22700: 	0.025967968203215962	18.49
# episode 22800: 	0.025098496028562928	14.55
# episode 22900: 	0.03500115713987331	19.39
# episode 23000: 	0.026571467694112987	17.11
# episode 23100: 	0.034620249197106066	18.9
# episode 23200: 	0.024005175176784115	14.33
# episode 23300: 	0.03570747706298803	18.5
# episode 23400: 	0.0246131723868757	16.62
# episode 23500: 	0.028418675782136856	18.6
# episode 23600: 	0.023649595667934405	16.66
# episode 23700: 	0.026908551551724044	17.16
# episode 23800: 	0.031419699009760126	17.7
# episode 23900: 	0.03364445605466829	17.14
# episode 24000: 	0.025656565354995	16.8
# #Total average reward per episode: 0.02795532363937471
# #Max possible average reward per episode: 0.04991113693436689
# #Confidence Interval with prob of 90%: 0.0004214604768789002
# #Confidence Interval with prob of 95%: 0.000502201133313421
# #Sell time entropy: 1.6842632674305664
# #Percentage of stock returns (Normalized): 0.030347299979051126
# #Percentage of stock returns (Real values): 0.030347299979051126
# #Percentage of option returns (Normalized): 0.13958821548505604
# #Percentage of option returns (Real values): 0.13958821548505604
# #Max possible average stock percentage return per episode: 0.05016143279455229
# #Max possible average real stock percentage return per episode: 0.05016143279455229
# #Max possible average option percentage return per episode: 0.8911531961300562
# #Max possible average real option percentage return per episode: 0.8911531961300562
# #Confidence Interval of Percentage of returns (Normalized) with prob of 90%: 0.0004110344940018445
# #Confidence Interval of Percentage of returns (Normalized) with prob of 95%: 0.0004897778084609032
# #Confidence Interval of Percentage of returns (Real values) with prob of 90%: 0.0004110344940018445
# #Confidence Interval of Percentage of returns (Real values) with prob of 95%: 0.0004897778084609032
# #Confidence Interval of Percentage of option returns (Normalized) with prob of 90%: 0.015708325618508292
# #Confidence Interval of Percentage of option returns (Normalized) with prob of 95%: 0.018717624453165063
# #Confidence Interval of Percentage of option returns (Real values) with prob of 90%: 0.015708325618508292
# #Confidence Interval of Percentage of option returns (Real values) with prob of 95%: 0.018717624453165063
# #Time to execute: 69.01257234017054min

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, AvgrList, color='red', label='Episode reward')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward / Ep Length')
plt.legend(loc='best');

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, np.array(AvgrList)*20, color='red', label='Episode reward x20')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward x20 / Ep Length')
plt.legend(loc='best');

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, np.array(AvgrList)*100, color='red', label='Episode reward x100')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward x100 / Ep Length')
plt.legend(loc='best');

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(range(len(sTimeList)), sTimeList, color='blue', label='Sell time')
plt.title('Sell time over time')
plt.xlabel('episodes')
plt.ylabel('Sell time')
plt.legend(loc='best');

# %% [markdown]
# # Select day of Max price over history [Benchmark]

# %%
env.reset_new_test() # reset to first observation in data (not sure if necessary but just to erase doubt)
# Have a look at the RL notebook for more correct tests (slightly changed)
begin_time = time.time()

test = 'MaxValue' #'Random'

myBuffer = experience_buffer()

#create lists to contain total rewards and steps per episode
jList = []
rList = []
sTimeList = [] # sell time list

percentage_rList = []
real_percentage_rList = []

option_percentage_rList = []
option_real_percentage_rList = []

# Average metrics per 100 episodes
AvgEpisodeList = []
AvgrList = []
AvgsTimeList = []
maxPossiblerList = []

maxPossibleP_returnList = []
maxPossibleR_P_returnList = []

maxPossibleOptionP_returnList = []
maxPossibleOptionR_P_returnList = []
  

with tf.Session() as sess, tf.device('/gpu:1'):
    
    for i in range(num_episodes):
        episodeBuffer = []
        #Reset environment and get first new observation
        sP = env.reset()
        s = processState(sP, input_size)
        d = False
        rAll = 0
        j = 0
        
        if test == 'Random':
          sell_time = random.randint(1,max_epLength - 1)
        elif test == 'MaxValue' or test == 'Normal':
          sell_time = -1
        
        while j < max_epLength: 
            if test == 'MaxValue':
              if (s[-1] >= max(s) or j == max_epLength - 1) and env.get_payoff() > 0:
                a = 1
              else:
                a = 0
            elif test == 'Random':
              if j == sell_time and env.get_payoff() > 0:
                a = 1
              else:
                a = 0
                
            s1P,r,d = env.step(a)
            
            s1 = processState(s1P, input_size)
            
            episodeBuffer.append(np.reshape(np.array([s,a,r,s1,d]),[1,5])) # store experience

            rAll += r
            s = s1
            sP = s1P
            j+=1 # episode length till selling or reaching last day of option
            
            if env.is_episode_finished():
                break

        myBuffer.add(episodeBuffer)
        jList.append(j)
        rList.append(rAll)
        sTimeList.append(env.get_sell_time() + 1)
        best_reward, stock_percentage_return, option_percentage_return, stock_real_percentage_return,\
        option_real_percentage_return = env.get_best_possible_reward()
        
        maxPossiblerList.append(best_reward)
        maxPossibleP_returnList.append(stock_percentage_return)
        maxPossibleR_P_returnList.append(stock_real_percentage_return)
        maxPossibleOptionP_returnList.append(option_percentage_return)
        maxPossibleOptionR_P_returnList.append(option_real_percentage_return)
        stock_percentage_return, option_percentage_return = env.get_percentage_return()
        percentage_rList.append(stock_percentage_return)
        option_percentage_rList.append(option_percentage_return)
        stock_percentage_return, option_percentage_return = env.get_real_percentage_return()
        real_percentage_rList.append(stock_percentage_return)
        option_real_percentage_rList.append(option_percentage_return)

        #Periodically print metrics. 
        if len(rList) % summaryLength == 0 and len(rList) != 0:
            AvgR = np.mean(rList[-summaryLength:])
            AvgsT = np.mean(sTimeList[-summaryLength:])
            AvgEpisodeList.append(i+1)
            AvgrList.append(AvgR)
            AvgsTimeList.append(AvgsT)
            print('episode ' + str(i+1) + ': \t' + str(AvgR) 
                  + '\t' + str(AvgsT)+ '\t'+ str(e))
        if len(rList) % summaryAverageReward == 0 and len(rList) != 0:
            print ("#Average reward per episode " + str(i+1) + ": " + str(sum(rList)/len(rList)))
                
option_percentage_rList = [value for value in option_percentage_rList if not math.isnan(value)]
maxPossibleOptionP_returnList = [value for value in maxPossibleOptionP_returnList if not math.isnan(value)]

print ("#Total average reward per episode: " + str(sum(rList)/num_episodes))

print ("#Max possible average reward per episode: " + str(np.mean(maxPossiblerList)))

print ("#Confidence Interval with prob of 90%: " + str(env.getConfidenceInterval(rList)))

print ("#Confidence Interval with prob of 95%: " + str(env.getConfidenceInterval95(rList)))

print ("#Sell time entropy: " + str(env.getEntropy(sTimeList)))

print ("#Percentage of stock returns (Normalized): " + str(np.mean(percentage_rList)))

print ("#Percentage of stock returns (Real values): " + str(np.mean(real_percentage_rList)))

print ("#Percentage of option returns (Normalized): " + str(np.mean(option_percentage_rList)))

print ("#Percentage of option returns (Real values): " + str(np.mean(option_real_percentage_rList)))

print ("#Max possible average stock percentage return per episode: " + str(np.mean(maxPossibleP_returnList)))

print ("#Max possible average real stock percentage return per episode: " + str(np.mean(maxPossibleR_P_returnList)))

print ("#Max possible average option percentage return per episode: " + str(np.mean(maxPossibleOptionP_returnList)))

print ("#Max possible average real option percentage return per episode: " + str(np.mean(maxPossibleOptionR_P_returnList)))

print ("#Confidence Interval of Percentage of returns (Normalized) with prob of 90%: " + str(env.getConfidenceInterval(percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Normalized) with prob of 95%: " + str(env.getConfidenceInterval95(percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Real values) with prob of 90%: " + str(env.getConfidenceInterval(real_percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Real values) with prob of 95%: " + str(env.getConfidenceInterval95(real_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Normalized) with prob of 90%: " + str(env.getConfidenceInterval(option_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Normalized) with prob of 95%: " + str(env.getConfidenceInterval95(option_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Real values) with prob of 90%: " + str(env.getConfidenceInterval(option_real_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Real values) with prob of 95%: " + str(env.getConfidenceInterval95(option_real_percentage_rList)))

end_time = time.time()
print('#Time to execute: '+ str((end_time - begin_time)/60) + 'min')
# Out:
# episode 100: 	0.022581448634089427	18.02	0
# episode 200: 	0.027417230396361805	19.5	0
# episode 300: 	0.031997202597456	20.98	0
# episode 400: 	0.02065658360285716	16.91	0
# episode 500: 	0.02775722507488879	19.87	0
# episode 600: 	0.02713543731829545	19.5	0
# episode 700: 	0.0266069804130894	18.39	0
# episode 800: 	0.03000183668807212	19.5	0
# episode 900: 	0.03066043113320444	19.87	0
# episode 1000: 	0.02202709380462718	16.91	0
# episode 1100: 	0.03549586296670482	19.87	0
# episode 1200: 	0.025254950387408846	19.87	0
# episode 1300: 	0.02418573369415695	14.69	0
# episode 1400: 	0.028573172015848906	18.76	0
# episode 1500: 	0.03514896746351186	21.72	0
# episode 1600: 	0.02395899407301606	17.28	0
# episode 1700: 	0.023593769099448866	16.91	0
# episode 1800: 	0.024141391913274895	18.02	0
# episode 1900: 	0.02727058881429777	18.39	0
# episode 2000: 	0.022743611287317562	16.17	0
# episode 2100: 	0.039647907439099114	24.31	0
# episode 2200: 	0.029955757792726582	20.24	0
# episode 2300: 	0.0343000650251394	20.61	0
# episode 2400: 	0.025224973519184627	19.13	0
# episode 2500: 	0.02935795766456626	17.28	0
# episode 2600: 	0.022686801225427135	17.28	0
# episode 2700: 	0.03073745162521195	19.87	0
# episode 2800: 	0.027518008063672852	19.5	0
# episode 2900: 	0.03569949628927664	20.61	0
# episode 3000: 	0.028055424589988845	16.91	0
# episode 3100: 	0.02927509702405782	19.13	0
# episode 3200: 	0.02603861743364347	18.02	0
# episode 3300: 	0.03036273073597257	19.5	0
# episode 3400: 	0.022488718467890408	16.91	0
# episode 3500: 	0.03342707751462171	20.61	0
# episode 3600: 	0.029505869661454	19.87	0
# episode 3700: 	0.03288684720735902	19.87	0
# episode 3800: 	0.031425607139283114	19.13	0
# episode 3900: 	0.030784839295156567	19.5	0
# episode 4000: 	0.025441141563418226	17.65	0
# episode 4100: 	0.03059297735126189	16.91	0
# episode 4200: 	0.025952688828434444	16.91	0
# episode 4300: 	0.03600454050522673	22.09	0
# episode 4400: 	0.023992169081558764	16.54	0
# episode 4500: 	0.027216591220970202	18.76	0
# episode 4600: 	0.026998564138168632	16.91	0
# episode 4700: 	0.02841421514013631	18.39	0
# episode 4800: 	0.02060135666393175	18.39	0
# episode 4900: 	0.029287147026235968	19.13	0
# episode 5000: 	0.022760846890642145	16.54	0
# #Average reward per episode 5000: 0.028076999950032835
# episode 5100: 	0.03258830770028537	19.13	0
# episode 5200: 	0.024717109055819853	16.91	0
# episode 5300: 	0.027446385571572324	18.76	0
# episode 5400: 	0.020712505122209665	17.28	0
# episode 5500: 	0.025985987449009963	18.39	0
# episode 5600: 	0.027933522811586797	20.24	0
# episode 5700: 	0.03127513973358717	19.5	0
# episode 5800: 	0.024373110870922046	15.8	0
# episode 5900: 	0.025091271806649093	19.13	0
# episode 6000: 	0.02089079125960398	15.8	0
# episode 6100: 	0.028906469562289868	19.13	0
# episode 6200: 	0.0224870728506243	17.28	0
# episode 6300: 	0.02739835031196334	18.76	0
# episode 6400: 	0.02616246039137536	17.65	0
# episode 6500: 	0.022195341931552353	17.65	0
# episode 6600: 	0.024883707349690854	16.91	0
# episode 6700: 	0.02578856894043625	18.76	0
# episode 6800: 	0.02694209727815498	19.5	0
# episode 6900: 	0.03336121508760525	21.35	0
# episode 7000: 	0.025636853591704475	18.02	0
# episode 7100: 	0.02636087847658713	17.65	0
# episode 7200: 	0.02233956290404117	17.65	0
# episode 7300: 	0.026342270864822295	19.13	0
# episode 7400: 	0.020150494358529066	17.65	0
# episode 7500: 	0.027408084420465016	20.98	0
# episode 7600: 	0.03216790858576024	18.76	0
# episode 7700: 	0.025862897778408656	18.76	0
# episode 7800: 	0.028943123843745013	18.76	0
# episode 7900: 	0.03339049782281314	19.5	0
# episode 8000: 	0.02058762115256417	17.28	0
# episode 8100: 	0.029629166725500023	19.5	0
# episode 8200: 	0.02734838730029616	19.5	0
# episode 8300: 	0.027443344620443944	19.5	0
# episode 8400: 	0.025591410178419604	15.8	0
# episode 8500: 	0.03965550157375262	21.35	0
# episode 8600: 	0.024836620443644507	16.91	0
# episode 8700: 	0.03735065809708313	19.5	0
# episode 8800: 	0.027613662604827845	16.54	0
# episode 8900: 	0.02968872611868296	19.5	0
# episode 9000: 	0.02529601804521337	17.28	0
# episode 9100: 	0.02918793959828236	20.24	0
# episode 9200: 	0.0231936194840884	16.91	0
# episode 9300: 	0.03202379995697265	19.5	0
# episode 9400: 	0.02931157514907279	19.87	0
# episode 9500: 	0.030441228594773034	20.98	0
# episode 9600: 	0.020928840768940436	16.17	0
# episode 9700: 	0.037201943034105324	20.98	0
# episode 9800: 	0.02099694706932415	16.54	0
# episode 9900: 	0.03072608568493911	19.13	0
# episode 10000: 	0.022894106551851624	17.28	0
# #Average reward per episode 10000: 0.027635391879862272
# episode 10100: 	0.030111242656616636	16.91	0
# episode 10200: 	0.025707415738146437	16.17	0
# episode 10300: 	0.030251744479426988	18.02	0
# episode 10400: 	0.03103578105917104	19.13	0
# episode 10500: 	0.026226135321595873	19.13	0
# episode 10600: 	0.02835139675202341	18.76	0
# episode 10700: 	0.030092617549178437	18.76	0
# episode 10800: 	0.029593423596604315	18.39	0
# episode 10900: 	0.0287353260144672	20.61	0
# episode 11000: 	0.022905397816750366	16.17	0
# episode 11100: 	0.03341560906816642	20.24	0
# episode 11200: 	0.01818299971361477	15.43	0
# episode 11300: 	0.03694711930283863	20.98	0
# episode 11400: 	0.028490847442010157	18.39	0
# episode 11500: 	0.031629290843303015	20.98	0
# episode 11600: 	0.02652327849797217	18.02	0
# episode 11700: 	0.030821997646216192	19.87	0
# episode 11800: 	0.025897004463536145	16.91	0
# episode 11900: 	0.031571857567463765	19.87	0
# episode 12000: 	0.025920060654480256	18.39	0
# episode 12100: 	0.0285968015444899	18.02	0
# episode 12200: 	0.02523524987943342	17.65	0
# episode 12300: 	0.02607525838573049	19.13	0
# episode 12400: 	0.027242717214021113	17.28	0
# episode 12500: 	0.03162034748787716	17.28	0
# episode 12600: 	0.021765296860105834	16.54	0
# episode 12700: 	0.031141022381838964	19.5	0
# episode 12800: 	0.020865360911589394	17.28	0
# episode 12900: 	0.02529030143766566	18.39	0
# episode 13000: 	0.023098583306642786	16.54	0
# episode 13100: 	0.03186897478196603	19.87	0
# episode 13200: 	0.02669460662756759	18.39	0
# episode 13300: 	0.031075099149798592	20.24	0
# episode 13400: 	0.019711676086151687	13.21	0
# episode 13500: 	0.028859790518083316	17.28	0
# episode 13600: 	0.024321603350135258	17.65	0
# episode 13700: 	0.02722771525689935	18.39	0
# episode 13800: 	0.027975255635708414	17.65	0
# episode 13900: 	0.03248318422823871	20.24	0
# episode 14000: 	0.025598789019901143	18.39	0
# episode 14100: 	0.029463741421406314	19.5	0
# episode 14200: 	0.02310992008742334	16.17	0
# episode 14300: 	0.0350450629172126	20.24	0
# episode 14400: 	0.02193107143183453	16.54	0
# episode 14500: 	0.03841979335045354	20.61	0
# episode 14600: 	0.024838278338626535	16.91	0
# episode 14700: 	0.03274228942879762	19.87	0
# episode 14800: 	0.023581481306073716	18.02	0
# episode 14900: 	0.033016878331940336	19.13	0
# episode 15000: 	0.023886972719836308	17.65	0
# #Average reward per episode 15000: 0.027724885717115053
# episode 15100: 	0.029346953924744342	19.5	0
# episode 15200: 	0.02850527226150426	18.02	0
# episode 15300: 	0.03666229304405985	23.2	0
# episode 15400: 	0.02478076650962728	16.17	0
# episode 15500: 	0.0342640444036594	23.2	0
# episode 15600: 	0.027469884951838414	18.02	0
# episode 15700: 	0.030014760265382915	19.5	0
# episode 15800: 	0.026529174438442733	18.39	0
# episode 15900: 	0.029952938847145127	18.76	0
# episode 16000: 	0.025836313101822248	17.65	0
# episode 16100: 	0.027272442944726808	19.5	0
# episode 16200: 	0.02225615882034854	15.43	0
# episode 16300: 	0.029137220279375237	20.61	0
# episode 16400: 	0.025806901730785883	19.13	0
# episode 16500: 	0.038028710032455344	21.35	0
# episode 16600: 	0.019973005218003954	15.43	0
# episode 16700: 	0.031886890533595	21.72	0
# episode 16800: 	0.026731352173044044	18.02	0
# episode 16900: 	0.032103055381294585	19.87	0
# episode 17000: 	0.023496186781344734	16.17	0
# episode 17100: 	0.02991266991990834	20.24	0
# episode 17200: 	0.025103843106432384	18.02	0
# episode 17300: 	0.027543196682893206	18.76	0
# episode 17400: 	0.029549162638273653	20.61	0
# episode 17500: 	0.02322856871061579	17.28	0
# episode 17600: 	0.022907070864005598	15.43	0
# episode 17700: 	0.02828635233993085	20.61	0
# episode 17800: 	0.022460426519764924	15.43	0
# episode 17900: 	0.03357747983865323	20.24	0
# episode 18000: 	0.023483003402674986	15.06	0
# episode 18100: 	0.0316929684355118	20.61	0
# episode 18200: 	0.0284497222121975	19.13	0
# episode 18300: 	0.029735632360399472	18.02	0
# episode 18400: 	0.02474676819783924	16.91	0
# episode 18500: 	0.033454830306251584	20.61	0
# episode 18600: 	0.02293781773609029	16.54	0
# episode 18700: 	0.031157365973861876	19.5	0
# episode 18800: 	0.02563000298610828	16.91	0
# episode 18900: 	0.02953449921782466	19.13	0
# episode 19000: 	0.02699766805188923	18.02	0
# episode 19100: 	0.03409549260223205	18.76	0
# episode 19200: 	0.02465455002683652	16.54	0
# episode 19300: 	0.02635451163942502	18.76	0
# episode 19400: 	0.028427283953361786	19.13	0
# episode 19500: 	0.02902671072379753	20.98	0
# episode 19600: 	0.02820104426739802	17.28	0
# episode 19700: 	0.03659798481210671	22.09	0
# episode 19800: 	0.023756190752162766	17.28	0
# episode 19900: 	0.03238877535643447	21.35	0
# episode 20000: 	0.026397331994728962	18.39	0
# #Average reward per episode 20000: 0.027845380544200344
# episode 20100: 	0.028596172863065678	22.09	0
# episode 20200: 	0.02128514372475091	14.32	0
# episode 20300: 	0.030909731824676	19.87	0
# episode 20400: 	0.024204035178562372	16.91	0
# episode 20500: 	0.03274305570100949	21.35	0
# episode 20600: 	0.025929107295909328	16.17	0
# episode 20700: 	0.029811415004732347	17.65	0
# episode 20800: 	0.02296810686625759	15.43	0
# episode 20900: 	0.026871759982729452	19.87	0
# episode 21000: 	0.02533195856896795	17.28	0
# episode 21100: 	0.030253866211750594	15.8	0
# episode 21200: 	0.025400007245793946	16.54	0
# episode 21300: 	0.032954555533818	22.09	0
# episode 21400: 	0.02430087492631337	16.54	0
# episode 21500: 	0.03275489788903038	19.13	0
# episode 21600: 	0.018136034513457067	14.69	0
# episode 21700: 	0.030536496085173077	20.98	0
# episode 21800: 	0.027506673362341316	17.28	0
# episode 21900: 	0.03490767397653396	20.61	0
# episode 22000: 	0.02515120611590891	17.65	0
# episode 22100: 	0.030081717609362367	19.13	0
# episode 22200: 	0.024546701636318356	16.91	0
# episode 22300: 	0.03138036100012118	17.28	0
# episode 22400: 	0.022463770754636153	15.8	0
# episode 22500: 	0.031852798083881737	20.98	0
# episode 22600: 	0.03001997558020281	16.91	0
# episode 22700: 	0.025816363043052196	19.87	0
# episode 22800: 	0.02498808340491248	16.54	0
# episode 22900: 	0.03483752204525429	20.61	0
# episode 23000: 	0.027254071680882123	18.76	0
# episode 23100: 	0.03546610019764767	20.98	0
# episode 23200: 	0.025108366295015467	15.06	0
# episode 23300: 	0.036798359989021104	20.61	0
# episode 23400: 	0.02365902622914386	17.28	0
# episode 23500: 	0.027432770725466068	20.24	0
# episode 23600: 	0.023740580244619044	17.28	0
# episode 23700: 	0.027744532753831038	19.13	0
# episode 23800: 	0.03119957868308387	18.76	0
# episode 23900: 	0.03340054779515282	19.13	0
# episode 24000: 	0.02565718268547898	17.65	0
# #Total average reward per episode: 0.027887822050616358
# #Max possible average reward per episode: 0.04991113693436689
# #Confidence Interval with prob of 90%: 0.00044472466951356505
# #Confidence Interval with prob of 95%: 0.0005299221286325325
# #Sell time entropy: 0.6917552533695535
# #Percentage of stock returns (Normalized): 0.03031564509707503
# #Percentage of stock returns (Real values): 0.03031564509707503
# #Percentage of option returns (Normalized): 0.13754272443469143
# #Percentage of option returns (Real values): 0.13754272443469134
# #Max possible average stock percentage return per episode: 0.05016143279455229
# #Max possible average real stock percentage return per episode: 0.05016143279455229
# #Max possible average option percentage return per episode: 0.8911531961300562
# #Max possible average real option percentage return per episode: 0.8911531961300562
# #Confidence Interval of Percentage of returns (Normalized) with prob of 90%: 0.0004355959782669392
# #Confidence Interval of Percentage of returns (Normalized) with prob of 95%: 0.0005190446221017337
# #Confidence Interval of Percentage of returns (Real values) with prob of 90%: 0.0004355959782669392
# #Confidence Interval of Percentage of returns (Real values) with prob of 95%: 0.0005190446221017337
# #Confidence Interval of Percentage of option returns (Normalized) with prob of 90%: 0.016580286085307223
# #Confidence Interval of Percentage of option returns (Normalized) with prob of 95%: 0.019756629433830775
# #Confidence Interval of Percentage of option returns (Real values) with prob of 90%: 0.016580286085307223
# #Confidence Interval of Percentage of option returns (Real values) with prob of 95%: 0.01975662943383077
# #Time to execute: 13.355018083254496min

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, AvgrList, color='red', label='Episode reward')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward / Ep Length')
plt.legend(loc='best')

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, np.array(AvgrList)*20, color='red', label='Episode reward x20')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward x20 / Ep Length')
plt.legend(loc='best')

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, np.array(AvgrList)*100, color='red', label='Episode reward x100')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward x100 / Ep Length')
plt.legend(loc='best')

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(range(len(sTimeList)), sTimeList, color='blue', label='Sell time')
plt.title('Sell time over time')
plt.xlabel('episodes')
plt.ylabel('Sell time')
plt.legend(loc='best');

# %% [markdown]
# # Select random day over history to sell [Benchmark]

# %%
env.reset_new_test() # reset to first observation in data (not sure if necessary but just to erase doubt)
begin_time = time.time()

test = 'Random'

myBuffer = experience_buffer()

#create lists to contain total rewards and steps per episode
jList = []
rList = []
sTimeList = [] # sell time list

percentage_rList = []
real_percentage_rList = []

option_percentage_rList = []
option_real_percentage_rList = []

# Average metrics per 100 episodes
AvgEpisodeList = []
AvgrList = []
AvgsTimeList = []
maxPossiblerList = []

maxPossibleP_returnList = []
maxPossibleR_P_returnList = []

maxPossibleOptionP_returnList = []
maxPossibleOptionR_P_returnList = []
  

with tf.Session() as sess, tf.device('/gpu:1'):
    
    for i in range(num_episodes):
        episodeBuffer = []
        #Reset environment and get first new observation
        sP = env.reset()
        s = processState(sP, input_size)
        d = False
        rAll = 0
        j = 0
        
        if test == 'Random':
          sell_time = random.randint(1,max_epLength - 1)
        elif test == 'MaxValue' or test == 'Normal':
          sell_time = -1
        
        while j < max_epLength: 
            
            if test == 'MaxValue':
              if (s[-1] >= max(s) or j == max_epLength - 1) and env.get_payoff() > 0:
                a = 1
              else:
                a = 0
            elif test == 'Random':
              if j == sell_time and env.get_payoff() > 0:
                a = 1
              else:
                a = 0
                
            s1P,r,d = env.step(a)
            
            s1 = processState(s1P, input_size)
            
            episodeBuffer.append(np.reshape(np.array([s,a,r,s1,d]),[1,5])) # store experience

            rAll += r
            s = s1
            sP = s1P
            j+=1 # episode length till selling or reaching last day of option
            
            if env.is_episode_finished():
                break
        
        myBuffer.add(episodeBuffer)
        jList.append(j)
        rList.append(rAll)
        sTimeList.append(env.get_sell_time() + 1)
        best_reward, stock_percentage_return, option_percentage_return, stock_real_percentage_return,\
        option_real_percentage_return = env.get_best_possible_reward()
        
        maxPossiblerList.append(best_reward)
        maxPossibleP_returnList.append(stock_percentage_return)
        maxPossibleR_P_returnList.append(stock_real_percentage_return)
        maxPossibleOptionP_returnList.append(option_percentage_return)
        maxPossibleOptionR_P_returnList.append(option_real_percentage_return)
        stock_percentage_return, option_percentage_return = env.get_percentage_return()
        percentage_rList.append(stock_percentage_return)
        option_percentage_rList.append(option_percentage_return)
        stock_percentage_return, option_percentage_return = env.get_real_percentage_return()
        real_percentage_rList.append(stock_percentage_return)
        option_real_percentage_rList.append(option_percentage_return)
        
        #Periodically print metrics. 
        if len(rList) % summaryLength == 0 and len(rList) != 0:
            AvgR = np.mean(rList[-summaryLength:])
            AvgsT = np.mean(sTimeList[-summaryLength:])
            AvgEpisodeList.append(i+1)
            AvgrList.append(AvgR)
            AvgsTimeList.append(AvgsT)
            print('episode ' + str(i+1) + ': \t' + str(AvgR) 
                  + '\t' + str(AvgsT)+ '\t'+ str(e))
        if len(rList) % summaryAverageReward == 0 and len(rList) != 0:
            print ("#Average reward per episode " + str(i+1) + ": " + str(sum(rList)/len(rList)))
                
option_percentage_rList = [value for value in option_percentage_rList if not math.isnan(value)]
maxPossibleOptionP_returnList = [value for value in maxPossibleOptionP_returnList if not math.isnan(value)]

print ("#Total average reward per episode: " + str(sum(rList)/num_episodes))

print ("#Max possible average reward per episode: " + str(np.mean(maxPossiblerList)))    

print ("#Confidence Interval with prob of 90%: " + str(env.getConfidenceInterval(rList)))

print ("#Confidence Interval with prob of 95%: " + str(env.getConfidenceInterval95(rList)))

print ("#Sell time entropy: " + str(env.getEntropy(sTimeList)))

print ("#Percentage of stock returns (Normalized): " + str(np.mean(percentage_rList)))

print ("#Percentage of stock returns (Real values): " + str(np.mean(real_percentage_rList)))

print ("#Percentage of option returns (Normalized): " + str(np.mean(option_percentage_rList)))

print ("#Percentage of option returns (Real values): " + str(np.mean(option_real_percentage_rList)))

print ("#Max possible average stock percentage return per episode: " + str(np.mean(maxPossibleP_returnList)))

print ("#Max possible average real stock percentage return per episode: " + str(np.mean(maxPossibleR_P_returnList)))

print ("#Max possible average option percentage return per episode: " + str(np.mean(maxPossibleOptionP_returnList)))

print ("#Max possible average real option percentage return per episode: " + str(np.mean(maxPossibleOptionR_P_returnList)))

print ("#Confidence Interval of Percentage of returns (Normalized) with prob of 90%: " + str(env.getConfidenceInterval(percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Normalized) with prob of 95%: " + str(env.getConfidenceInterval95(percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Real values) with prob of 90%: " + str(env.getConfidenceInterval(real_percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Real values) with prob of 95%: " + str(env.getConfidenceInterval95(real_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Normalized) with prob of 90%: " + str(env.getConfidenceInterval(option_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Normalized) with prob of 95%: " + str(env.getConfidenceInterval95(option_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Real values) with prob of 90%: " + str(env.getConfidenceInterval(option_real_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Real values) with prob of 95%: " + str(env.getConfidenceInterval95(option_real_percentage_rList)))


end_time = time.time()
print('#Time to execute: '+ str((end_time - begin_time)/60) + 'min')
# Out:
# episode 100: 	0.019737990329150124	15.87	0
# episode 200: 	0.02437887563704885	13.88	0
# episode 300: 	0.026356619682970935	16.21	0
# episode 400: 	0.01850160866388698	12.81	0
# episode 500: 	0.024246937474927094	16.3	0
# episode 600: 	0.02345268652790313	15.81	0
# episode 700: 	0.021655544279876413	15.03	0
# episode 800: 	0.02796607390376173	16.76	0
# episode 900: 	0.025344435004493075	15.38	0
# episode 1000: 	0.019512605533441668	13.49	0
# episode 1100: 	0.031117665477487306	16.67	0
# episode 1200: 	0.023066601349240955	15.79	0
# episode 1300: 	0.022311275609867058	12.4	0
# episode 1400: 	0.02513717978676561	15.43	0
# episode 1500: 	0.029276224557209664	19.86	0
# episode 1600: 	0.02379191164446304	15.9	0
# episode 1700: 	0.022918613102241876	13.69	0
# episode 1800: 	0.021584432809164045	15.3	0
# episode 1900: 	0.02497169463212789	15.27	0
# episode 2000: 	0.018986657919567263	12.69	0
# episode 2100: 	0.03689583050496341	19.61	0
# episode 2200: 	0.02102286319857576	14.81	0
# episode 2300: 	0.02516334262267409	15.46	0
# episode 2400: 	0.021182535298320274	14.17	0
# episode 2500: 	0.02314333922881513	12.68	0
# episode 2600: 	0.02090544098468926	14.97	0
# episode 2700: 	0.02395561502207736	15.61	0
# episode 2800: 	0.022384173232306147	14.4	0
# episode 2900: 	0.028417502193966215	15.37	0
# episode 3000: 	0.025759566306241263	14.57	0
# episode 3100: 	0.025245826867333673	14.81	0
# episode 3200: 	0.020590323067025088	14.54	0
# episode 3300: 	0.02483535438759696	14.81	0
# episode 3400: 	0.024008582810879232	15.05	0
# episode 3500: 	0.027574364528512932	16.04	0
# episode 3600: 	0.02647602441769395	17.03	0
# episode 3700: 	0.029797153592980942	16.13	0
# episode 3800: 	0.028309405672820878	15.85	0
# episode 3900: 	0.025425307101639764	15.1	0
# episode 4000: 	0.021460490497474873	14.96	0
# episode 4100: 	0.025889234975207665	11.53	0
# episode 4200: 	0.018557018392579165	12.32	0
# episode 4300: 	0.030056991185441303	16.22	0
# episode 4400: 	0.021708423630963626	13.95	0
# episode 4500: 	0.026606504159822998	15.84	0
# episode 4600: 	0.021226949708394036	13.11	0
# episode 4700: 	0.023530858281390805	15.32	0
# episode 4800: 	0.0191687240344614	14.39	0
# episode 4900: 	0.0270502706025499	15.32	0
# episode 5000: 	0.017312468474286673	12.83	0
# #Average reward per episode 5000: 0.024159522378145518
# episode 5100: 	0.026755159773495886	15.59	0
# episode 5200: 	0.021892000971705527	14.31	0
# episode 5300: 	0.025150322773228626	14.21	0
# episode 5400: 	0.021070043692199007	15.72	0
# episode 5500: 	0.01733393238063556	13.89	0
# episode 5600: 	0.022774048911128088	16.4	0
# episode 5700: 	0.02603331435674096	15.85	0
# episode 5800: 	0.022868071581503894	14.81	0
# episode 5900: 	0.02266940726135237	15.87	0
# episode 6000: 	0.020078005937944378	14.37	0
# episode 6100: 	0.022894319825750443	14.98	0
# episode 6200: 	0.020799809518441945	13.92	0
# episode 6300: 	0.023643161894678574	16.79	0
# episode 6400: 	0.021371212043947967	14.96	0
# episode 6500: 	0.024873644912834506	14.55	0
# episode 6600: 	0.021513334837620204	12.83	0
# episode 6700: 	0.024002006498941113	17.11	0
# episode 6800: 	0.024178854804229336	15.42	0
# episode 6900: 	0.027516519934844094	17.39	0
# episode 7000: 	0.022788449843130477	14.86	0
# episode 7100: 	0.025350180945392656	13.69	0
# episode 7200: 	0.020622689238926767	13.68	0
# episode 7300: 	0.02485011531712719	16.42	0
# episode 7400: 	0.01889587105976217	13.63	0
# episode 7500: 	0.02344199789119765	16.2	0
# episode 7600: 	0.024920279437741853	15.83	0
# episode 7700: 	0.02465814272416797	15.44	0
# episode 7800: 	0.02473771530487054	14.46	0
# episode 7900: 	0.02560408546509122	15.0	0
# episode 8000: 	0.018264465513156487	14.43	0
# episode 8100: 	0.029844072216381877	16.66	0
# episode 8200: 	0.02689566617798893	16.45	0
# episode 8300: 	0.025331384387014176	14.66	0
# episode 8400: 	0.02557183094381071	15.27	0
# episode 8500: 	0.03203206785696773	16.19	0
# episode 8600: 	0.020620969852566992	12.69	0
# episode 8700: 	0.030583002855903717	14.21	0
# episode 8800: 	0.02382590436819579	13.15	0
# episode 8900: 	0.022169981687413808	14.54	0
# episode 9000: 	0.024838625153889807	15.38	0
# episode 9100: 	0.027007690174528816	17.26	0
# episode 9200: 	0.022187893941228026	13.9	0
# episode 9300: 	0.02554971793096472	14.68	0
# episode 9400: 	0.023465129712736642	15.79	0
# episode 9500: 	0.02507056740585091	16.87	0
# episode 9600: 	0.018854858034927046	13.62	0
# episode 9700: 	0.031099385843315966	16.18	0
# episode 9800: 	0.018168907306586737	14.11	0
# episode 9900: 	0.026920516369087655	17.55	0
# episode 10000: 	0.020759513799425075	14.48	0
# #Average reward per episode 10000: 0.02400324969577846
# episode 10100: 	0.024616990106996944	14.58	0
# episode 10200: 	0.025166031231971576	14.0	0
# episode 10300: 	0.028129299511722577	15.34	0
# episode 10400: 	0.026633262578198903	16.03	0
# episode 10500: 	0.02250226238884015	16.39	0
# episode 10600: 	0.02380260431824745	15.71	0
# episode 10700: 	0.02480385709787068	15.12	0
# episode 10800: 	0.024445830228992313	15.34	0
# episode 10900: 	0.02795160508055328	15.49	0
# episode 11000: 	0.022522378399551832	13.66	0
# episode 11100: 	0.02755046769703833	14.85	0
# episode 11200: 	0.01704245687364514	13.35	0
# episode 11300: 	0.031083862604024615	16.77	0
# episode 11400: 	0.023491897520244453	15.45	0
# episode 11500: 	0.024664292207088122	16.78	0
# episode 11600: 	0.022768776593093377	14.41	0
# episode 11700: 	0.025659696573005545	16.35	0
# episode 11800: 	0.02279942294866141	14.63	0
# episode 11900: 	0.021371608906435045	15.76	0
# episode 12000: 	0.023175640736040785	14.88	0
# episode 12100: 	0.021921536722780185	13.08	0
# episode 12200: 	0.021636073548766968	14.25	0
# episode 12300: 	0.02523764175742014	17.06	0
# episode 12400: 	0.024193435763389805	14.19	0
# episode 12500: 	0.024189312026843914	13.96	0
# episode 12600: 	0.020343090938048345	13.59	0
# episode 12700: 	0.028351525819582116	15.78	0
# episode 12800: 	0.02020255699769761	14.28	0
# episode 12900: 	0.021744336804023004	14.88	0
# episode 13000: 	0.021218447647191344	13.96	0
# episode 13100: 	0.029089690204570143	16.31	0
# episode 13200: 	0.026839947310046814	16.37	0
# episode 13300: 	0.025856070841562596	15.43	0
# episode 13400: 	0.019019052063104103	11.06	0
# episode 13500: 	0.02527576621006002	14.01	0
# episode 13600: 	0.0214903414238208	15.2	0
# episode 13700: 	0.02447199363805651	14.35	0
# episode 13800: 	0.02146102198016576	13.51	0
# episode 13900: 	0.029215403457748403	15.57	0
# episode 14000: 	0.024862698580150555	16.48	0
# episode 14100: 	0.024485821742078057	15.45	0
# episode 14200: 	0.019295306175120965	13.31	0
# episode 14300: 	0.0304902584943442	18.1	0
# episode 14400: 	0.02166863810854005	14.16	0
# episode 14500: 	0.032452645916799194	16.54	0
# episode 14600: 	0.02069906313443199	13.06	0
# episode 14700: 	0.027759734315904994	16.22	0
# episode 14800: 	0.021274234665578318	16.45	0
# episode 14900: 	0.028848082296639443	14.44	0
# episode 15000: 	0.020963801254842592	14.66	0
# #Average reward per episode 15000: 0.024100431620129183
# episode 15100: 	0.023904514216291	14.62	0
# episode 15200: 	0.02521820418840437	16.6	0
# episode 15300: 	0.03389070602303708	19.8	0
# episode 15400: 	0.026156699914440446	14.54	0
# episode 15500: 	0.029128063959221077	17.99	0
# episode 15600: 	0.025634043590214893	15.18	0
# episode 15700: 	0.025555991821784425	16.99	0
# episode 15800: 	0.02428844180768911	15.09	0
# episode 15900: 	0.025429764276400087	13.5	0
# episode 16000: 	0.02101243589023449	12.73	0
# episode 16100: 	0.026172690832519892	16.82	0
# episode 16200: 	0.019719930651661687	13.91	0
# episode 16300: 	0.02777737719562789	15.27	0
# episode 16400: 	0.02276073039246848	15.56	0
# episode 16500: 	0.03407519065759376	18.22	0
# episode 16600: 	0.01935985006169327	12.84	0
# episode 16700: 	0.02888930201237656	17.04	0
# episode 16800: 	0.021722213825866657	14.55	0
# episode 16900: 	0.028336803634282575	17.31	0
# episode 17000: 	0.021587454321253297	14.06	0
# episode 17100: 	0.0309542550213103	15.66	0
# episode 17200: 	0.022881992397967482	14.63	0
# episode 17300: 	0.02480754206223349	16.54	0
# episode 17400: 	0.02618308742688252	15.82	0
# episode 17500: 	0.021576826607347263	14.44	0
# episode 17600: 	0.022009444046254684	13.61	0
# episode 17700: 	0.02339161686817066	15.88	0
# episode 17800: 	0.023447780929873388	13.3	0
# episode 17900: 	0.027317384322954937	15.13	0
# episode 18000: 	0.022388740143386317	13.28	0
# episode 18100: 	0.02877908557844706	18.08	0
# episode 18200: 	0.027659702287681248	15.9	0
# episode 18300: 	0.02472371652589174	15.01	0
# episode 18400: 	0.02203823187307195	14.44	0
# episode 18500: 	0.026908218186978538	15.02	0
# episode 18600: 	0.019719653514438513	14.93	0
# episode 18700: 	0.024672901636331016	15.77	0
# episode 18800: 	0.022898571955792545	14.51	0
# episode 18900: 	0.028303976684683447	16.61	0
# episode 19000: 	0.023284641829751075	15.9	0
# episode 19100: 	0.027842382405822444	13.81	0
# episode 19200: 	0.021003890761302876	13.68	0
# episode 19300: 	0.024737891401291113	14.5	0
# episode 19400: 	0.02491114049414627	16.29	0
# episode 19500: 	0.025007754962312213	17.01	0
# episode 19600: 	0.021483991019989938	12.19	0
# episode 19700: 	0.03263799803988964	16.75	0
# episode 19800: 	0.022060112079208487	13.24	0
# episode 19900: 	0.03290570068428103	17.85	0
# episode 20000: 	0.0198937772622816	14.75	0
# #Average reward per episode 20000: 0.02436058580651214
# episode 20100: 	0.02573104825393516	18.15	0
# episode 20200: 	0.017339713872363414	11.42	0
# episode 20300: 	0.025277058783983505	14.77	0
# episode 20400: 	0.02073216246839766	13.39	0
# episode 20500: 	0.024809782914804582	16.7	0
# episode 20600: 	0.02317689705463713	13.85	0
# episode 20700: 	0.02480913424289346	13.46	0
# episode 20800: 	0.017787700524870068	11.44	0
# episode 20900: 	0.02341229420935941	15.8	0
# episode 21000: 	0.02391445021240562	14.77	0
# episode 21100: 	0.0264469072091421	13.29	0
# episode 21200: 	0.02100104290399704	12.42	0
# episode 21300: 	0.02994254168204391	17.83	0
# episode 21400: 	0.018833526883549275	12.8	0
# episode 21500: 	0.027228773868939987	14.51	0
# episode 21600: 	0.01900959918306251	12.72	0
# episode 21700: 	0.025901854572647997	16.55	0
# episode 21800: 	0.022994035752101582	14.75	0
# episode 21900: 	0.026796621850712993	16.89	0
# episode 22000: 	0.022713642056793805	15.19	0
# episode 22100: 	0.02440485134593788	15.06	0
# episode 22200: 	0.02167998035750711	14.55	0
# episode 22300: 	0.028616532434905223	14.22	0
# episode 22400: 	0.022299287645393403	14.87	0
# episode 22500: 	0.02843469786481745	17.77	0
# episode 22600: 	0.02446229816872828	15.1	0
# episode 22700: 	0.023284289737386006	15.88	0
# episode 22800: 	0.0199944135928196	12.68	0
# episode 22900: 	0.027523962438468965	15.69	0
# episode 23000: 	0.022527105324666567	14.17	0
# episode 23100: 	0.02978791584406876	15.86	0
# episode 23200: 	0.02256408430152734	13.17	0
# episode 23300: 	0.03252081781167349	16.73	0
# episode 23400: 	0.022876587135031743	15.33	0
# episode 23500: 	0.021896744436440234	16.58	0
# episode 23600: 	0.022390445143584823	15.27	0
# episode 23700: 	0.02455166992384323	14.61	0
# episode 23800: 	0.025524932618857816	14.86	0
# episode 23900: 	0.027481571565289853	14.29	0
# episode 24000: 	0.022503260610823292	14.89	0
# #Total average reward per episode: 0.024313755825436788
# #Max possible average reward per episode: 0.04991113693436689
# #Confidence Interval with prob of 90%: 0.0003692574171471749
# #Confidence Interval with prob of 95%: 0.00043999735099474474
# #Sell time entropy: 2.299931623434361
# #Percentage of stock returns (Normalized): 0.026078413944928016
# #Percentage of stock returns (Real values): 0.026078413944928016
# #Percentage of option returns (Normalized): -0.018294880677202783
# #Percentage of option returns (Real values): -0.018294880677202807
# #Max possible average stock percentage return per episode: 0.05016143279455229
# #Max possible average real stock percentage return per episode: 0.05016143279455229
# #Max possible average option percentage return per episode: 0.8911531961300562
# #Max possible average real option percentage return per episode: 0.8911531961300562
# #Confidence Interval of Percentage of returns (Normalized) with prob of 90%: 0.00036248103532951855
# #Confidence Interval of Percentage of returns (Normalized) with prob of 95%: 0.0004319227940308439
# #Confidence Interval of Percentage of returns (Real values) with prob of 90%: 0.00036248103532951855
# #Confidence Interval of Percentage of returns (Real values) with prob of 95%: 0.0004319227940308439
# #Confidence Interval of Percentage of option returns (Normalized) with prob of 90%: 0.01383620608285499
# #Confidence Interval of Percentage of option returns (Normalized) with prob of 95%: 0.01648685643556651
# #Confidence Interval of Percentage of option returns (Real values) with prob of 90%: 0.01383620608285499
# #Confidence Interval of Percentage of option returns (Real values) with prob of 95%: 0.01648685643556651
# #Time to execute: 13.244277203083039min

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, AvgrList, color='red', label='Episode reward')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward / Ep Length')
plt.legend(loc='best')

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, np.array(AvgrList)*20, color='red', label='Episode reward x20')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward x20 / Ep Length')
plt.legend(loc='best')

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, np.array(AvgrList)*100, color='red', label='Episode reward x100')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward x100 / Ep Length')
plt.legend(loc='best')

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(range(len(sTimeList)), sTimeList, color='blue', label='Sell time')
plt.title('Sell time over time')
plt.xlabel('episodes')
plt.ylabel('Sell time')
plt.legend(loc='best');

# %% [markdown]
# # Select last day over history to sell [Benchmark]

# %%
env.reset_new_test() # reset to first observation in data (not sure if necessary but just to erase doubt)
begin_time = time.time()

test = 'LastDay'

myBuffer = experience_buffer()

#create lists to contain total rewards and steps per episode
jList = []
rList = []
sTimeList = [] # sell time list

percentage_rList = []
real_percentage_rList = []

option_percentage_rList = []
option_real_percentage_rList = []

# Average metrics per 100 episodes
AvgEpisodeList = []
AvgrList = []
AvgsTimeList = []
maxPossiblerList = []

maxPossibleP_returnList = []
maxPossibleR_P_returnList = []  

maxPossibleOptionP_returnList = []
maxPossibleOptionR_P_returnList = []

with tf.Session() as sess, tf.device('/gpu:1'):
    
    for i in range(num_episodes):
        episodeBuffer = []
        #Reset environment and get first new observation
        sP = env.reset()
        s = processState(sP, input_size)
        d = False
        rAll = 0
        j = 0
        
        if test == 'Random':
          sell_time = random.randint(1,max_epLength - 1)
        elif test == 'LastDay':
          sell_time = max_epLength - 1  
        elif test == 'MaxValue' or test == 'Normal':
          sell_time = -1
        
        while j < max_epLength: 
            if test == 'MaxValue':
              if (s[-1] >= max(s) or j == max_epLength - 1) and env.get_payoff() > 0:
                a = 1
              else:
                a = 0
            elif test == 'Random' or test == 'LastDay':
              if j == sell_time and env.get_payoff() > 0:
                a = 1
              else:
                a = 0
                
            s1P,r,d = env.step(a)
            
            s1 = processState(s1P, input_size)

            episodeBuffer.append(np.reshape(np.array([s,a,r,s1,d]),[1,5])) # store experience

            rAll += r
            s = s1
            sP = s1P
            j+=1 # episode length till selling or reaching last day of option
            
            if env.is_episode_finished():
                break
        
        myBuffer.add(episodeBuffer)
        jList.append(j)
        rList.append(rAll)
        sTimeList.append(env.get_sell_time() + 1)
        #maxPossiblerList.append(env.get_best_possible_reward())
        #best_reward, percentage_return, real_percentage_return = env.get_best_possible_reward()
        best_reward, stock_percentage_return, option_percentage_return, stock_real_percentage_return,\
        option_real_percentage_return = env.get_best_possible_reward()
        
        maxPossiblerList.append(best_reward)
        maxPossibleP_returnList.append(stock_percentage_return)
        maxPossibleR_P_returnList.append(stock_real_percentage_return)
        maxPossibleOptionP_returnList.append(option_percentage_return)
        maxPossibleOptionR_P_returnList.append(option_real_percentage_return)
        #real_percentage_rList.append(env.get_real_percentage_return())
        stock_percentage_return, option_percentage_return = env.get_percentage_return()
        percentage_rList.append(stock_percentage_return)
        option_percentage_rList.append(option_percentage_return)
        stock_percentage_return, option_percentage_return = env.get_real_percentage_return()
        real_percentage_rList.append(stock_percentage_return)
        option_real_percentage_rList.append(option_percentage_return)

        #Periodically print metrics. 
        if len(rList) % summaryLength == 0 and len(rList) != 0:
            AvgR = np.mean(rList[-summaryLength:])
            AvgsT = np.mean(sTimeList[-summaryLength:])
            AvgEpisodeList.append(i+1)
            AvgrList.append(AvgR)
            AvgsTimeList.append(AvgsT)
            print('episode ' + str(i+1) + ': \t' + str(AvgR) 
                  + '\t' + str(AvgsT)+ '\t'+ str(e))
        if len(rList) % summaryAverageReward == 0 and len(rList) != 0:
            print ("#Average reward per episode " + str(i+1) + ": " + str(sum(rList)/len(rList)))
                
option_percentage_rList = [value for value in option_percentage_rList if not math.isnan(value)]
maxPossibleOptionP_returnList = [value for value in maxPossibleOptionP_returnList if not math.isnan(value)]

print ("#Total average reward per episode: " + str(sum(rList)/num_episodes))

print ("#Max possible average reward per episode: " + str(np.mean(maxPossiblerList)))   

print ("#Confidence Interval with prob of 90%: " + str(env.getConfidenceInterval(rList)))

print ("#Confidence Interval with prob of 95%: " + str(env.getConfidenceInterval95(rList)))

print ("#Sell time entropy: " + str(env.getEntropy(sTimeList)))

print ("#Percentage of stock returns (Normalized): " + str(np.mean(percentage_rList)))

print ("#Percentage of stock returns (Real values): " + str(np.mean(real_percentage_rList)))

print ("#Percentage of option returns (Normalized): " + str(np.mean(option_percentage_rList)))

print ("#Percentage of option returns (Real values): " + str(np.mean(option_real_percentage_rList)))

print ("#Max possible average stock percentage return per episode: " + str(np.mean(maxPossibleP_returnList)))

print ("#Max possible average real stock percentage return per episode: " + str(np.mean(maxPossibleR_P_returnList)))

print ("#Max possible average option percentage return per episode: " + str(np.mean(maxPossibleOptionP_returnList)))

print ("#Max possible average real option percentage return per episode: " + str(np.mean(maxPossibleOptionR_P_returnList)))

print ("#Confidence Interval of Percentage of returns (Normalized) with prob of 90%: " + str(env.getConfidenceInterval(percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Normalized) with prob of 95%: " + str(env.getConfidenceInterval95(percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Real values) with prob of 90%: " + str(env.getConfidenceInterval(real_percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Real values) with prob of 95%: " + str(env.getConfidenceInterval95(real_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Normalized) with prob of 90%: " + str(env.getConfidenceInterval(option_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Normalized) with prob of 95%: " + str(env.getConfidenceInterval95(option_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Real values) with prob of 90%: " + str(env.getConfidenceInterval(option_real_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Real values) with prob of 95%: " + str(env.getConfidenceInterval95(option_real_percentage_rList)))

#print ("#Discounted rewards:")

#print ("#Total average reward per episode: " + str(sum(rList)/num_episodes * discount_factor))

#print ("#Max possible average reward per episode: " + str(np.mean(maxPossiblerList) * discount_factor))

end_time = time.time()
print('#Time to execute: '+ str((end_time - begin_time)/60) + 'min')
# Out:
# episode 100: 	0.022581448634089427	18.02	0
# episode 200: 	0.027417230396361805	19.5	0
# episode 300: 	0.031997202597456	20.98	0
# episode 400: 	0.02065658360285716	16.91	0
# episode 500: 	0.02775722507488879	19.87	0
# episode 600: 	0.02713543731829545	19.5	0
# episode 700: 	0.0266069804130894	18.39	0
# episode 800: 	0.03000183668807212	19.5	0
# episode 900: 	0.03066043113320444	19.87	0
# episode 1000: 	0.02202709380462718	16.91	0
# episode 1100: 	0.03549586296670482	19.87	0
# episode 1200: 	0.025254950387408846	19.87	0
# episode 1300: 	0.02418573369415695	14.69	0
# episode 1400: 	0.028573172015848906	18.76	0
# episode 1500: 	0.03514896746351186	21.72	0
# episode 1600: 	0.02395899407301606	17.28	0
# episode 1700: 	0.023593769099448866	16.91	0
# episode 1800: 	0.024141391913274895	18.02	0
# episode 1900: 	0.02727058881429777	18.39	0
# episode 2000: 	0.022743611287317562	16.17	0
# episode 2100: 	0.039647907439099114	24.31	0
# episode 2200: 	0.029955757792726582	20.24	0
# episode 2300: 	0.0343000650251394	20.61	0
# episode 2400: 	0.025224973519184627	19.13	0
# episode 2500: 	0.02935795766456626	17.28	0
# episode 2600: 	0.022686801225427135	17.28	0
# episode 2700: 	0.03073745162521195	19.87	0
# episode 2800: 	0.027518008063672852	19.5	0
# episode 2900: 	0.03569949628927664	20.61	0
# episode 3000: 	0.028055424589988845	16.91	0
# episode 3100: 	0.02927509702405782	19.13	0
# episode 3200: 	0.02603861743364347	18.02	0
# episode 3300: 	0.03036273073597257	19.5	0
# episode 3400: 	0.022488718467890408	16.91	0
# episode 3500: 	0.03342707751462171	20.61	0
# episode 3600: 	0.029505869661454	19.87	0
# episode 3700: 	0.03288684720735902	19.87	0
# episode 3800: 	0.031425607139283114	19.13	0
# episode 3900: 	0.030784839295156567	19.5	0
# episode 4000: 	0.025441141563418226	17.65	0
# episode 4100: 	0.03059297735126189	16.91	0
# episode 4200: 	0.025952688828434444	16.91	0
# episode 4300: 	0.03600454050522673	22.09	0
# episode 4400: 	0.023992169081558764	16.54	0
# episode 4500: 	0.027216591220970202	18.76	0
# episode 4600: 	0.026998564138168632	16.91	0
# episode 4700: 	0.02841421514013631	18.39	0
# episode 4800: 	0.02060135666393175	18.39	0
# episode 4900: 	0.029287147026235968	19.13	0
# episode 5000: 	0.022760846890642145	16.54	0
# #Average reward per episode 5000: 0.028076999950032835
# episode 5100: 	0.03258830770028537	19.13	0
# episode 5200: 	0.024717109055819853	16.91	0
# episode 5300: 	0.027446385571572324	18.76	0
# episode 5400: 	0.020712505122209665	17.28	0
# episode 5500: 	0.025985987449009963	18.39	0
# episode 5600: 	0.027933522811586797	20.24	0
# episode 5700: 	0.03127513973358717	19.5	0
# episode 5800: 	0.024373110870922046	15.8	0
# episode 5900: 	0.025091271806649093	19.13	0
# episode 6000: 	0.02089079125960398	15.8	0
# episode 6100: 	0.028906469562289868	19.13	0
# episode 6200: 	0.0224870728506243	17.28	0
# episode 6300: 	0.02739835031196334	18.76	0
# episode 6400: 	0.02616246039137536	17.65	0
# episode 6500: 	0.022195341931552353	17.65	0
# episode 6600: 	0.024883707349690854	16.91	0
# episode 6700: 	0.02578856894043625	18.76	0
# episode 6800: 	0.02694209727815498	19.5	0
# episode 6900: 	0.03336121508760525	21.35	0
# episode 7000: 	0.025636853591704475	18.02	0
# episode 7100: 	0.02636087847658713	17.65	0
# episode 7200: 	0.02233956290404117	17.65	0
# episode 7300: 	0.026342270864822295	19.13	0
# episode 7400: 	0.020150494358529066	17.65	0
# episode 7500: 	0.027408084420465016	20.98	0
# episode 7600: 	0.03216790858576024	18.76	0
# episode 7700: 	0.025862897778408656	18.76	0
# episode 7800: 	0.028943123843745013	18.76	0
# episode 7900: 	0.03339049782281314	19.5	0
# episode 8000: 	0.02058762115256417	17.28	0
# episode 8100: 	0.029629166725500023	19.5	0
# episode 8200: 	0.02734838730029616	19.5	0
# episode 8300: 	0.027443344620443944	19.5	0
# episode 8400: 	0.025591410178419604	15.8	0
# episode 8500: 	0.03965550157375262	21.35	0
# episode 8600: 	0.024836620443644507	16.91	0
# episode 8700: 	0.03735065809708313	19.5	0
# episode 8800: 	0.027613662604827845	16.54	0
# episode 8900: 	0.02968872611868296	19.5	0
# episode 9000: 	0.02529601804521337	17.28	0
# episode 9100: 	0.02918793959828236	20.24	0
# episode 9200: 	0.0231936194840884	16.91	0
# episode 9300: 	0.03202379995697265	19.5	0
# episode 9400: 	0.02931157514907279	19.87	0
# episode 9500: 	0.030441228594773034	20.98	0
# episode 9600: 	0.020928840768940436	16.17	0
# episode 9700: 	0.037201943034105324	20.98	0
# episode 9800: 	0.02099694706932415	16.54	0
# episode 9900: 	0.03072608568493911	19.13	0
# episode 10000: 	0.022894106551851624	17.28	0
# #Average reward per episode 10000: 0.027635391879862272
# episode 10100: 	0.030111242656616636	16.91	0
# episode 10200: 	0.025707415738146437	16.17	0
# episode 10300: 	0.030251744479426988	18.02	0
# episode 10400: 	0.03103578105917104	19.13	0
# episode 10500: 	0.026226135321595873	19.13	0
# episode 10600: 	0.02835139675202341	18.76	0
# episode 10700: 	0.030092617549178437	18.76	0
# episode 10800: 	0.029593423596604315	18.39	0
# episode 10900: 	0.0287353260144672	20.61	0
# episode 11000: 	0.022905397816750366	16.17	0
# episode 11100: 	0.03341560906816642	20.24	0
# episode 11200: 	0.01818299971361477	15.43	0
# episode 11300: 	0.03694711930283863	20.98	0
# episode 11400: 	0.028490847442010157	18.39	0
# episode 11500: 	0.031629290843303015	20.98	0
# episode 11600: 	0.02652327849797217	18.02	0
# episode 11700: 	0.030821997646216192	19.87	0
# episode 11800: 	0.025897004463536145	16.91	0
# episode 11900: 	0.031571857567463765	19.87	0
# episode 12000: 	0.025920060654480256	18.39	0
# episode 12100: 	0.0285968015444899	18.02	0
# episode 12200: 	0.02523524987943342	17.65	0
# episode 12300: 	0.02607525838573049	19.13	0
# episode 12400: 	0.027242717214021113	17.28	0
# episode 12500: 	0.03162034748787716	17.28	0
# episode 12600: 	0.021765296860105834	16.54	0
# episode 12700: 	0.031141022381838964	19.5	0
# episode 12800: 	0.020865360911589394	17.28	0
# episode 12900: 	0.02529030143766566	18.39	0
# episode 13000: 	0.023098583306642786	16.54	0
# episode 13100: 	0.03186897478196603	19.87	0
# episode 13200: 	0.02669460662756759	18.39	0
# episode 13300: 	0.031075099149798592	20.24	0
# episode 13400: 	0.019711676086151687	13.21	0
# episode 13500: 	0.028859790518083316	17.28	0
# episode 13600: 	0.024321603350135258	17.65	0
# episode 13700: 	0.02722771525689935	18.39	0
# episode 13800: 	0.027975255635708414	17.65	0
# episode 13900: 	0.03248318422823871	20.24	0
# episode 14000: 	0.025598789019901143	18.39	0
# episode 14100: 	0.029463741421406314	19.5	0
# episode 14200: 	0.02310992008742334	16.17	0
# episode 14300: 	0.0350450629172126	20.24	0
# episode 14400: 	0.02193107143183453	16.54	0
# episode 14500: 	0.03841979335045354	20.61	0
# episode 14600: 	0.024838278338626535	16.91	0
# episode 14700: 	0.03274228942879762	19.87	0
# episode 14800: 	0.023581481306073716	18.02	0
# episode 14900: 	0.033016878331940336	19.13	0
# episode 15000: 	0.023886972719836308	17.65	0
# #Average reward per episode 15000: 0.027724885717115053
# episode 15100: 	0.029346953924744342	19.5	0
# episode 15200: 	0.02850527226150426	18.02	0
# episode 15300: 	0.03666229304405985	23.2	0
# episode 15400: 	0.02478076650962728	16.17	0
# episode 15500: 	0.0342640444036594	23.2	0
# episode 15600: 	0.027469884951838414	18.02	0
# episode 15700: 	0.030014760265382915	19.5	0
# episode 15800: 	0.026529174438442733	18.39	0
# episode 15900: 	0.029952938847145127	18.76	0
# episode 16000: 	0.025836313101822248	17.65	0
# episode 16100: 	0.027272442944726808	19.5	0
# episode 16200: 	0.02225615882034854	15.43	0
# episode 16300: 	0.029137220279375237	20.61	0
# episode 16400: 	0.025806901730785883	19.13	0
# episode 16500: 	0.038028710032455344	21.35	0
# episode 16600: 	0.019973005218003954	15.43	0
# episode 16700: 	0.031886890533595	21.72	0
# episode 16800: 	0.026731352173044044	18.02	0
# episode 16900: 	0.032103055381294585	19.87	0
# episode 17000: 	0.023496186781344734	16.17	0
# episode 17100: 	0.02991266991990834	20.24	0
# episode 17200: 	0.025103843106432384	18.02	0
# episode 17300: 	0.027543196682893206	18.76	0
# episode 17400: 	0.029549162638273653	20.61	0
# episode 17500: 	0.02322856871061579	17.28	0
# episode 17600: 	0.022907070864005598	15.43	0
# episode 17700: 	0.02828635233993085	20.61	0
# episode 17800: 	0.022460426519764924	15.43	0
# episode 17900: 	0.03357747983865323	20.24	0
# episode 18000: 	0.023483003402674986	15.06	0
# episode 18100: 	0.0316929684355118	20.61	0
# episode 18200: 	0.0284497222121975	19.13	0
# episode 18300: 	0.029735632360399472	18.02	0
# episode 18400: 	0.02474676819783924	16.91	0
# episode 18500: 	0.033454830306251584	20.61	0
# episode 18600: 	0.02293781773609029	16.54	0
# episode 18700: 	0.031157365973861876	19.5	0
# episode 18800: 	0.02563000298610828	16.91	0
# episode 18900: 	0.02953449921782466	19.13	0
# episode 19000: 	0.02699766805188923	18.02	0
# episode 19100: 	0.03409549260223205	18.76	0
# episode 19200: 	0.02465455002683652	16.54	0
# episode 19300: 	0.02635451163942502	18.76	0
# episode 19400: 	0.028427283953361786	19.13	0
# episode 19500: 	0.02902671072379753	20.98	0
# episode 19600: 	0.02820104426739802	17.28	0
# episode 19700: 	0.03659798481210671	22.09	0
# episode 19800: 	0.023756190752162766	17.28	0
# episode 19900: 	0.03238877535643447	21.35	0
# episode 20000: 	0.026397331994728962	18.39	0
# #Average reward per episode 20000: 0.027845380544200344
# episode 20100: 	0.028596172863065678	22.09	0
# episode 20200: 	0.02128514372475091	14.32	0
# episode 20300: 	0.030909731824676	19.87	0
# episode 20400: 	0.024204035178562372	16.91	0
# episode 20500: 	0.03274305570100949	21.35	0
# episode 20600: 	0.025929107295909328	16.17	0
# episode 20700: 	0.029811415004732347	17.65	0
# episode 20800: 	0.02296810686625759	15.43	0
# episode 20900: 	0.026871759982729452	19.87	0
# episode 21000: 	0.02533195856896795	17.28	0
# episode 21100: 	0.030253866211750594	15.8	0
# episode 21200: 	0.025400007245793946	16.54	0
# episode 21300: 	0.032954555533818	22.09	0
# episode 21400: 	0.02430087492631337	16.54	0
# episode 21500: 	0.03275489788903038	19.13	0
# episode 21600: 	0.018136034513457067	14.69	0
# episode 21700: 	0.030536496085173077	20.98	0
# episode 21800: 	0.027506673362341316	17.28	0
# episode 21900: 	0.03490767397653396	20.61	0
# episode 22000: 	0.02515120611590891	17.65	0
# episode 22100: 	0.030081717609362367	19.13	0
# episode 22200: 	0.024546701636318356	16.91	0
# episode 22300: 	0.03138036100012118	17.28	0
# episode 22400: 	0.022463770754636153	15.8	0
# episode 22500: 	0.031852798083881737	20.98	0
# episode 22600: 	0.03001997558020281	16.91	0
# episode 22700: 	0.025816363043052196	19.87	0
# episode 22800: 	0.02498808340491248	16.54	0
# episode 22900: 	0.03483752204525429	20.61	0
# episode 23000: 	0.027254071680882123	18.76	0
# episode 23100: 	0.03546610019764767	20.98	0
# episode 23200: 	0.025108366295015467	15.06	0
# episode 23300: 	0.036798359989021104	20.61	0
# episode 23400: 	0.02365902622914386	17.28	0
# episode 23500: 	0.027432770725466068	20.24	0
# episode 23600: 	0.023740580244619044	17.28	0
# episode 23700: 	0.027744532753831038	19.13	0
# episode 23800: 	0.03119957868308387	18.76	0
# episode 23900: 	0.03340054779515282	19.13	0
# episode 24000: 	0.02565718268547898	17.65	0
# #Total average reward per episode: 0.027887822050616358
# #Max possible average reward per episode: 0.04991113693436689
# #Confidence Interval with prob of 90%: 0.00044472466951356505
# #Confidence Interval with prob of 95%: 0.0005299221286325325
# #Sell time entropy: 0.6917552533695535
# #Percentage of stock returns (Normalized): 0.03031564509707503
# #Percentage of stock returns (Real values): 0.03031564509707503
# #Percentage of option returns (Normalized): 0.13754272443469143
# #Percentage of option returns (Real values): 0.13754272443469134
# #Max possible average stock percentage return per episode: 0.05016143279455229
# #Max possible average real stock percentage return per episode: 0.05016143279455229
# #Max possible average option percentage return per episode: 0.8911531961300562
# #Max possible average real option percentage return per episode: 0.8911531961300562
# #Confidence Interval of Percentage of returns (Normalized) with prob of 90%: 0.0004355959782669392
# #Confidence Interval of Percentage of returns (Normalized) with prob of 95%: 0.0005190446221017337
# #Confidence Interval of Percentage of returns (Real values) with prob of 90%: 0.0004355959782669392
# #Confidence Interval of Percentage of returns (Real values) with prob of 95%: 0.0005190446221017337
# #Confidence Interval of Percentage of option returns (Normalized) with prob of 90%: 0.016580286085307223
# #Confidence Interval of Percentage of option returns (Normalized) with prob of 95%: 0.019756629433830775
# #Confidence Interval of Percentage of option returns (Real values) with prob of 90%: 0.016580286085307223
# #Confidence Interval of Percentage of option returns (Real values) with prob of 95%: 0.01975662943383077
# #Time to execute: 13.30935316880544min

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, AvgrList, color='red', label='Episode reward')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward / Ep Length')
plt.legend(loc='best')

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, np.array(AvgrList)*20, color='red', label='Episode reward x20')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward x20 / Ep Length')
plt.legend(loc='best')

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, np.array(AvgrList)*100, color='red', label='Episode reward x100')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward x100 / Ep Length')
plt.legend(loc='best')

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(range(len(sTimeList)), sTimeList, color='blue', label='Sell time')
plt.title('Sell time over time')
plt.xlabel('episodes')
plt.ylabel('Sell time')
plt.legend(loc='best');

# %% [markdown]
# # Validation part

# %%
#Generate stocks data
stocks_data, _ = GBM(num_seeds, is_training).generate_stock_paths(mu, sigma, 928, num_seeds, is_training)
stocks_train_data = []
stocks_test_data = []
real_stocks_train_data = []
real_stocks_test_data = []
for stock_data in stocks_data:
    #train_data, test_data = prepare_company_stock(stock_name, Normalization, Window_Normalization, scriptDirectory, test_data_ratio)
    #train_data, test_data, real_train_data, real_test_data = prepare_company_stock(stock_name, Normalization, Window_Normalization, scriptDirectory, test_data_ratio)
    train_data, test_data, real_train_data, real_test_data = prepare_company_stock(stock_data, Normalization, Window_Normalization, scriptDirectory, test_data_ratio)
    stocks_train_data.append(train_data)
    stocks_test_data.append(test_data)
    real_stocks_train_data.append(real_train_data)
    real_stocks_test_data.append(real_test_data)
    plt.plot(range(len(train_data)), train_data, color='b')
    plt.plot(range(len(train_data), len(train_data) + len(test_data)), test_data, color='r')
# Out:
# min value of data: 152.40072436906038, max value of data: 233.76779815686893
# train_size: 743
# test_size: 185
# min value of data: 141.69220585131188, max value of data: 224.2618146036533
# train_size: 743
# test_size: 185
# min value of data: 130.8036533100137, max value of data: 207.4614762731008
# train_size: 743
# test_size: 185
# min value of data: 59.36989414885515, max value of data: 102.90875728615067
# train_size: 743
# test_size: 185
# min value of data: 88.32482844060033, max value of data: 127.85678135456038
# train_size: 743
# test_size: 185
# min value of data: 131.8732349738424, max value of data: 188.89924331210884
# train_size: 743
# test_size: 185
# min value of data: 77.90661199501645, max value of data: 126.6348094962481
# train_size: 743
# test_size: 185
# min value of data: 54.63192490207038, max value of data: 97.24646621796207
# train_size: 743
# test_size: 185
# min value of data: 77.95062815511642, max value of data: 173.2507563827493
# train_size: 743
# test_size: 185
# min value of data: 146.10846847083647, max value of data: 279.4276671539772
# train_size: 743
# test_size: 185
# min value of data: 115.6181040721177, max value of data: 156.6034113779859
# train_size: 743
# test_size: 185
# min value of data: 90.01107697147637, max value of data: 210.9068219335946
# train_size: 743
# test_size: 185
# min value of data: 149.49748743718595, max value of data: 312.94655767715153
# train_size: 743
# test_size: 185
# min value of data: 153.193873393021, max value of data: 389.576786212124
# train_size: 743
# test_size: 185
# min value of data: 93.53679169457645, max value of data: 177.4518963008881
# train_size: 743
# test_size: 185
# min value of data: 123.93311265405842, max value of data: 231.68551288960415
# train_size: 743
# test_size: 185
# min value of data: 162.7432164509831, max value of data: 469.1194891768137
# train_size: 743
# test_size: 185
# min value of data: 104.47460707287203, max value of data: 166.93517576929042
# train_size: 743
# test_size: 185
# min value of data: 108.93899536261672, max value of data: 196.51580124769984
# train_size: 743
# test_size: 185
# min value of data: 67.86962397024826, max value of data: 106.11518490594872
# train_size: 743
# test_size: 185
# min value of data: 84.23887361593567, max value of data: 155.6849672876446
# train_size: 743
# test_size: 185
# min value of data: 173.6180904522613, max value of data: 280.729252725389
# train_size: 743
# test_size: 185
# min value of data: 48.03353567212544, max value of data: 76.89330663466026
# train_size: 743
# test_size: 185
# min value of data: 95.07513254482441, max value of data: 141.01319181492605
# train_size: 743
# test_size: 185
# min value of data: 49.20387731637072, max value of data: 78.62918360183075
# train_size: 743
# test_size: 185
# min value of data: 112.37438658718641, max value of data: 303.2253358697532
# train_size: 743
# test_size: 185
# min value of data: 112.20144255594266, max value of data: 525.2630630578499
# train_size: 743
# test_size: 185
# min value of data: 157.78335085841684, max value of data: 209.97740864297825
# train_size: 743
# test_size: 185
# min value of data: 137.25799446227592, max value of data: 297.7304638476533
# train_size: 743
# test_size: 185
# min value of data: 92.17627577133848, max value of data: 157.7414765737999
# train_size: 743
# test_size: 185
# min value of data: 158.87550791583104, max value of data: 302.3350304242494
# train_size: 743
# test_size: 185
# min value of data: 29.95647202783833, max value of data: 55.31567239360549
# train_size: 743
# test_size: 185
# min value of data: 121.46393194574074, max value of data: 176.21566221336664
# train_size: 743
# test_size: 185
# min value of data: 55.91338048974651, max value of data: 121.19170984922107
# train_size: 743
# test_size: 185
# min value of data: 177.97921987259863, max value of data: 439.92799809106714
# train_size: 743
# test_size: 185
# min value of data: 100.18936936121544, max value of data: 177.957362136006
# train_size: 743
# test_size: 185
# min value of data: 125.96885232095399, max value of data: 292.06991768873326
# train_size: 743
# test_size: 185
# min value of data: 125.22039528881415, max value of data: 198.58114576171076
# train_size: 743
# test_size: 185
# min value of data: 104.00428003899718, max value of data: 154.51585653241554
# train_size: 743
# test_size: 185
# min value of data: 130.75394794379355, max value of data: 188.71382540501784
# train_size: 743
# test_size: 185
# min value of data: 51.39955158784336, max value of data: 130.93421853498702
# train_size: 743
# test_size: 185
# min value of data: 70.34940478586833, max value of data: 104.85080054054212
# train_size: 743
# test_size: 185
# min value of data: 158.34970512485532, max value of data: 248.3857270912132
# train_size: 743
# test_size: 185
# min value of data: 65.44896020341514, max value of data: 137.3377449341127
# train_size: 743
# test_size: 185
# min value of data: 73.14036191809997, max value of data: 136.42191272696053
# train_size: 743
# test_size: 185
# min value of data: 191.2785267428132, max value of data: 405.3227015514731
# train_size: 743
# test_size: 185
# min value of data: 198.8992955269732, max value of data: 494.27396732946676
# train_size: 743
# test_size: 185
# min value of data: 71.76378786274898, max value of data: 107.52803104988564
# train_size: 743
# test_size: 185
# min value of data: 96.12494442576869, max value of data: 197.97927160418575
# train_size: 743
# test_size: 185
# min value of data: 85.44205988615425, max value of data: 143.76721103710986
# train_size: 743
# test_size: 185
# min value of data: 148.8868474336609, max value of data: 350.15603022667375
# train_size: 743
# test_size: 185
# min value of data: 94.67015665404558, max value of data: 173.38038025061869
# train_size: 743
# test_size: 185
# min value of data: 52.65951474290038, max value of data: 96.81334411718969
# train_size: 743
# test_size: 185
# min value of data: 43.95087085825662, max value of data: 96.20673599837282
# train_size: 743
# test_size: 185
# min value of data: 66.10000176592818, max value of data: 150.51531304081345
# train_size: 743
# test_size: 185
# min value of data: 141.98648788344707, max value of data: 289.7517440872629
# train_size: 743
# test_size: 185
# min value of data: 47.204008682970944, max value of data: 74.09516729477937
# train_size: 743
# test_size: 185
# min value of data: 89.25512124862036, max value of data: 144.426773594183
# train_size: 743
# test_size: 185
# min value of data: 183.42154986360327, max value of data: 499.128559820773
# train_size: 743
# test_size: 185
# min value of data: 96.41241753730816, max value of data: 189.44723618090453
# train_size: 743
# test_size: 185
# min value of data: 119.09465488964918, max value of data: 204.5524277053712
# train_size: 743
# test_size: 185
# min value of data: 59.03526037409647, max value of data: 116.42189635279054
# train_size: 743
# test_size: 185
# min value of data: 53.29379710454324, max value of data: 86.49071160276037
# train_size: 743
# test_size: 185
# min value of data: 49.5430884570747, max value of data: 154.8227178630091
# train_size: 743
# test_size: 185
# min value of data: 82.23229412576013, max value of data: 119.41873030560404
# train_size: 743
# test_size: 185
# min value of data: 97.26247896411371, max value of data: 245.15229267748646
# train_size: 743
# test_size: 185
# min value of data: 68.00733514095208, max value of data: 151.83040320140208
# train_size: 743
# test_size: 185
# min value of data: 84.44934958179199, max value of data: 167.1357327803976
# train_size: 743
# test_size: 185
# min value of data: 71.52813828543324, max value of data: 139.7400229957164
# train_size: 743
# test_size: 185
# min value of data: 80.62952255138065, max value of data: 125.11645903838159
# train_size: 743
# test_size: 185
# min value of data: 103.77386098804726, max value of data: 169.2974275670991
# train_size: 743
# test_size: 185
# min value of data: 155.79668328386452, max value of data: 250.69279095796847
# train_size: 743
# test_size: 185
# min value of data: 83.93528001246882, max value of data: 178.08712626861563
# train_size: 743
# test_size: 185
# min value of data: 35.407502212370346, max value of data: 81.98354001630597
# train_size: 743
# test_size: 185
# min value of data: 66.46473726939212, max value of data: 130.06875804891075
# train_size: 743
# test_size: 185
# min value of data: 36.31651660732352, max value of data: 71.85929648241206
# train_size: 743
# test_size: 185
# min value of data: 31.87545438636522, max value of data: 81.53286297573527
# train_size: 743
# test_size: 185
# min value of data: 178.98584210600865, max value of data: 311.47405756354226
# train_size: 743
# test_size: 185
# min value of data: 141.1473729001357, max value of data: 198.21775529872247
# train_size: 743
# test_size: 185
# min value of data: 68.16978476599832, max value of data: 112.84770257610235
# train_size: 743
# test_size: 185
# min value of data: 93.28819102969119, max value of data: 174.61792836919966
# train_size: 743
# test_size: 185
# min value of data: 55.55762760302912, max value of data: 78.59028450209541
# train_size: 743
# test_size: 185
# min value of data: 161.13561788365882, max value of data: 439.0931056000851
# train_size: 743
# test_size: 185
# min value of data: 93.71859296482413, max value of data: 183.44638807698828
# train_size: 743
# test_size: 185
# min value of data: 103.33726318541532, max value of data: 189.53407792853284
# train_size: 743
# test_size: 185
# min value of data: 97.75233128751273, max value of data: 155.27532479064885
# train_size: 743
# test_size: 185
# min value of data: 45.364811803299766, max value of data: 108.3700731680372
# train_size: 743
# test_size: 185
# min value of data: 86.60344345528735, max value of data: 150.71745533439366
# train_size: 743
# test_size: 185
# min value of data: 55.042062826868744, max value of data: 107.80398165823459
# train_size: 743
# test_size: 185
# min value of data: 146.4824120603015, max value of data: 279.4080718657436
# train_size: 743
# test_size: 185
# min value of data: 113.04772003837897, max value of data: 191.00850386959965
# train_size: 743
# test_size: 185
# min value of data: 86.29171171109184, max value of data: 120.9737810467554
# train_size: 743
# test_size: 185
# min value of data: 174.5390023271719, max value of data: 312.9928468391085
# train_size: 743
# test_size: 185
# min value of data: 104.68369112144221, max value of data: 175.69289535239443
# train_size: 743
# test_size: 185
# min value of data: 109.28802015299256, max value of data: 174.94161770636282
# train_size: 743
# test_size: 185
# min value of data: 112.84866302290418, max value of data: 215.01252479478413
# train_size: 743
# test_size: 185
# min value of data: 108.57876748415215, max value of data: 213.19667187028094
# train_size: 743
# test_size: 185
# min value of data: 112.04110375478699, max value of data: 186.3400028001162
# train_size: 743
# test_size: 185
# min value of data: 133.23786376966248, max value of data: 210.67681549178477
# train_size: 743
# test_size: 185
# min value of data: 153.65053380029548, max value of data: 414.551781775882
# train_size: 743
# test_size: 185
# min value of data: 66.8749917127207, max value of data: 165.1970053525847
# train_size: 743
# test_size: 185
# min value of data: 54.39786044029206, max value of data: 94.68913227115266
# train_size: 743
# test_size: 185
# min value of data: 80.10772302144335, max value of data: 153.27616916347188
# train_size: 743
# test_size: 185
# min value of data: 68.98046493509928, max value of data: 107.70637024934771
# train_size: 743
# test_size: 185
# min value of data: 104.6011297812822, max value of data: 173.55181389168428
# train_size: 743
# test_size: 185
# min value of data: 57.991450230760414, max value of data: 115.33476171919787
# train_size: 743
# test_size: 185
# min value of data: 62.6926744433595, max value of data: 117.25775894675766
# train_size: 743
# test_size: 185
# min value of data: 97.6947967462884, max value of data: 251.92030991800087
# train_size: 743
# test_size: 185
# min value of data: 115.78464667300229, max value of data: 160.64934923444667
# train_size: 743
# test_size: 185
# min value of data: 123.1843602554967, max value of data: 194.37244142888687
# train_size: 743
# test_size: 185
# min value of data: 157.67447507837167, max value of data: 221.68767313464852
# train_size: 743
# test_size: 185
# min value of data: 62.80383473758744, max value of data: 152.00886005696458
# train_size: 743
# test_size: 185
# min value of data: 67.85715125163566, max value of data: 122.25204393088559
# train_size: 743
# test_size: 185
# min value of data: 106.02849883694695, max value of data: 193.766214401511
# train_size: 743
# test_size: 185
# min value of data: 100.91038291871827, max value of data: 223.62047881094816
# train_size: 743
# test_size: 185
# min value of data: 150.0791203380526, max value of data: 217.15449580228795
# train_size: 743
# test_size: 185
# min value of data: 132.93464266031782, max value of data: 202.0412417589923
# train_size: 743
# test_size: 185
# min value of data: 109.52144153381298, max value of data: 227.8932990833371
# train_size: 743
# test_size: 185
# min value of data: 174.72336002731794, max value of data: 353.7974450589067
# train_size: 743
# test_size: 185
# min value of data: 97.62694868349331, max value of data: 201.74554502807044
# train_size: 743
# test_size: 185
# min value of data: 160.0502512562814, max value of data: 272.6181340103385
# train_size: 743
# test_size: 185
# min value of data: 47.686623150836986, max value of data: 70.91462379989574
# train_size: 743
# test_size: 185
# min value of data: 55.893750084861566, max value of data: 83.61382050144542
# train_size: 743
# test_size: 185
# min value of data: 59.37268197140098, max value of data: 111.4514923795649
# train_size: 743
# test_size: 185
# min value of data: 53.22479936075723, max value of data: 119.5221200489175
# train_size: 743
# test_size: 185
# min value of data: 41.048713218955555, max value of data: 92.21105527638191
# train_size: 743
# test_size: 185
# min value of data: 118.94766469609868, max value of data: 222.54240275129973
# train_size: 743
# test_size: 185
# min value of data: 54.32534110020789, max value of data: 81.60643967989152
# train_size: 743
# test_size: 185
# min value of data: 89.29449053621127, max value of data: 130.47579168838027
# train_size: 743
# test_size: 185
# min value of data: 54.67913922472096, max value of data: 86.93467336683418
# train_size: 743
# test_size: 185
# min value of data: 107.21404250840196, max value of data: 159.17737786925386
# train_size: 743
# test_size: 185
# min value of data: 33.62764968010982, max value of data: 66.0375851110628
# train_size: 743
# test_size: 185
# min value of data: 51.64499464233918, max value of data: 79.16630896556289
# train_size: 743
# test_size: 185
# min value of data: 147.32448164503228, max value of data: 333.5902385961704
# train_size: 743
# test_size: 185
# min value of data: 49.29452676189582, max value of data: 91.73126199887224
# train_size: 743
# test_size: 185
# min value of data: 123.00497374230413, max value of data: 184.16931175766496
# train_size: 743
# test_size: 185
# min value of data: 65.4951999683317, max value of data: 90.14806541217219
# train_size: 743
# test_size: 185
# min value of data: 134.06406942748805, max value of data: 228.18734375557443
# train_size: 743
# test_size: 185
# min value of data: 47.18128871730688, max value of data: 92.38344129493338
# train_size: 743
# test_size: 185
# min value of data: 31.902911908244715, max value of data: 51.349554354407786
# train_size: 743
# test_size: 185
# min value of data: 106.78156702370018, max value of data: 190.71988331186535
# train_size: 743
# test_size: 185
# min value of data: 107.48985989849305, max value of data: 240.83115560864871
# train_size: 743
# test_size: 185
# min value of data: 100.4082954686965, max value of data: 151.13786745655764
# train_size: 743
# test_size: 185
# min value of data: 66.00244159683767, max value of data: 114.68946759911024
# train_size: 743
# test_size: 185
# min value of data: 56.936728767912015, max value of data: 101.6025943030025
# train_size: 743
# test_size: 185
# min value of data: 126.31462613253709, max value of data: 189.8326172118702
# train_size: 743
# test_size: 185
# min value of data: 133.8807891817072, max value of data: 282.5236125860134
# train_size: 743
# test_size: 185
# min value of data: 177.96413605755274, max value of data: 314.03357561070277
# train_size: 743
# test_size: 185
# min value of data: 154.54123828312188, max value of data: 260.2597909725769
# train_size: 743
# test_size: 185
# min value of data: 71.92958038168433, max value of data: 123.59102040278482
# train_size: 743
# test_size: 185
# min value of data: 183.44507442508424, max value of data: 311.88908031171667
# train_size: 743
# test_size: 185
# min value of data: 193.46801456546055, max value of data: 396.9676944922025
# train_size: 743
# test_size: 185
# min value of data: 140.7092402890418, max value of data: 211.92021066690066
# train_size: 743
# test_size: 185
# min value of data: 97.2794726557984, max value of data: 229.84546200315148
# train_size: 743
# test_size: 185
# min value of data: 81.37349826661935, max value of data: 138.6671896620452
# train_size: 743
# test_size: 185
# min value of data: 150.7317138895337, max value of data: 275.4462032259199
# train_size: 743
# test_size: 185
# min value of data: 33.39309810090488, max value of data: 75.76172460609332
# train_size: 743
# test_size: 185
# min value of data: 54.52261306532663, max value of data: 182.0792842075352
# train_size: 743
# test_size: 185
# min value of data: 159.85484249178398, max value of data: 336.9593650311826
# train_size: 743
# test_size: 185
# min value of data: 132.92409118084547, max value of data: 214.9864510139589
# train_size: 743
# test_size: 185
# min value of data: 82.498447361785, max value of data: 147.01898061466184
# train_size: 743
# test_size: 185
# min value of data: 124.83166205649894, max value of data: 248.28669451167272
# train_size: 743
# test_size: 185
# min value of data: 78.25082339748619, max value of data: 104.43318642251651
# train_size: 743
# test_size: 185
# min value of data: 99.3724345982362, max value of data: 152.67583928750116
# train_size: 743
# test_size: 185
# min value of data: 93.88739791594143, max value of data: 183.9575353935358
# train_size: 743
# test_size: 185
# min value of data: 146.79717031565622, max value of data: 287.9746753665733
# train_size: 743
# test_size: 185
# min value of data: 133.68164867158262, max value of data: 210.24403921076353
# train_size: 743
# test_size: 185
# min value of data: 65.07537688442211, max value of data: 95.54483938198484
# train_size: 743
# test_size: 185
# min value of data: 121.04482633087339, max value of data: 191.55006663884103
# train_size: 743
# test_size: 185
# min value of data: 53.677016615265195, max value of data: 83.93174399144114
# train_size: 743
# test_size: 185
# min value of data: 143.63926409079738, max value of data: 243.4885729415757
# train_size: 743
# test_size: 185
# min value of data: 99.37519098988429, max value of data: 161.38345802931687
# train_size: 743
# test_size: 185
# min value of data: 56.83374971380317, max value of data: 156.15356697233582
# train_size: 743
# test_size: 185
# min value of data: 88.22766876198095, max value of data: 153.45519245843744
# train_size: 743
# test_size: 185
# min value of data: 176.10479238880978, max value of data: 356.6945638162651
# train_size: 743
# test_size: 185
# min value of data: 126.04317611795958, max value of data: 204.62504776312468
# train_size: 743
# test_size: 185
# min value of data: 42.16936467013651, max value of data: 95.1535689607079
# train_size: 743
# test_size: 185
# min value of data: 127.9723289543816, max value of data: 204.86580166529413
# train_size: 743
# test_size: 185
# min value of data: 100.32827231488793, max value of data: 194.9299677856505
# train_size: 743
# test_size: 185
# min value of data: 118.3281000569269, max value of data: 187.18592964824123
# train_size: 743
# test_size: 185
# min value of data: 80.74909609668583, max value of data: 215.09001523096885
# train_size: 743
# test_size: 185
# min value of data: 85.99950370748677, max value of data: 156.48669220534805
# train_size: 743
# test_size: 185
# min value of data: 83.10320896083245, max value of data: 182.2989465063999
# train_size: 743
# test_size: 185
# min value of data: 99.13068615982537, max value of data: 156.46628802438272
# train_size: 743
# test_size: 185
# min value of data: 95.41750846967844, max value of data: 181.75110600099617
# train_size: 743
# test_size: 185
# min value of data: 89.0035458912678, max value of data: 171.22985557633888
# train_size: 743
# test_size: 185
# min value of data: 56.96111276198021, max value of data: 100.77502632201188
# train_size: 743
# test_size: 185
# min value of data: 143.93650671836096, max value of data: 216.92154652210087
# train_size: 743
# test_size: 185
# min value of data: 110.477473084887, max value of data: 198.16416988713775
# train_size: 743
# test_size: 185
# min value of data: 81.01800046552258, max value of data: 162.8792969692057
# train_size: 743
# test_size: 185
# min value of data: 66.55293975394211, max value of data: 125.8059697031787
# train_size: 743
# test_size: 185
# min value of data: 150.3870225981903, max value of data: 220.77485737403393
# train_size: 743
# test_size: 185
# min value of data: 55.5790369532008, max value of data: 90.84062751173305
# train_size: 743
# test_size: 185
# min value of data: 51.956689279535325, max value of data: 97.29291093823741
# train_size: 743
# test_size: 185
# min value of data: 70.79174105266002, max value of data: 177.21529615021828
# train_size: 743
# test_size: 185
# min value of data: 151.88409620636935, max value of data: 237.10037061876446
# train_size: 743
# test_size: 185
# min value of data: 121.66977787256279, max value of data: 286.61490903608683
# train_size: 743
# test_size: 185
# min value of data: 119.85347006782499, max value of data: 220.0846046649749
# train_size: 743
# test_size: 185
# min value of data: 48.276210636440624, max value of data: 81.39092009840992
# train_size: 743
# test_size: 185
# min value of data: 82.18749191096272, max value of data: 150.4874000630351
# train_size: 743
# test_size: 185

# %%
env = StockEnv(stocks_test_data, real_stocks_test_data, risk_free_rate, history_t=history_t, option_T=option_T)
#max_num_observations = env.max_num_observations
num_batch_episodes_per_epoch = env.get_total_num_episodes_per_epoch() // batch_size
num_episodes = env.get_total_num_episodes_per_epoch()
print('num_batch_episodes_per_epoch: ' + str(num_batch_episodes_per_epoch))
print('num_episodes_per_epoch: ' + str(env.get_total_num_episodes_per_epoch()))
print('min value of stock: '+str(min(test_data)) + ', max value of stock: '+str(max(test_data)))
plt.plot(range(len(test_data)), test_data, color='b')
# Out:
# ###############################
# option_T: 50
# history_t: 15
# build_warm_up_state_t: 12
# ###############################
# num_batch_episodes_per_epoch: 375
# num_episodes_per_epoch: 24000
# min value of stock: 126.41322951712296, max value of stock: 140.16641891411143

# %%
begin_time = time.time()
tf.reset_default_graph()

mainQN = Qnetwork('main')
targetQN = Qnetwork('target')


init = tf.global_variables_initializer()

saver = tf.train.Saver(max_to_keep=2)

myBuffer = experience_buffer()

#create lists to contain total rewards and steps per episode
jList = []
rList = []
sTimeList = [] # sell time list

percentage_rList = []
real_percentage_rList = []

option_percentage_rList = []
option_real_percentage_rList = []

# Average metrics per 100 episodes
AvgEpisodeList = []
AvgrList = []
AvgsTimeList = []
maxPossiblerList = []

maxPossibleP_returnList = []
maxPossibleR_P_returnList = []

maxPossibleOptionP_returnList = []
maxPossibleOptionR_P_returnList = []

#num_short_sell = 0

#Make a path for our model to be saved in.
if not os.path.exists(path):
    os.makedirs(path) 
  

with tf.Session() as sess, tf.device('/gpu:1'):
    set_seed(seed)
    if load_model == True:
        print ('Loading Model...')
        #ckpt = tf.train.get_checkpoint_state(path)
        #saver.restore(sess,ckpt.model_checkpoint_path)
        saver.restore(sess,final_trained_model_name)
    else:
        sess.run(init)
    
    for i in range(num_episodes):
        episodeBuffer = []
        #Reset environment and get first new observation
        sP = env.reset()
        s = processState(sP, input_size)
        d = False
        rAll = 0
        j = 0
        #Reset the recurrent layer's hidden state
        state = np.zeros((num_layers, 2, 1, h_size))
        while j < max_epLength: 

            if j == max_epLength - 1 and env.is_episode_finished() == False:
                a = 1
            else:
                a, state1 = sess.run([mainQN.predict,mainQN.rnn_state],\
                        feed_dict={mainQN.scalarInput:[s],mainQN.trainLength:1,mainQN.state_in:state,mainQN.batch_size:1})
                if env.get_time() < build_warm_up_state_t:
                    a = 0 #hold
                elif env.get_payoff() <= 0:
                    a = 0 #hold
                    #num_short_sell += 1
                else:
                    a = a[0]
                
            s1P,r,d = env.step(a)
            
            s1 = processState(s1P, input_size)
            
            episodeBuffer.append(np.reshape(np.array([s,a,r,s1,d]),[1,5])) # store experience

            rAll += r
            s = s1
            sP = s1P
            state = state1
            j+=1 # episode length till selling or reaching last day of option

            if env.is_episode_finished():
                break
        
        myBuffer.add(episodeBuffer)
        jList.append(j)
        rList.append(rAll)
        sTimeList.append(env.get_sell_time() + 1)
        #maxPossiblerList.append(env.get_best_possible_reward())
        #best_reward, percentage_return, real_percentage_return = env.get_best_possible_reward()
        best_reward, stock_percentage_return, option_percentage_return, stock_real_percentage_return,\
        option_real_percentage_return = env.get_best_possible_reward()
        
        maxPossiblerList.append(best_reward)
        maxPossibleP_returnList.append(stock_percentage_return)
        maxPossibleR_P_returnList.append(stock_real_percentage_return)
        maxPossibleOptionP_returnList.append(option_percentage_return)
        maxPossibleOptionR_P_returnList.append(option_real_percentage_return)
        #real_percentage_rList.append(env.get_real_percentage_return())
        stock_percentage_return, option_percentage_return = env.get_percentage_return()
        percentage_rList.append(stock_percentage_return)
        option_percentage_rList.append(option_percentage_return)
        stock_percentage_return, option_percentage_return = env.get_real_percentage_return()
        real_percentage_rList.append(stock_percentage_return)
        option_real_percentage_rList.append(option_percentage_return)

        #Periodically print metrics. 
        if len(rList) % summaryLength == 0 and len(rList) != 0:
            AvgR = np.mean(rList[-summaryLength:])
            AvgsT = np.mean(sTimeList[-summaryLength:])
            AvgEpisodeList.append(i+1)
            AvgrList.append(AvgR)
            AvgsTimeList.append(AvgsT)
            print('episode ' + str(i+1) + ': \t' + str(AvgR) 
                  + '\t' + str(AvgsT))
            
        if len(rList) % summaryAverageReward == 0 and len(rList) != 0:
            print ("#Average reward per episode " + str(i+1) + ": " + str(sum(rList)/len(rList)))
                
option_percentage_rList = [value for value in option_percentage_rList if not math.isnan(value)]
maxPossibleOptionP_returnList = [value for value in maxPossibleOptionP_returnList if not math.isnan(value)]

print ("#Total average reward per episode: " + str(sum(rList)/num_episodes))

print ("#Max possible average reward per episode: " + str(np.mean(maxPossiblerList)))

print ("#Confidence Interval with prob of 90%: " + str(env.getConfidenceInterval(rList)))

print ("#Confidence Interval with prob of 95%: " + str(env.getConfidenceInterval95(rList)))

print ("#Sell time entropy: " + str(env.getEntropy(sTimeList)))

print ("#Percentage of stock returns (Normalized): " + str(np.mean(percentage_rList)))

print ("#Percentage of stock returns (Real values): " + str(np.mean(real_percentage_rList)))

print ("#Percentage of option returns (Normalized): " + str(np.mean(option_percentage_rList)))

print ("#Percentage of option returns (Real values): " + str(np.mean(option_real_percentage_rList)))

print ("#Max possible average stock percentage return per episode: " + str(np.mean(maxPossibleP_returnList)))

print ("#Max possible average real stock percentage return per episode: " + str(np.mean(maxPossibleR_P_returnList)))

print ("#Max possible average option percentage return per episode: " + str(np.mean(maxPossibleOptionP_returnList)))

print ("#Max possible average real option percentage return per episode: " + str(np.mean(maxPossibleOptionR_P_returnList)))

print ("#Confidence Interval of Percentage of returns (Normalized) with prob of 90%: " + str(env.getConfidenceInterval(percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Normalized) with prob of 95%: " + str(env.getConfidenceInterval95(percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Real values) with prob of 90%: " + str(env.getConfidenceInterval(real_percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Real values) with prob of 95%: " + str(env.getConfidenceInterval95(real_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Normalized) with prob of 90%: " + str(env.getConfidenceInterval(option_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Normalized) with prob of 95%: " + str(env.getConfidenceInterval95(option_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Real values) with prob of 90%: " + str(env.getConfidenceInterval(option_real_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Real values) with prob of 95%: " + str(env.getConfidenceInterval95(option_real_percentage_rList)))

#print ("#Number of short selling: " + str(num_short_sell))

#print ("#Discounted rewards:")

#print ("#Total average reward per episode: " + str(sum(rList)/num_episodes * discount_factor))

#print ("#Max possible average reward per episode: " + str(np.mean(maxPossiblerList) * discount_factor))

end_time = time.time()
print('#Time to execute: '+ str((end_time - begin_time)/60) + 'min')
# Out:
# WARNING:tensorflow:Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2cc0169590>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2cc0169590>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2cc0169590>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2cc0169590>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2cc016c090>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2cc016c090>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2cc016c090>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2cc016c090>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2cc015ff90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2cc015ff90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2cc015ff90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2cc015ff90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67c633d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67c633d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67c633d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67c633d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2c67bf6790>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2c67bf6790>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2c67bf6790>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2c67bf6790>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d26774c90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d26774c90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d26774c90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d26774c90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c907fcb90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c907fcb90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c907fcb90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c907fcb90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67ebcbd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67ebcbd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67ebcbd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67ebcbd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67fc1410>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67fc1410>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67fc1410>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67fc1410>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2c90043e50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2c90043e50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2c90043e50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2c90043e50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# Loading Model...
# INFO:tensorflow:Restoring parameters from /misc/scratch05/patx/fathanab/Experiments_RL/normalizeFirstDay_seed_corrected_2019_11_21_shuffled_GBM_version/savedModel/C51_noSoft_arch0-option_T50-history_t15-num_episodes203400-softUpdateFalse-tau0.001-dropout0.19999999999999996True-num_layers3-freq30-batch64-capacity3000-lambda0.0025-final
# episode 100: 	0.034665130494463126	18.3
# episode 200: 	0.021575197459322	14.19
# episode 300: 	0.028939937131129433	19.58
# episode 400: 	0.020107411180764694	16.58
# episode 500: 	0.0274779431074447	18.22
# episode 600: 	0.03069546979402692	19.96
# episode 700: 	0.031582443022527024	17.41
# episode 800: 	0.028518700618726675	16.33
# episode 900: 	0.03476978902544378	20.94
# episode 1000: 	0.02367941483496453	18.79
# episode 1100: 	0.03789489353586938	18.87
# episode 1200: 	0.033376949012375416	20.21
# episode 1300: 	0.025726053339874374	17.24
# episode 1400: 	0.031138183466200838	16.75
# episode 1500: 	0.030573777960575508	19.41
# episode 1600: 	0.03316099220138092	21.05
# episode 1700: 	0.02783578503053971	16.56
# episode 1800: 	0.02626864351657616	15.76
# episode 1900: 	0.030638934974595064	19.92
# episode 2000: 	0.031784383418376326	20.58
# episode 2100: 	0.028001198309075628	17.17
# episode 2200: 	0.023870217329932605	17.26
# episode 2300: 	0.03201458270800676	18.38
# episode 2400: 	0.023985677662837265	17.01
# episode 2500: 	0.02706647754185118	17.33
# episode 2600: 	0.02499815266252448	17.1
# episode 2700: 	0.03063129870422024	18.65
# episode 2800: 	0.029892712230799246	19.12
# episode 2900: 	0.029159905105456737	20.32
# episode 3000: 	0.027180258327154327	18.41
# episode 3100: 	0.031471922164987225	19.44
# episode 3200: 	0.02573635886899782	16.78
# episode 3300: 	0.025698446864123255	17.66
# episode 3400: 	0.026280731079947786	17.7
# episode 3500: 	0.033214976577065174	19.38
# episode 3600: 	0.019795546893763723	16.14
# episode 3700: 	0.030081155904968748	19.88
# episode 3800: 	0.022548288823952566	17.04
# episode 3900: 	0.03067281986354106	18.76
# episode 4000: 	0.02180375408206505	16.27
# episode 4100: 	0.03616503747036199	20.4
# episode 4200: 	0.02723091207310543	16.54
# episode 4300: 	0.030567989442170068	15.76
# episode 4400: 	0.030920333591070617	16.95
# episode 4500: 	0.029083965126001022	17.91
# episode 4600: 	0.024562689269210822	17.4
# episode 4700: 	0.03146769143636835	18.34
# episode 4800: 	0.022990279443733993	18.85
# episode 4900: 	0.030281401286996676	18.1
# episode 5000: 	0.02373895902333715	15.09
# #Average reward per episode 5000: 0.028430475459856063
# episode 5100: 	0.0296578986167531	18.18
# episode 5200: 	0.023695608574872205	17.85
# episode 5300: 	0.02424566131889304	18.62
# episode 5400: 	0.023681127325871507	17.43
# episode 5500: 	0.02718364335215812	15.26
# episode 5600: 	0.026135016009934203	17.28
# episode 5700: 	0.03417322068867406	19.13
# episode 5800: 	0.02995279054109526	18.96
# episode 5900: 	0.02693338721297706	14.85
# episode 6000: 	0.025618969016530806	17.01
# episode 6100: 	0.03271571943961314	19.22
# episode 6200: 	0.02866582366886423	18.2
# episode 6300: 	0.030113790792449458	16.98
# episode 6400: 	0.0327777216185463	18.9
# episode 6500: 	0.02713207624033828	18.46
# episode 6600: 	0.02381392038163389	15.43
# episode 6700: 	0.029914291001416737	14.92
# episode 6800: 	0.028711548664536138	18.35
# episode 6900: 	0.029254531141642476	19.18
# episode 7000: 	0.02472429859839501	17.71
# episode 7100: 	0.029668226628680672	16.86
# episode 7200: 	0.02534442283638897	18.58
# episode 7300: 	0.03147719531700242	18.88
# episode 7400: 	0.024111219000747367	16.74
# episode 7500: 	0.028009823065940954	17.71
# episode 7600: 	0.022866724713167422	15.9
# episode 7700: 	0.03567690135311515	20.11
# episode 7800: 	0.024513206065373286	17.6
# episode 7900: 	0.03807139523048387	20.18
# episode 8000: 	0.025735769861585666	16.85
# episode 8100: 	0.03055131493940544	19.28
# episode 8200: 	0.02214115432760547	15.85
# episode 8300: 	0.02170949715965184	17.1
# episode 8400: 	0.02317374830136644	16.48
# episode 8500: 	0.023880387421723576	16.73
# episode 8600: 	0.025447027285389133	20.96
# episode 8700: 	0.029968664652107235	17.64
# episode 8800: 	0.023899976495271296	18.24
# episode 8900: 	0.02802095789293939	17.95
# episode 9000: 	0.029843311220054358	20.38
# episode 9100: 	0.028278156580732225	18.89
# episode 9200: 	0.027486503576631897	14.73
# episode 9300: 	0.031007925744962077	18.66
# episode 9400: 	0.027266037758284664	18.41
# episode 9500: 	0.03174620279943747	17.77
# episode 9600: 	0.023510459290293162	16.57
# episode 9700: 	0.03174100302764165	18.71
# episode 9800: 	0.026217081933418335	17.82
# episode 9900: 	0.0303750764438248	19.12
# episode 10000: 	0.027412342482843598	18.25
# #Average reward per episode 10000: 0.028097765306040627
# episode 10100: 	0.029492047934617557	19.98
# episode 10200: 	0.026203144798708954	17.8
# episode 10300: 	0.033060887062279595	19.13
# episode 10400: 	0.02800857088931209	20.05
# episode 10500: 	0.02881405746660147	20.94
# episode 10600: 	0.022808500337201113	16.14
# episode 10700: 	0.0330373768412995	18.77
# episode 10800: 	0.02764656224786399	19.04
# episode 10900: 	0.032596596814493874	18.49
# episode 11000: 	0.026387286852650956	16.91
# episode 11100: 	0.027640829267751025	16.61
# episode 11200: 	0.032186600201517285	17.59
# episode 11300: 	0.031886290004730686	18.94
# episode 11400: 	0.020920283974629493	15.99
# episode 11500: 	0.03477677886687722	18.95
# episode 11600: 	0.025660111590680375	16.61
# episode 11700: 	0.024228319512850763	16.2
# episode 11800: 	0.02243760556394018	17.62
# episode 11900: 	0.029642473649733346	19.01
# episode 12000: 	0.021631373978105942	17.8
# episode 12100: 	0.02794339930684405	15.6
# episode 12200: 	0.02712641092543658	17.57
# episode 12300: 	0.025116493384383456	17.14
# episode 12400: 	0.026713934587634814	16.7
# episode 12500: 	0.02430094097413977	16.15
# episode 12600: 	0.025932831928324507	16.51
# episode 12700: 	0.025985702510041377	18.79
# episode 12800: 	0.024897684078309765	15.87
# episode 12900: 	0.03239880784492242	17.81
# episode 13000: 	0.030063520062438863	18.34
# episode 13100: 	0.025171253885374164	19.08
# episode 13200: 	0.026747352094587153	16.75
# episode 13300: 	0.028499423850874433	17.71
# episode 13400: 	0.03360536349532161	18.19
# episode 13500: 	0.026396936754089547	18.62
# episode 13600: 	0.02673646914881628	18.87
# episode 13700: 	0.02921285775625599	18.23
# episode 13800: 	0.02816296726626999	17.83
# episode 13900: 	0.028935787613990547	18.68
# episode 14000: 	0.0273829007289768	17.18
# episode 14100: 	0.025472923375460577	15.98
# episode 14200: 	0.028428225384511716	17.78
# episode 14300: 	0.025257822659738163	15.78
# episode 14400: 	0.021103637299949084	17.46
# episode 14500: 	0.027929771782811766	17.7
# episode 14600: 	0.02588319729321677	18.19
# episode 14700: 	0.02053151957166294	14.19
# episode 14800: 	0.020664266005180395	15.22
# episode 14900: 	0.023948742061338176	18.2
# episode 15000: 	0.020950796832196413	12.65
# #Average reward per episode 15000: 0.02773562779282008
# episode 15100: 	0.028966683709238876	15.75
# episode 15200: 	0.0238754568219003	18.85
# episode 15300: 	0.032614936199537946	19.38
# episode 15400: 	0.02777384753786824	17.98
# episode 15500: 	0.032202531143230836	20.43
# episode 15600: 	0.02622598243852583	16.18
# episode 15700: 	0.029103172111963338	19.49
# episode 15800: 	0.027966465878717137	16.85
# episode 15900: 	0.02809874114854812	19.75
# episode 16000: 	0.031733330124734886	18.39
# episode 16100: 	0.02519040520138603	15.82
# episode 16200: 	0.02476729517258786	15.82
# episode 16300: 	0.031807811879535776	19.05
# episode 16400: 	0.028801930734102896	18.17
# episode 16500: 	0.03279587902550636	19.9
# episode 16600: 	0.029166221755903297	19.12
# episode 16700: 	0.03081369679914835	19.53
# episode 16800: 	0.024379067045557753	17.35
# episode 16900: 	0.01776009090301841	12.47
# episode 17000: 	0.020383775453026668	15.29
# episode 17100: 	0.023800059750486668	17.15
# episode 17200: 	0.029113063257663618	18.4
# episode 17300: 	0.025619960295304844	17.61
# episode 17400: 	0.02132017883234413	18.26
# episode 17500: 	0.02697786547662372	17.9
# episode 17600: 	0.02700449303612004	15.71
# episode 17700: 	0.025646493756656456	15.43
# episode 17800: 	0.024909731354430958	19.14
# episode 17900: 	0.028349960297242252	16.31
# episode 18000: 	0.031207037824862355	18.38
# episode 18100: 	0.03153051667839013	20.26
# episode 18200: 	0.026891484975933713	16.42
# episode 18300: 	0.03529063129339942	19.13
# episode 18400: 	0.026980084006655653	17.34
# episode 18500: 	0.022198908389109488	15.51
# episode 18600: 	0.023961133762674704	13.97
# episode 18700: 	0.027099487300625023	17.89
# episode 18800: 	0.030688685025522223	18.97
# episode 18900: 	0.02497975397385157	17.77
# episode 19000: 	0.023458238180775838	18.74
# episode 19100: 	0.026757020686076154	16.36
# episode 19200: 	0.02658139038839107	17.5
# episode 19300: 	0.03473840749156481	19.28
# episode 19400: 	0.03000223223384421	17.52
# episode 19500: 	0.02477530337892239	16.72
# episode 19600: 	0.022970809346357108	17.11
# episode 19700: 	0.02455551216419053	18.19
# episode 19800: 	0.025568592322164515	16.5
# episode 19900: 	0.03588307487485747	19.46
# episode 20000: 	0.024553847592519017	16.64
# #Average reward per episode 20000: 0.027640927239773003
# episode 20100: 	0.029591352516089412	18.65
# episode 20200: 	0.0310580495030563	18.05
# episode 20300: 	0.029392761301417023	14.87
# episode 20400: 	0.02242914678407632	15.54
# episode 20500: 	0.025608446028238228	18.34
# episode 20600: 	0.024473232268056918	15.2
# episode 20700: 	0.03015394588017734	19.76
# episode 20800: 	0.02813790605821713	15.46
# episode 20900: 	0.034508483661858984	19.72
# episode 21000: 	0.023278631064538854	15.99
# episode 21100: 	0.033123373552078485	19.84
# episode 21200: 	0.023979424023392645	15.5
# episode 21300: 	0.02741808361454084	15.8
# episode 21400: 	0.027091600534486004	17.54
# episode 21500: 	0.03461722794386608	18.05
# episode 21600: 	0.028258974900623082	18.73
# episode 21700: 	0.0375510554963862	22.1
# episode 21800: 	0.02631850787230801	18.51
# episode 21900: 	0.025825228039462668	16.72
# episode 22000: 	0.024299281355648756	15.05
# episode 22100: 	0.025875658377671504	16.06
# episode 22200: 	0.028594548517727435	19.69
# episode 22300: 	0.02989186865719568	17.96
# episode 22400: 	0.028205543050455	16.64
# episode 22500: 	0.03240634038874029	19.21
# episode 22600: 	0.027868999959135072	18.17
# episode 22700: 	0.033610701502756746	19.14
# episode 22800: 	0.023160225616145627	14.99
# episode 22900: 	0.024644627798649885	17.12
# episode 23000: 	0.028842586700340112	18.81
# episode 23100: 	0.02825884162456171	15.63
# episode 23200: 	0.03070485321831732	18.25
# episode 23300: 	0.025937501918921566	18.4
# episode 23400: 	0.024591629310863533	17.14
# episode 23500: 	0.027291433436412577	16.94
# episode 23600: 	0.022393330007066448	16.03
# episode 23700: 	0.0324096614389702	21.39
# episode 23800: 	0.027094174424947798	17.86
# episode 23900: 	0.029221343179319542	16.91
# episode 24000: 	0.025024237750313948	17.65
# #Total average reward per episode: 0.02771386778013179
# #Max possible average reward per episode: 0.050930774804006186
# #Confidence Interval with prob of 90%: 0.00041642132887930106
# #Confidence Interval with prob of 95%: 0.0004961966181212175
# #Sell time entropy: 1.6635434186750477
# #Percentage of stock returns (Normalized): 0.029963611703181292
# #Percentage of stock returns (Real values): 0.029963611703181292
# #Percentage of option returns (Normalized): 0.12861030947943322
# #Percentage of option returns (Real values): 0.12861030947943336
# #Max possible average stock percentage return per episode: 0.05118061146718081
# #Max possible average real stock percentage return per episode: 0.05118061146718081
# #Max possible average option percentage return per episode: 0.924461434885426
# #Max possible average real option percentage return per episode: 0.924461434885426
# #Confidence Interval of Percentage of returns (Normalized) with prob of 90%: 0.0004068318802307949
# #Confidence Interval of Percentage of returns (Normalized) with prob of 95%: 0.00048477008528285026
# #Confidence Interval of Percentage of returns (Real values) with prob of 90%: 0.0004068318802307949
# #Confidence Interval of Percentage of returns (Real values) with prob of 95%: 0.00048477008528285026
# #Confidence Interval of Percentage of option returns (Normalized) with prob of 90%: 0.015823603236086954
# #Confidence Interval of Percentage of option returns (Normalized) with prob of 95%: 0.01885498620680421
# #Confidence Interval of Percentage of option returns (Real values) with prob of 90%: 0.015823603236086954
# #Confidence Interval of Percentage of option returns (Real values) with prob of 95%: 0.01885498620680421
# #Time to execute: 71.91746572256088min

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, AvgrList, color='red', label='Episode reward')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward / Ep Length')
plt.legend(loc='best');

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, np.array(AvgrList)*20, color='red', label='Episode reward x20')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward x20 / Ep Length')
plt.legend(loc='best');

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, np.array(AvgrList)*100, color='red', label='Episode reward x100')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward x100 / Ep Length')
plt.legend(loc='best');

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(range(len(sTimeList)), sTimeList, color='blue', label='Sell time')
plt.title('Sell time over time')
plt.xlabel('episodes')
plt.ylabel('Sell time')
plt.legend(loc='best');

# %% [markdown]
# # Second Valid

# %%
env = StockEnv(stocks_train_data, real_stocks_train_data, risk_free_rate, history_t=history_t, option_T=option_T)
#max_num_observations = env.max_num_observations
num_batch_episodes_per_epoch = env.get_total_num_episodes_per_epoch() // batch_size
num_episodes = env.get_total_num_episodes_per_epoch()
print('num_batch_episodes_per_epoch: ' + str(num_batch_episodes_per_epoch))
print('num_episodes_per_epoch: ' + str(env.get_total_num_episodes_per_epoch()))
print('min value of stock: '+str(min(train_data)) + ', max value of stock: '+str(max(train_data)))
plt.plot(range(len(train_data)), train_data, color='b')
# Out:
# ###############################
# option_T: 50
# history_t: 15
# build_warm_up_state_t: 12
# ###############################
# num_batch_episodes_per_epoch: 2118
# num_episodes_per_epoch: 135600
# min value of stock: 82.18749191096272, max value of stock: 150.4874000630351

# %%
begin_time = time.time()
tf.reset_default_graph()

mainQN = Qnetwork('main')
targetQN = Qnetwork('target')


init = tf.global_variables_initializer()

saver = tf.train.Saver(max_to_keep=2)

myBuffer = experience_buffer()

#create lists to contain total rewards and steps per episode
jList = []
rList = []
sTimeList = [] # sell time list

percentage_rList = []
real_percentage_rList = []

option_percentage_rList = []
option_real_percentage_rList = []

# Average metrics per 100 episodes
AvgEpisodeList = []
AvgrList = []
AvgsTimeList = []
maxPossiblerList = []

maxPossibleP_returnList = []
maxPossibleR_P_returnList = []

maxPossibleOptionP_returnList = []
maxPossibleOptionR_P_returnList = []

#num_short_sell = 0

#Make a path for our model to be saved in.
if not os.path.exists(path):
    os.makedirs(path) 
  

with tf.Session() as sess, tf.device('/gpu:1'):
    set_seed(seed)
    if load_model == True:
        print ('Loading Model...')
        #ckpt = tf.train.get_checkpoint_state(path)
        #saver.restore(sess,ckpt.model_checkpoint_path)
        saver.restore(sess,final_trained_model_name)
    else:
        sess.run(init)
    
    for i in range(num_episodes):
        episodeBuffer = []
        #Reset environment and get first new observation
        sP = env.reset()
        s = processState(sP, input_size)
        d = False
        rAll = 0
        j = 0
        #Reset the recurrent layer's hidden state
        state = np.zeros((num_layers, 2, 1, h_size))
        while j < max_epLength: 

            if j == max_epLength - 1 and env.is_episode_finished() == False:
                a = 1
            else:
                a, state1 = sess.run([mainQN.predict,mainQN.rnn_state],\
                        feed_dict={mainQN.scalarInput:[s],mainQN.trainLength:1,mainQN.state_in:state,mainQN.batch_size:1})
                if env.get_time() < build_warm_up_state_t:
                    a = 0 #hold
                elif env.get_payoff() <= 0:
                    a = 0 #hold
                    #num_short_sell += 1
                else:
                    a = a[0]
                
            s1P,r,d = env.step(a)
            
            s1 = processState(s1P, input_size)
            
            episodeBuffer.append(np.reshape(np.array([s,a,r,s1,d]),[1,5])) # store experience

            rAll += r
            s = s1
            sP = s1P
            state = state1
            j+=1 # episode length till selling or reaching last day of option

            if env.is_episode_finished():
                break
        
        myBuffer.add(episodeBuffer)
        jList.append(j)
        rList.append(rAll)
        sTimeList.append(env.get_sell_time() + 1)
        #maxPossiblerList.append(env.get_best_possible_reward())
        #best_reward, percentage_return, real_percentage_return = env.get_best_possible_reward()
        best_reward, stock_percentage_return, option_percentage_return, stock_real_percentage_return,\
        option_real_percentage_return = env.get_best_possible_reward()
        
        maxPossiblerList.append(best_reward)
        maxPossibleP_returnList.append(stock_percentage_return)
        maxPossibleR_P_returnList.append(stock_real_percentage_return)
        maxPossibleOptionP_returnList.append(option_percentage_return)
        maxPossibleOptionR_P_returnList.append(option_real_percentage_return)
        #real_percentage_rList.append(env.get_real_percentage_return())
        stock_percentage_return, option_percentage_return = env.get_percentage_return()
        percentage_rList.append(stock_percentage_return)
        option_percentage_rList.append(option_percentage_return)
        stock_percentage_return, option_percentage_return = env.get_real_percentage_return()
        real_percentage_rList.append(stock_percentage_return)
        option_real_percentage_rList.append(option_percentage_return)

        #Periodically print metrics. 
        if len(rList) % summaryLength == 0 and len(rList) != 0:
            AvgR = np.mean(rList[-summaryLength:])
            AvgsT = np.mean(sTimeList[-summaryLength:])
            AvgEpisodeList.append(i+1)
            AvgrList.append(AvgR)
            AvgsTimeList.append(AvgsT)
            print('episode ' + str(i+1) + ': \t' + str(AvgR) 
                  + '\t' + str(AvgsT))
            
        if len(rList) % summaryAverageReward == 0 and len(rList) != 0:
            print ("#Average reward per episode " + str(i+1) + ": " + str(sum(rList)/len(rList)))
                
option_percentage_rList = [value for value in option_percentage_rList if not math.isnan(value)]
maxPossibleOptionP_returnList = [value for value in maxPossibleOptionP_returnList if not math.isnan(value)]

print ("#Total average reward per episode: " + str(sum(rList)/num_episodes))

print ("#Max possible average reward per episode: " + str(np.mean(maxPossiblerList)))

print ("#Confidence Interval with prob of 90%: " + str(env.getConfidenceInterval(rList)))

print ("#Confidence Interval with prob of 95%: " + str(env.getConfidenceInterval95(rList)))

print ("#Sell time entropy: " + str(env.getEntropy(sTimeList)))

print ("#Percentage of stock returns (Normalized): " + str(np.mean(percentage_rList)))

print ("#Percentage of stock returns (Real values): " + str(np.mean(real_percentage_rList)))

print ("#Percentage of option returns (Normalized): " + str(np.mean(option_percentage_rList)))

print ("#Percentage of option returns (Real values): " + str(np.mean(option_real_percentage_rList)))

print ("#Max possible average stock percentage return per episode: " + str(np.mean(maxPossibleP_returnList)))

print ("#Max possible average real stock percentage return per episode: " + str(np.mean(maxPossibleR_P_returnList)))

print ("#Max possible average option percentage return per episode: " + str(np.mean(maxPossibleOptionP_returnList)))

print ("#Max possible average real option percentage return per episode: " + str(np.mean(maxPossibleOptionR_P_returnList)))

print ("#Confidence Interval of Percentage of returns (Normalized) with prob of 90%: " + str(env.getConfidenceInterval(percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Normalized) with prob of 95%: " + str(env.getConfidenceInterval95(percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Real values) with prob of 90%: " + str(env.getConfidenceInterval(real_percentage_rList)))

print ("#Confidence Interval of Percentage of returns (Real values) with prob of 95%: " + str(env.getConfidenceInterval95(real_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Normalized) with prob of 90%: " + str(env.getConfidenceInterval(option_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Normalized) with prob of 95%: " + str(env.getConfidenceInterval95(option_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Real values) with prob of 90%: " + str(env.getConfidenceInterval(option_real_percentage_rList)))

print ("#Confidence Interval of Percentage of option returns (Real values) with prob of 95%: " + str(env.getConfidenceInterval95(option_real_percentage_rList)))

#print ("#Number of short selling: " + str(num_short_sell))

#print ("#Discounted rewards:")

#print ("#Total average reward per episode: " + str(sum(rList)/num_episodes * discount_factor))

#print ("#Max possible average reward per episode: " + str(np.mean(maxPossiblerList) * discount_factor))

end_time = time.time()
print('#Time to execute: '+ str((end_time - begin_time)/60) + 'min')
# Out:
# WARNING:tensorflow:Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d25dfe210>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d25dfe210>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d25dfe210>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d25dfe210>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67e82410>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67e82410>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67e82410>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67e82410>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d2678a110>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d2678a110>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d2678a110>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2d2678a110>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c651aead0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c651aead0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c651aead0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c651aead0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2cc06b0650>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2cc06b0650>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2cc06b0650>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2cc06b0650>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d100aca50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d100aca50>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d100aca50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7f2d100aca50>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67be2f90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67be2f90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67be2f90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c67be2f90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c644ffc90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c644ffc90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c644ffc90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c644ffc90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c6465c310>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c6465c310>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c6465c310>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMBlockCell.call of <tensorflow.contrib.cudnn_rnn.python.ops.cudnn_rnn_ops.CudnnCompatibleLSTMCell object at 0x7f2c6465c310>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2c64402050>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2c64402050>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2c64402050>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f2c64402050>>: AssertionError: Bad argument number for Name: 3, expecting 4
# Loading Model...
# INFO:tensorflow:Restoring parameters from /misc/scratch05/patx/fathanab/Experiments_RL/normalizeFirstDay_seed_corrected_2019_11_21_shuffled_GBM_version/savedModel/C51_noSoft_arch0-option_T50-history_t15-num_episodes203400-softUpdateFalse-tau0.001-dropout0.19999999999999996True-num_layers3-freq30-batch64-capacity3000-lambda0.0025-final
# episode 100: 	0.027232719935802674	17.12
# episode 200: 	0.02404429625150413	18.61
# episode 300: 	0.032277709366440616	18.39
# episode 400: 	0.027575422897042783	17.36
# episode 500: 	0.030288263135914265	18.94
# episode 600: 	0.031399944456414405	17.62
# episode 700: 	0.03306261499153517	17.58
# episode 800: 	0.029742168683859066	17.21
# episode 900: 	0.028648156243730884	16.05
# episode 1000: 	0.027705620820313234	16.53
# episode 1100: 	0.028535964458418724	18.19
# episode 1200: 	0.029227744847894244	16.46
# episode 1300: 	0.02668194574953401	18.34
# episode 1400: 	0.0288380532137504	18.85
# episode 1500: 	0.020946330252428487	15.05
# episode 1600: 	0.023191001563922616	14.73
# episode 1700: 	0.021518634758293128	14.93
# episode 1800: 	0.02837500891164521	17.26
# episode 1900: 	0.02667821796756227	18.2
# episode 2000: 	0.023292228555770483	16.7
# episode 2100: 	0.03326651115211311	18.9
# episode 2200: 	0.02466460176666243	14.58
# episode 2300: 	0.025446087896862746	17.87
# episode 2400: 	0.028177808129757374	18.27
# episode 2500: 	0.0191909766257325	12.5
# episode 2600: 	0.032946700315750706	19.18
# episode 2700: 	0.029662115554805468	17.07
# episode 2800: 	0.027057360291434983	18.65
# episode 2900: 	0.020975454759723493	18.8
# episode 3000: 	0.026106586169118307	17.97
# episode 3100: 	0.027252770456415342	17.44
# episode 3200: 	0.030150824874956062	19.59
# episode 3300: 	0.022728022904264837	15.51
# episode 3400: 	0.027428903925007915	14.05
# episode 3500: 	0.02839155630897689	13.99
# episode 3600: 	0.028733741974149875	19.35
# episode 3700: 	0.02474663525014402	15.61
# episode 3800: 	0.025673526101702353	16.18
# episode 3900: 	0.029137289323400845	20.72
# episode 4000: 	0.03764455475428578	20.8
# episode 4100: 	0.031728863820316346	18.59
# episode 4200: 	0.0320295858179422	16.15
# episode 4300: 	0.02412647915094468	16.12
# episode 4400: 	0.024951259031171104	18.02
# episode 4500: 	0.028471529176944912	18.85
# episode 4600: 	0.021748897771404742	14.43
# episode 4700: 	0.0279921252987971	16.55
# episode 4800: 	0.027359426540639484	17.24
# episode 4900: 	0.025328965566417422	17.16
# episode 5000: 	0.02768942055611766	15.66
# #Average reward per episode 5000: 0.02740141256655474
# episode 5100: 	0.023113980693021605	14.92
# episode 5200: 	0.02192646074609726	13.61
# episode 5300: 	0.02906839394044369	18.87
# episode 5400: 	0.030383834621074603	18.69
# episode 5500: 	0.029628420964278333	15.77
# episode 5600: 	0.03635973260884758	22.62
# episode 5700: 	0.0254286831654175	17.11
# episode 5800: 	0.03187045804070075	18.57
# episode 5900: 	0.02332246591353314	15.88
# episode 6000: 	0.02075606464901845	15.23
# episode 6100: 	0.021298678287498148	15.6
# episode 6200: 	0.028254219238612183	16.97
# episode 6300: 	0.030968082976237866	17.94
# episode 6400: 	0.026960298456519004	16.48
# episode 6500: 	0.02332139185827775	14.97
# episode 6600: 	0.026184731619842513	19.25
# episode 6700: 	0.02309984349670226	14.31
# episode 6800: 	0.023367839660913377	17.76
# episode 6900: 	0.0233835873431014	18.29
# episode 7000: 	0.02390157571987582	14.64
# episode 7100: 	0.02180718233519536	15.43
# episode 7200: 	0.027488658631339723	17.54
# episode 7300: 	0.02616485784209252	15.18
# episode 7400: 	0.026313447849571875	17.49
# episode 7500: 	0.025258478235416267	14.16
# episode 7600: 	0.03310204765178291	18.2
# episode 7700: 	0.027419715019923015	17.18
# episode 7800: 	0.021510247495694645	15.56
# episode 7900: 	0.03251606554186038	19.04
# episode 8000: 	0.018817951969253132	14.11
# episode 8100: 	0.027211044182256873	17.51
# episode 8200: 	0.02487546173399044	14.59
# episode 8300: 	0.026781777113661528	17.42
# episode 8400: 	0.03179266873462323	19.55
# episode 8500: 	0.03088305377179178	19.19
# episode 8600: 	0.025418275589503398	17.24
# episode 8700: 	0.03242006631045165	19.56
# episode 8800: 	0.02630294764892164	16.45
# episode 8900: 	0.025806330715768797	15.61
# episode 9000: 	0.023329794878038813	15.75
# episode 9100: 	0.024317489181922638	18.4
# episode 9200: 	0.034152972866036656	18.52
# episode 9300: 	0.030234377055919623	19.24
# episode 9400: 	0.022337681588917913	17.97
# episode 9500: 	0.02549488131501336	16.16
# episode 9600: 	0.026577628122386822	18.38
# episode 9700: 	0.022744080004010597	16.77
# episode 9800: 	0.031021382038720922	19.46
# episode 9900: 	0.020752895084152498	12.55
# episode 10000: 	0.025479599107992405	18.25
# #Average reward per episode 10000: 0.02691002431943955
# episode 10100: 	0.02731156743179163	18.27
# episode 10200: 	0.024960671416821897	18.27
# episode 10300: 	0.03327807774150902	16.15
# episode 10400: 	0.023207857090133507	14.46
# episode 10500: 	0.02342947036038643	15.54
# episode 10600: 	0.03169601545695818	19.31
# episode 10700: 	0.024053711362848954	16.74
# episode 10800: 	0.030920546398324523	19.99
# episode 10900: 	0.023416792658178906	17.33
# episode 11000: 	0.027709505076295188	18.18
# episode 11100: 	0.026646031261076203	16.26
# episode 11200: 	0.021120424492174696	16.51
# episode 11300: 	0.03083250498036423	20.31
# episode 11400: 	0.021628718647850244	17.35
# episode 11500: 	0.01942335972171604	15.22
# episode 11600: 	0.030203897939091822	18.72
# episode 11700: 	0.024375196620506006	16.92
# episode 11800: 	0.029702611872405093	19.8
# episode 11900: 	0.02769204874082789	18.18
# episode 12000: 	0.03135201266997793	22.0
# episode 12100: 	0.026839351948436344	18.41
# episode 12200: 	0.035147871084908314	18.16
# episode 12300: 	0.02416106475955342	17.22
# episode 12400: 	0.027736563977290768	18.81
# episode 12500: 	0.030698345717034274	19.17
# episode 12600: 	0.024961541632825063	16.74
# episode 12700: 	0.03480181905113467	18.63
# episode 12800: 	0.027065069455834877	14.68
# episode 12900: 	0.026009520113589736	18.65
# episode 13000: 	0.022695065043370422	13.64
# episode 13100: 	0.02811553808178465	17.52
# episode 13200: 	0.02160991112596365	16.11
# episode 13300: 	0.02733793832614693	17.13
# episode 13400: 	0.029538471341701653	15.76
# episode 13500: 	0.023668037831990868	17.15
# episode 13600: 	0.02979388792658456	16.6
# episode 13700: 	0.023125800112555175	13.63
# episode 13800: 	0.025563358596094224	18.59
# episode 13900: 	0.025931986630045922	15.76
# episode 14000: 	0.02636261729098959	16.67
# episode 14100: 	0.029883334999953902	18.6
# episode 14200: 	0.03417524522625301	19.42
# episode 14300: 	0.025179853910942924	15.07
# episode 14400: 	0.027147145152498338	18.31
# episode 14500: 	0.02875658624729444	17.29
# episode 14600: 	0.02625809628350828	17.53
# episode 14700: 	0.03146585370073535	18.79
# episode 14800: 	0.03030506515986542	17.97
# episode 14900: 	0.023613047321095707	14.31
# episode 15000: 	0.029894511142116685	16.76
# #Average reward per episode 15000: 0.02701203968716865
# episode 15100: 	0.029143601581721308	17.12
# episode 15200: 	0.02517346279866669	18.28
# episode 15300: 	0.02902251405365958	19.5
# episode 15400: 	0.031020834802923072	17.13
# episode 15500: 	0.021771009482721704	14.67
# episode 15600: 	0.02401116902547262	18.25
# episode 15700: 	0.024765759421707362	15.46
# episode 15800: 	0.0323622385120786	18.02
# episode 15900: 	0.0339821272107131	20.65
# episode 16000: 	0.024136065284276476	16.4
# episode 16100: 	0.02288997412365461	14.59
# episode 16200: 	0.028471358339904374	16.83
# episode 16300: 	0.02732677488011833	16.81
# episode 16400: 	0.030209396761772957	18.75
# episode 16500: 	0.02194798300427929	15.14
# episode 16600: 	0.032035395921171966	18.31
# episode 16700: 	0.024002829613415887	14.84
# episode 16800: 	0.02796365957488202	15.59
# episode 16900: 	0.02309306754214274	16.05
# episode 17000: 	0.03379114293845866	18.65
# episode 17100: 	0.03424842424132734	18.29
# episode 17200: 	0.02475914949105659	15.03
# episode 17300: 	0.025027028289648437	17.41
# episode 17400: 	0.031579241933920504	17.42
# episode 17500: 	0.022278481336642522	16.13
# episode 17600: 	0.027957717963207954	16.36
# episode 17700: 	0.026376532687332373	18.62
# episode 17800: 	0.02348982412565797	15.67
# episode 17900: 	0.02447811432284503	16.52
# episode 18000: 	0.03471722394548088	19.25
# episode 18100: 	0.03507826251126713	22.3
# episode 18200: 	0.02369132666147114	14.82
# episode 18300: 	0.030229956707354108	17.13
# episode 18400: 	0.03119950909277244	16.93
# episode 18500: 	0.02435432796075145	13.6
# episode 18600: 	0.03209485191901629	17.52
# episode 18700: 	0.032302807796998775	18.56
# episode 18800: 	0.02447296417000175	15.62
# episode 18900: 	0.02697526734434413	17.82
# episode 19000: 	0.023802699507559845	16.69
# episode 19100: 	0.027361800971886834	16.77
# episode 19200: 	0.028312231378955163	16.83
# episode 19300: 	0.023296909114946848	16.31
# episode 19400: 	0.03256423528818567	19.53
# episode 19500: 	0.025042669849093886	19.32
# episode 19600: 	0.026269139115853955	19.83
# episode 19700: 	0.03283779936827001	17.08
# episode 19800: 	0.022994070585886397	15.91
# episode 19900: 	0.026441050013173345	16.05
# episode 20000: 	0.024962517918900713	15.71
# #Average reward per episode 20000: 0.027140612267814224
# episode 20100: 	0.02549344608189954	17.14
# episode 20200: 	0.026526256818622723	14.74
# episode 20300: 	0.028976675325235002	17.42
# episode 20400: 	0.023085369094624927	14.31
# episode 20500: 	0.02551807471940055	15.41
# episode 20600: 	0.025556069598622916	15.94
# episode 20700: 	0.023922837771172167	13.07
# episode 20800: 	0.02581383609921717	15.86
# episode 20900: 	0.026263194533173405	18.01
# episode 21000: 	0.02343676534566866	15.94
# episode 21100: 	0.02835656158247354	15.26
# episode 21200: 	0.02905155442214066	19.13
# episode 21300: 	0.028209287869308562	14.75
# episode 21400: 	0.03289338162641351	19.24
# episode 21500: 	0.02686344705994462	17.4
# episode 21600: 	0.02883411260717686	18.0
# episode 21700: 	0.031020904566583473	16.32
# episode 21800: 	0.03264898167397465	18.88
# episode 21900: 	0.03135855157075103	18.14
# episode 22000: 	0.03198792206490011	18.89
# episode 22100: 	0.03564303446801071	20.74
# episode 22200: 	0.02675984790961342	16.78
# episode 22300: 	0.019423232363757047	14.78
# episode 22400: 	0.02449064974006104	14.37
# episode 22500: 	0.022849653013789203	17.86
# episode 22600: 	0.03376069522335273	20.04
# episode 22700: 	0.03724929862516863	18.53
# episode 22800: 	0.02652499325397003	17.89
# episode 22900: 	0.028757079863143666	16.32
# episode 23000: 	0.024000144583712354	16.39
# episode 23100: 	0.026272799430249186	17.59
# episode 23200: 	0.023127851137075536	14.36
# episode 23300: 	0.030185880205130747	17.39
# episode 23400: 	0.025226299125975765	18.15
# episode 23500: 	0.0254488043382463	17.09
# episode 23600: 	0.028488060016429582	17.7
# episode 23700: 	0.023050307620422567	15.51
# episode 23800: 	0.02322537944709767	17.62
# episode 23900: 	0.028964497972199795	17.56
# episode 24000: 	0.023111182016584936	14.97
# episode 24100: 	0.026797500902588527	15.07
# episode 24200: 	0.027663653299244927	18.0
# episode 24300: 	0.026402704417762612	19.5
# episode 24400: 	0.02172819261195567	17.0
# episode 24500: 	0.034889658689644026	19.47
# episode 24600: 	0.03120530713473126	16.65
# episode 24700: 	0.021340113099865086	16.73
# episode 24800: 	0.03059694881775172	20.81
# episode 24900: 	0.024380420802315606	16.43
# episode 25000: 	0.027182502365320476	16.49
# #Average reward per episode 25000: 0.027170745505957244
# episode 25100: 	0.0312080008711826	16.35
# episode 25200: 	0.025189420395883934	17.19
# episode 25300: 	0.03210059259501053	21.13
# episode 25400: 	0.028354409519418568	17.09
# episode 25500: 	0.030828270825460996	17.46
# episode 25600: 	0.025003430799014202	16.44
# episode 25700: 	0.030945687895572775	17.15
# episode 25800: 	0.02945551876191605	18.53
# episode 25900: 	0.02611610925640675	17.28
# episode 26000: 	0.025709484025620403	18.61
# episode 26100: 	0.023414528020599307	16.23
# episode 26200: 	0.022177228834549916	17.59
# episode 26300: 	0.032283376933054594	17.84
# episode 26400: 	0.025263453947578656	16.44
# episode 26500: 	0.030165926225096264	17.28
# episode 26600: 	0.028122078522881965	16.95
# episode 26700: 	0.02828390188511388	17.11
# episode 26800: 	0.03215679788257513	18.47
# episode 26900: 	0.026969340141251234	15.28
# episode 27000: 	0.02922224994201498	18.73
# episode 27100: 	0.027345089175199087	16.34
# episode 27200: 	0.027904003022973026	17.26
# episode 27300: 	0.03173641925319334	18.02
# episode 27400: 	0.025181161095587358	18.42
# episode 27500: 	0.026743954346725562	16.56
# episode 27600: 	0.027030432792505114	18.36
# episode 27700: 	0.0248154976438346	15.65
# episode 27800: 	0.027571468137638486	17.73
# episode 27900: 	0.03039640635509181	17.36
# episode 28000: 	0.024527820153881615	17.81
# episode 28100: 	0.030750903450317377	15.29
# episode 28200: 	0.028691135082842902	16.66
# episode 28300: 	0.029687005432781258	17.75
# episode 28400: 	0.025028570648383028	16.62
# episode 28500: 	0.028766368589049865	19.29
# episode 28600: 	0.022206503299735524	15.66
# episode 28700: 	0.025672862396658044	19.45
# episode 28800: 	0.02133589441792235	13.23
# episode 28900: 	0.026880252945271268	18.02
# episode 29000: 	0.021406752188638408	15.95
# episode 29100: 	0.026642775822856884	17.11
# episode 29200: 	0.026689371871711557	18.52
# episode 29300: 	0.027103417819686965	17.5
# episode 29400: 	0.028335285140335613	16.01
# episode 29500: 	0.024016464776153663	17.99
# episode 29600: 	0.030632510117686786	19.76
# episode 29700: 	0.024111655080940438	16.31
# episode 29800: 	0.025692496778940005	15.2
# episode 29900: 	0.03112084435363459	18.9
# episode 30000: 	0.027944658046180564	17.59
# #Average reward per episode 30000: 0.027205413880019614
# episode 30100: 	0.024588765165120915	18.03
# episode 30200: 	0.025365496830465673	15.52
# episode 30300: 	0.025996423686194436	17.54
# episode 30400: 	0.028519171385678742	19.8
# episode 30500: 	0.033061757015319305	15.95
# episode 30600: 	0.025795241300989452	16.12
# episode 30700: 	0.02693565916828476	15.73
# episode 30800: 	0.02868606527008472	16.16
# episode 30900: 	0.025932672437659753	15.94
# episode 31000: 	0.021368006529023188	15.57
# episode 31100: 	0.032286413293102	19.27
# episode 31200: 	0.028262186254162505	17.27
# episode 31300: 	0.02397490663200392	15.45
# episode 31400: 	0.026091071976010075	15.62
# episode 31500: 	0.02474709823678022	16.33
# episode 31600: 	0.03536840489883946	18.94
# episode 31700: 	0.0301334151246054	18.33
# episode 31800: 	0.022456979928626053	17.59
# episode 31900: 	0.02458410637784847	17.99
# episode 32000: 	0.030045849672675314	17.33
# episode 32100: 	0.0266481913480159	15.47
# episode 32200: 	0.028943681088420076	19.25
# episode 32300: 	0.02707826030268624	18.96
# episode 32400: 	0.022124780013385453	17.96
# episode 32500: 	0.023839422288849145	16.51
# episode 32600: 	0.025721816702314132	14.7
# episode 32700: 	0.0223669848437417	17.03
# episode 32800: 	0.029075912432393613	19.15
# episode 32900: 	0.024402621845492595	17.94
# episode 33000: 	0.025896678632833202	16.59
# episode 33100: 	0.020184853964018236	13.52
# episode 33200: 	0.023857444744353563	15.06
# episode 33300: 	0.019739324276296603	14.36
# episode 33400: 	0.03368701215649987	19.68
# episode 33500: 	0.024004035992307392	14.81
# episode 33600: 	0.02611542286195118	19.41
# episode 33700: 	0.030425521004347523	16.46
# episode 33800: 	0.03124927891481383	17.79
# episode 33900: 	0.025308944823637786	17.07
# episode 34000: 	0.0237758914555102	15.19
# episode 34100: 	0.03414242882085121	19.59
# episode 34200: 	0.03562263097430399	19.84
# episode 34300: 	0.028149296288794846	19.51
# episode 34400: 	0.019678402510646075	13.21
# episode 34500: 	0.022026109916242733	14.84
# episode 34600: 	0.030494014735463332	17.62
# episode 34700: 	0.03132802170916203	18.47
# episode 34800: 	0.03081631532612815	19.92
# episode 34900: 	0.024546021079568908	15.76
# episode 35000: 	0.02754737593872393	17.77
# #Average reward per episode 35000: 0.027156058720517476
# episode 35100: 	0.02375715744447807	17.26
# episode 35200: 	0.031404743280057164	16.82
# episode 35300: 	0.022405768120762157	13.68
# episode 35400: 	0.03345812701915797	19.19
# episode 35500: 	0.024744801042983093	20.23
# episode 35600: 	0.02905458355476203	15.07
# episode 35700: 	0.023872817101345544	16.75
# episode 35800: 	0.026634459135326912	18.35
# episode 35900: 	0.028575937437719624	17.92
# episode 36000: 	0.026553895371271858	19.19
# episode 36100: 	0.025424001078075992	16.85
# episode 36200: 	0.0258271541595688	17.67
# episode 36300: 	0.03254589538430582	16.89
# episode 36400: 	0.027119946018022083	17.14
# episode 36500: 	0.027280593850989035	14.85
# episode 36600: 	0.02587912651323408	16.78
# episode 36700: 	0.029076288999868295	16.68
# episode 36800: 	0.02670541124307354	15.86
# episode 36900: 	0.023267436240191394	14.16
# episode 37000: 	0.028096966530963628	17.56
# episode 37100: 	0.03012182600769377	16.82
# episode 37200: 	0.023201546903083382	16.66
# episode 37300: 	0.026073112535470705	19.16
# episode 37400: 	0.025828992736411784	16.31
# episode 37500: 	0.02989704998339658	18.73
# episode 37600: 	0.030959540631507805	17.89
# episode 37700: 	0.02747161488095597	18.4
# episode 37800: 	0.02292278144550064	16.43
# episode 37900: 	0.023171283523353504	16.58
# episode 38000: 	0.02817195226540353	16.7
# episode 38100: 	0.02862513101871089	16.93
# episode 38200: 	0.023195084265840497	15.59
# episode 38300: 	0.02210593349015166	13.96
# episode 38400: 	0.02375903990059245	16.0
# episode 38500: 	0.03307170305744852	19.31
# episode 38600: 	0.02445343009488675	15.55
# episode 38700: 	0.026674764146215925	16.48
# episode 38800: 	0.030274243295817575	18.17
# episode 38900: 	0.029930053877868224	18.04
# episode 39000: 	0.022077752234399835	14.4
# episode 39100: 	0.033283687836349295	19.89
# episode 39200: 	0.025034509324354436	15.3
# episode 39300: 	0.022207727856710945	14.8
# episode 39400: 	0.0303939585778347	17.69
# episode 39500: 	0.02632104145374371	17.29
# episode 39600: 	0.02428149244624571	16.06
# episode 39700: 	0.031730683610243386	17.42
# episode 39800: 	0.02778418373780505	17.48
# episode 39900: 	0.032379335566355874	18.26
# episode 40000: 	0.030496076880000545	17.28
# #Average reward per episode 40000: 0.027155512988229106
# episode 40100: 	0.026911346742341646	17.51
# episode 40200: 	0.022199781772328217	13.24
# episode 40300: 	0.029691349093950926	16.47
# episode 40400: 	0.03003633351815557	15.55
# episode 40500: 	0.024990273209667693	17.1
# episode 40600: 	0.02669819918484598	19.4
# episode 40700: 	0.025673447249662976	17.44
# episode 40800: 	0.0238845199027669	17.56
# episode 40900: 	0.025665017466118774	16.99
# episode 41000: 	0.02948235849872746	18.68
# episode 41100: 	0.023038388282816277	13.86
# episode 41200: 	0.029342195568593618	17.3
# episode 41300: 	0.023713616790054508	16.03
# episode 41400: 	0.025681296403738934	16.26
# episode 41500: 	0.030572243301824193	15.87
# episode 41600: 	0.025898570758488944	16.17
# episode 41700: 	0.03561358509177779	19.69
# episode 41800: 	0.02942454903596969	19.13
# episode 41900: 	0.023375068803567454	13.28
# episode 42000: 	0.030965985142764794	19.93
# episode 42100: 	0.0293896877267921	18.35
# episode 42200: 	0.028708371097291387	16.71
# episode 42300: 	0.02337764256791376	17.49
# episode 42400: 	0.026936353902611006	17.01
# episode 42500: 	0.02012366166838161	15.21
# episode 42600: 	0.0276458443602478	18.72
# episode 42700: 	0.017202287078909695	14.75
# episode 42800: 	0.022075232905094576	15.49
# episode 42900: 	0.02231375058823848	14.87
# episode 43000: 	0.025760037550241702	14.59
# episode 43100: 	0.027770677369379597	18.5
# episode 43200: 	0.03192069919683702	17.11
# episode 43300: 	0.023077132495227932	15.59
# episode 43400: 	0.0281147519197816	17.52
# episode 43500: 	0.025505091156283837	17.48
# episode 43600: 	0.028744073180661703	17.27
# episode 43700: 	0.023817917557627556	15.06
# episode 43800: 	0.029636280029023673	16.1
# episode 43900: 	0.025007738850550302	16.38
# episode 44000: 	0.028825465616193834	17.07
# episode 44100: 	0.025900142442679304	18.33
# episode 44200: 	0.029680912323242273	15.52
# episode 44300: 	0.022812482414508787	15.32
# episode 44400: 	0.028565027575270744	15.64
# episode 44500: 	0.02811938481119544	18.59
# episode 44600: 	0.02904088833735041	19.47
# episode 44700: 	0.02381777054562923	15.3
# episode 44800: 	0.028134319069263544	16.45
# episode 44900: 	0.026594205225357204	17.26
# episode 45000: 	0.031431462980352015	18.45
# #Average reward per episode 45000: 0.027100250252559858
# episode 45100: 	0.03261455454325239	18.58
# episode 45200: 	0.03158587670551377	17.53
# episode 45300: 	0.028387586681260703	17.1
# episode 45400: 	0.021276351288661944	16.98
# episode 45500: 	0.02838893858395043	16.4
# episode 45600: 	0.028747596154687326	16.36
# episode 45700: 	0.029490752708214635	18.93
# episode 45800: 	0.0253922729889366	17.57
# episode 45900: 	0.034207688128289365	17.04
# episode 46000: 	0.030039532011242986	17.0
# episode 46100: 	0.029975515270799814	18.79
# episode 46200: 	0.02647591711389162	18.42
# episode 46300: 	0.03390329268373151	20.33
# episode 46400: 	0.0299820892739442	17.04
# episode 46500: 	0.02922217888257561	17.78
# episode 46600: 	0.028706996299487336	19.92
# episode 46700: 	0.02530611625975132	15.81
# episode 46800: 	0.027936915453045382	16.22
# episode 46900: 	0.019475352901954332	13.35
# episode 47000: 	0.03021118338204819	17.8
# episode 47100: 	0.025628953995409497	15.78
# episode 47200: 	0.022948584478219253	17.12
# episode 47300: 	0.028170951205907836	16.39
# episode 47400: 	0.030982023359472307	17.91
# episode 47500: 	0.029834779544564986	16.4
# episode 47600: 	0.026923149100784624	18.39
# episode 47700: 	0.029236903781758236	18.14
# episode 47800: 	0.021819711245293846	15.23
# episode 47900: 	0.03146675087324098	19.65
# episode 48000: 	0.031661175154041946	19.57
# episode 48100: 	0.02866651019994283	17.93
# episode 48200: 	0.023645735136598036	15.54
# episode 48300: 	0.031468068220326245	18.14
# episode 48400: 	0.022784520708430307	16.46
# episode 48500: 	0.02871973294501451	18.02
# episode 48600: 	0.03170324090939883	16.86
# episode 48700: 	0.029761694147714967	19.57
# episode 48800: 	0.02276747623260084	14.88
# episode 48900: 	0.027088373168360755	15.54
# episode 49000: 	0.027770899090938977	19.14
# episode 49100: 	0.028497550865817463	17.67
# episode 49200: 	0.02484307267978396	16.25
# episode 49300: 	0.026687229705921075	18.6
# episode 49400: 	0.024442079164827758	17.14
# episode 49500: 	0.03303514608687386	18.33
# episode 49600: 	0.03078917586705378	16.89
# episode 49700: 	0.02951347764976565	17.78
# episode 49800: 	0.027900620106526178	17.61
# episode 49900: 	0.030690819627092632	20.13
# episode 50000: 	0.022962996782447648	16.94
# #Average reward per episode 50000: 0.027197701446002566
# episode 50100: 	0.02858718333689252	17.95
# episode 50200: 	0.02570414545934701	17.4
# episode 50300: 	0.02405336579276066	13.97
# episode 50400: 	0.027417875653859988	17.08
# episode 50500: 	0.03170416544724779	17.85
# episode 50600: 	0.029033381355336677	18.9
# episode 50700: 	0.022028255636143305	14.34
# episode 50800: 	0.019817301196651996	13.1
# episode 50900: 	0.025904398003172506	14.99
# episode 51000: 	0.03327738439979303	18.93
# episode 51100: 	0.02219703986525954	15.17
# episode 51200: 	0.03280371692332591	19.51
# episode 51300: 	0.023002000397174673	17.2
# episode 51400: 	0.024380870557817073	14.9
# episode 51500: 	0.02705582306643358	16.89
# episode 51600: 	0.029695636577942063	19.59
# episode 51700: 	0.022175462651504114	17.36
# episode 51800: 	0.024980827138216494	15.14
# episode 51900: 	0.026263928916801235	17.15
# episode 52000: 	0.03153648284532046	19.39
# episode 52100: 	0.022978929642444773	15.45
# episode 52200: 	0.029341575692042352	19.49
# episode 52300: 	0.028293562636330892	16.68
# episode 52400: 	0.02063512629273995	16.53
# episode 52500: 	0.026470995372400746	14.34
# episode 52600: 	0.028089147558068506	17.31
# episode 52700: 	0.02369828047769946	16.31
# episode 52800: 	0.02508310070711439	16.18
# episode 52900: 	0.032321771683373884	17.47
# episode 53000: 	0.026988071302834822	15.06
# episode 53100: 	0.030620679830570624	17.7
# episode 53200: 	0.02474436068516633	14.54
# episode 53300: 	0.02755240507557542	19.16
# episode 53400: 	0.02744114108703601	16.86
# episode 53500: 	0.03293982833415532	16.88
# episode 53600: 	0.031013754670745533	16.46
# episode 53700: 	0.025002541104388314	14.55
# episode 53800: 	0.03051150100237576	17.19
# episode 53900: 	0.031637142267030766	18.62
# episode 54000: 	0.028004700376198226	18.47
# episode 54100: 	0.022730478078997685	15.95
# episode 54200: 	0.031134730495683577	21.82
# episode 54300: 	0.02203037840956062	17.04
# episode 54400: 	0.01876192210930193	15.79
# episode 54500: 	0.029129829129431094	18.33
# episode 54600: 	0.025442708174415418	19.53
# episode 54700: 	0.029405169659808935	16.61
# episode 54800: 	0.021049791739901572	13.0
# episode 54900: 	0.021540142747953465	14.31
# episode 55000: 	0.025951964562388415	19.13
# #Average reward per episode 55000: 0.027147301271141767
# episode 55100: 	0.029530156916785025	18.52
# episode 55200: 	0.024147906511855083	14.77
# episode 55300: 	0.036735856292634136	19.97
# episode 55400: 	0.029166262454572343	17.79
# episode 55500: 	0.031307946285509265	19.48
# episode 55600: 	0.02628572293614818	16.84
# episode 55700: 	0.028270697684934093	18.54
# episode 55800: 	0.03385286751867651	18.58
# episode 55900: 	0.031133963742990368	16.92
# episode 56000: 	0.032858003749392066	18.91
# episode 56100: 	0.03863891769965895	21.2
# episode 56200: 	0.02677257597418457	17.48
# episode 56300: 	0.02804564817733264	17.9
# episode 56400: 	0.022574192957299836	17.3
# episode 56500: 	0.022554098106254465	14.63
# episode 56600: 	0.023758948283379672	16.43
# episode 56700: 	0.03652531832080021	19.56
# episode 56800: 	0.023581258718990795	16.23
# episode 56900: 	0.02398357969145529	17.52
# episode 57000: 	0.028191382322888515	14.89
# episode 57100: 	0.02967603317452697	17.65
# episode 57200: 	0.024387981935818107	14.56
# episode 57300: 	0.023400177863943373	14.97
# episode 57400: 	0.026099486326178766	16.47
# episode 57500: 	0.02734749175591695	18.51
# episode 57600: 	0.027279881120886168	17.14
# episode 57700: 	0.03196913681257222	18.47
# episode 57800: 	0.02470954091369436	16.52
# episode 57900: 	0.027073238199284432	19.48
# episode 58000: 	0.035735751495714944	21.1
# episode 58100: 	0.02910272698576793	17.04
# episode 58200: 	0.02980403612843258	15.27
# episode 58300: 	0.028648154764218364	17.01
# episode 58400: 	0.027550958453966778	19.95
# episode 58500: 	0.029055658925034658	18.73
# episode 58600: 	0.025165143211645525	16.05
# episode 58700: 	0.023484544013042133	17.94
# episode 58800: 	0.02611844895864094	14.47
# episode 58900: 	0.02883197458522835	16.77
# episode 59000: 	0.0278271322748573	17.45
# episode 59100: 	0.028294313232749856	15.58
# episode 59200: 	0.02078693903874018	15.37
# episode 59300: 	0.029604757151314113	16.74
# episode 59400: 	0.026430449239496466	18.26
# episode 59500: 	0.028644952549733448	17.72
# episode 59600: 	0.03102631511652627	16.13
# episode 59700: 	0.021638512395736463	16.74
# episode 59800: 	0.032249935835207945	18.54
# episode 59900: 	0.024951019846948787	17.5
# episode 60000: 	0.031511160925631845	18.38
# #Average reward per episode 60000: 0.02722889476117522
# episode 60100: 	0.027526923427896293	16.5
# episode 60200: 	0.022053804911200247	14.89
# episode 60300: 	0.023994627530859475	16.45
# episode 60400: 	0.024436750298500554	17.29
# episode 60500: 	0.02308431774434651	16.11
# episode 60600: 	0.025189131980225845	17.17
# episode 60700: 	0.027962821649593506	18.47
# episode 60800: 	0.02175374022856022	16.58
# episode 60900: 	0.03410427543296047	20.39
# episode 61000: 	0.0245313364865043	13.75
# episode 61100: 	0.02794045014269304	16.26
# episode 61200: 	0.021577528901185736	15.06
# episode 61300: 	0.028217547542629208	16.08
# episode 61400: 	0.0300796563956459	18.43
# episode 61500: 	0.023345151821991404	13.37
# episode 61600: 	0.020174705920605683	13.11
# episode 61700: 	0.02680383720413654	17.2
# episode 61800: 	0.023902609530612916	16.19
# episode 61900: 	0.02642780503033176	17.79
# episode 62000: 	0.027543411123684067	16.29
# episode 62100: 	0.03399251442707916	20.84
# episode 62200: 	0.023528009017885942	15.28
# episode 62300: 	0.031663350920497296	18.08
# episode 62400: 	0.02884060729023381	18.3
# episode 62500: 	0.023806197573943633	18.09
# episode 62600: 	0.02673794570808216	19.03
# episode 62700: 	0.021560425813007704	13.81
# episode 62800: 	0.026154270784732515	18.47
# episode 62900: 	0.024714881307459996	16.33
# episode 63000: 	0.027062371234176652	17.07
# episode 63100: 	0.027716677176864463	16.28
# episode 63200: 	0.02932210006392036	17.29
# episode 63300: 	0.026756649744724186	14.95
# episode 63400: 	0.025305303657700017	17.4
# episode 63500: 	0.021997903423861362	16.6
# episode 63600: 	0.02341572237425333	18.51
# episode 63700: 	0.021483624981257443	15.53
# episode 63800: 	0.031135956262589044	19.94
# episode 63900: 	0.02784204792035736	15.58
# episode 64000: 	0.02608878865944059	14.98
# episode 64100: 	0.024131673916048493	15.77
# episode 64200: 	0.026538190817059007	17.8
# episode 64300: 	0.023625799476560908	16.54
# episode 64400: 	0.026811295664107716	17.98
# episode 64500: 	0.025247297469967105	14.65
# episode 64600: 	0.023605496352361973	14.69
# episode 64700: 	0.0314809719168429	17.35
# episode 64800: 	0.027757206697963725	17.52
# episode 64900: 	0.027413262536533745	18.29
# episode 65000: 	0.021331375619642937	16.08
# #Average reward per episode 65000: 0.02713085416741299
# episode 65100: 	0.02548430791815167	15.62
# episode 65200: 	0.02429253991627543	16.33
# episode 65300: 	0.029201875893707863	18.67
# episode 65400: 	0.023769311932994683	15.69
# episode 65500: 	0.027392047022301722	15.99
# episode 65600: 	0.029347038836732807	19.49
# episode 65700: 	0.0253137974470817	16.82
# episode 65800: 	0.02548137940194653	13.91
# episode 65900: 	0.026300032800159242	17.6
# episode 66000: 	0.03239507758214885	19.81
# episode 66100: 	0.02398104477219928	17.51
# episode 66200: 	0.025188460144337236	17.04
# episode 66300: 	0.030748441580050453	17.02
# episode 66400: 	0.031099229382829784	18.11
# episode 66500: 	0.028480202881723714	16.76
# episode 66600: 	0.023567355369136803	18.18
# episode 66700: 	0.02948155666370993	17.94
# episode 66800: 	0.02690518426475514	16.81
# episode 66900: 	0.023336533874733133	14.46
# episode 67000: 	0.03219130476083774	17.88
# episode 67100: 	0.032005980513765936	20.41
# episode 67200: 	0.025765812949709154	14.08
# episode 67300: 	0.029997472877039313	17.7
# episode 67400: 	0.02951192123455292	17.58
# episode 67500: 	0.024258005521096134	19.15
# episode 67600: 	0.027972983080546517	18.89
# episode 67700: 	0.027476135178938474	15.7
# episode 67800: 	0.028206382421347473	16.68
# episode 67900: 	0.027547796435002443	19.58
# episode 68000: 	0.031747123928367725	21.17
# episode 68100: 	0.02968177075220331	17.31
# episode 68200: 	0.02293886037059547	15.63
# episode 68300: 	0.02905980176717617	16.24
# episode 68400: 	0.02942382404491999	15.28
# episode 68500: 	0.028085823365950335	16.75
# episode 68600: 	0.023507243160039736	16.42
# episode 68700: 	0.031006441596104203	18.21
# episode 68800: 	0.0262195428853728	16.13
# episode 68900: 	0.03382515053899895	19.76
# episode 69000: 	0.021260791253744957	15.75
# episode 69100: 	0.027593403703443795	16.64
# episode 69200: 	0.030163118123885228	20.24
# episode 69300: 	0.02578708861456393	16.43
# episode 69400: 	0.030155436206952508	18.36
# episode 69500: 	0.023874982700968925	19.84
# episode 69600: 	0.021997485472653143	18.71
# episode 69700: 	0.031138278222416375	16.73
# episode 69800: 	0.02878720885791881	15.7
# episode 69900: 	0.024141522639788828	16.88
# episode 70000: 	0.03515817241349952	18.83
# #Average reward per episode 70000: 0.027167582131565515
# episode 70100: 	0.017916288190085842	13.24
# episode 70200: 	0.029019323963463538	15.63
# episode 70300: 	0.03446650343634702	21.37
# episode 70400: 	0.029320577953808574	17.7
# episode 70500: 	0.03299125990072563	20.82
# episode 70600: 	0.02735293261018387	18.62
# episode 70700: 	0.03549598109580101	19.37
# episode 70800: 	0.026579330945375883	16.58
# episode 70900: 	0.031126660780360523	16.23
# episode 71000: 	0.0259779989504921	18.6
# episode 71100: 	0.029899808813449134	19.18
# episode 71200: 	0.029888945090255428	17.91
# episode 71300: 	0.02408349400750658	15.1
# episode 71400: 	0.027761181274537014	18.2
# episode 71500: 	0.03085769579204296	18.17
# episode 71600: 	0.026644682425205166	16.28
# episode 71700: 	0.030484634636094333	19.23
# episode 71800: 	0.025394653907001172	16.69
# episode 71900: 	0.029554367986631674	17.35
# episode 72000: 	0.023735946018942692	15.21
# episode 72100: 	0.0320682386451025	19.28
# episode 72200: 	0.03029387954117617	18.64
# episode 72300: 	0.02512506492976112	16.38
# episode 72400: 	0.032556773906492746	20.53
# episode 72500: 	0.029708338604549366	16.6
# episode 72600: 	0.030033660350892295	19.36
# episode 72700: 	0.027682890651475618	20.79
# episode 72800: 	0.021624045041369295	17.11
# episode 72900: 	0.025196605890967522	16.89
# episode 73000: 	0.0277523027335538	17.47
# episode 73100: 	0.02423904623113787	15.71
# episode 73200: 	0.022690164128619947	16.43
# episode 73300: 	0.02822058785080797	16.9
# episode 73400: 	0.02647321850225169	17.67
# episode 73500: 	0.028444035878848594	16.93
# episode 73600: 	0.0287623832451942	15.76
# episode 73700: 	0.02707650653344317	17.61
# episode 73800: 	0.02865038312489764	17.5
# episode 73900: 	0.026388056561031253	16.91
# episode 74000: 	0.029673143685039746	17.69
# episode 74100: 	0.02265448240640979	15.93
# episode 74200: 	0.02373979544139631	16.93
# episode 74300: 	0.02995582061819443	18.01
# episode 74400: 	0.026585976704751112	17.83
# episode 74500: 	0.02463657370468621	14.87
# episode 74600: 	0.027914316092427848	19.47
# episode 74700: 	0.02717107529835274	14.74
# episode 74800: 	0.025261515774954724	18.24
# episode 74900: 	0.03682319331337354	17.57
# episode 75000: 	0.02569739198777077	17.4
# #Average reward per episode 75000: 0.027211945636337432
# episode 75100: 	0.033391929264044856	19.67
# episode 75200: 	0.027854191674920287	17.57
# episode 75300: 	0.02978759547062819	17.09
# episode 75400: 	0.022419126031809174	17.57
# episode 75500: 	0.030865304572350122	19.44
# episode 75600: 	0.019030548090158136	14.85
# episode 75700: 	0.025399909614365616	16.65
# episode 75800: 	0.030202624203453068	17.49
# episode 75900: 	0.031745038267759346	18.71
# episode 76000: 	0.03478595559589125	18.37
# episode 76100: 	0.028235933416234763	18.48
# episode 76200: 	0.028396959730656087	18.35
# episode 76300: 	0.026381292410156743	15.53
# episode 76400: 	0.03286429864389057	19.19
# episode 76500: 	0.030240976807502692	16.07
# episode 76600: 	0.024176535514293874	15.77
# episode 76700: 	0.0294770629645334	13.66
# episode 76800: 	0.023069362391899252	16.45
# episode 76900: 	0.029278106868737348	15.84
# episode 77000: 	0.025150880489704625	16.41
# episode 77100: 	0.026429422262645504	19.4
# episode 77200: 	0.025241162077030345	16.76
# episode 77300: 	0.02570496453713814	17.47
# episode 77400: 	0.030028546916336968	18.02
# episode 77500: 	0.028210265514814807	17.84
# episode 77600: 	0.02631297048223716	16.77
# episode 77700: 	0.029450400795348042	16.67
# episode 77800: 	0.02195743219072677	14.86
# episode 77900: 	0.03095422696822922	16.87
# episode 78000: 	0.030792606286589072	20.37
# episode 78100: 	0.028617793676047987	18.25
# episode 78200: 	0.02277144615714488	14.52
# episode 78300: 	0.022056363374179506	14.99
# episode 78400: 	0.02478714909984114	15.8
# episode 78500: 	0.023527688708988217	14.4
# episode 78600: 	0.028003121130842797	18.3
# episode 78700: 	0.02922760399672144	19.53
# episode 78800: 	0.033643061665227035	19.76
# episode 78900: 	0.023841752420812882	17.42
# episode 79000: 	0.01852087744132053	13.22
# episode 79100: 	0.027719301834456322	16.11
# episode 79200: 	0.026907976621553607	15.73
# episode 79300: 	0.0233085867963784	15.39
# episode 79400: 	0.02572046545131395	17.24
# episode 79500: 	0.03159592025815387	19.35
# episode 79600: 	0.023669571823326567	13.47
# episode 79700: 	0.017770801764759064	15.26
# episode 79800: 	0.028882709062347044	17.24
# episode 79900: 	0.02945583773345925	18.36
# episode 80000: 	0.027040970137821488	15.41
# #Average reward per episode 80000: 0.02720482982057743
# episode 80100: 	0.026974949849998372	16.75
# episode 80200: 	0.03504780466429266	19.71
# episode 80300: 	0.02905496881526421	19.18
# episode 80400: 	0.021197898951812285	15.93
# episode 80500: 	0.028485905129016	18.56
# episode 80600: 	0.030978915811727306	21.15
# episode 80700: 	0.025471212851498126	15.75
# episode 80800: 	0.024346344781949792	16.4
# episode 80900: 	0.03290453268715782	18.03
# episode 81000: 	0.02381949387237143	15.76
# episode 81100: 	0.027573969804328954	20.36
# episode 81200: 	0.023281484743756565	16.7
# episode 81300: 	0.026171411135381267	16.73
# episode 81400: 	0.030031425445565873	17.06
# episode 81500: 	0.025666448774870877	18.16
# episode 81600: 	0.02799128186237807	17.44
# episode 81700: 	0.03036011669027334	18.18
# episode 81800: 	0.03138992994152406	19.87
# episode 81900: 	0.024289503917166534	15.54
# episode 82000: 	0.0276693690568204	18.85
# episode 82100: 	0.03197879488267132	17.29
# episode 82200: 	0.027292252015265955	18.98
# episode 82300: 	0.02167829351018846	16.09
# episode 82400: 	0.02574012934754172	15.27
# episode 82500: 	0.02920886620059429	16.75
# episode 82600: 	0.023997196726044792	15.23
# episode 82700: 	0.028531062306611624	18.31
# episode 82800: 	0.02447287963955911	17.73
# episode 82900: 	0.031184275364666253	17.54
# episode 83000: 	0.017997972337878906	16.33
# episode 83100: 	0.03092524154942038	16.75
# episode 83200: 	0.02668697357323578	18.26
# episode 83300: 	0.03027886459825925	19.85
# episode 83400: 	0.026268768000859925	16.12
# episode 83500: 	0.030132451179005853	20.99
# episode 83600: 	0.026361355116851892	16.63
# episode 83700: 	0.027394311023480288	19.39
# ...
# episode 103800: 	0.02311217927905396	15.4
# episode 103900: 	0.03538015588766543	20.35
# episode 104000: 	0.027949738991482707	17.51
# episode 104100: 	0.030010763542584373	18.82
# episode 104200: 	0.028694050629176668	17.59
# episode 104300: 	0.02716507269077801	17.18
# episode 104400: 	0.024357367924328476	16.04
# episode 104500: 	0.029459403899149424	16.64
# episode 104600: 	0.0249845755250394	17.36
# episode 104700: 	0.020721064975324666	13.49
# episode 104800: 	0.033323262004994636	20.97
# episode 104900: 	0.02571659544440653	17.76
# episode 105000: 	0.03002131387635686	19.09
# #Average reward per episode 105000: 0.027253002845398767
# episode 105100: 	0.023024156716296634	15.25
# episode 105200: 	0.028031518264694476	16.54
# episode 105300: 	0.03365159608832932	18.6
# episode 105400: 	0.03671829134089239	20.89
# episode 105500: 	0.03135505069652496	19.19
# episode 105600: 	0.027600951092702684	18.43
# episode 105700: 	0.03217728090963368	18.53
# episode 105800: 	0.02968630765273404	16.2
# episode 105900: 	0.023098688411256153	16.06
# episode 106000: 	0.025230467421614527	16.53
# episode 106100: 	0.025088940341696623	15.32
# episode 106200: 	0.025149340505051573	14.23
# episode 106300: 	0.02450453328855942	19.69
# episode 106400: 	0.026352046775247405	18.92
# episode 106500: 	0.02668037486007728	18.35
# episode 106600: 	0.027082620454433198	17.94
# episode 106700: 	0.031969773530294225	19.45
# episode 106800: 	0.029077178156726134	18.23
# episode 106900: 	0.022944608308298302	14.35
# episode 107000: 	0.031882851152830634	19.28
# episode 107100: 	0.028972620424026548	19.77
# episode 107200: 	0.027129950635683953	18.25
# episode 107300: 	0.028606328657655243	18.12
# episode 107400: 	0.028669962155444918	18.82
# episode 107500: 	0.025317610961495193	17.06
# episode 107600: 	0.025697205409785005	17.58
# episode 107700: 	0.0324949584072013	17.62
# episode 107800: 	0.03242452949245958	17.31
# episode 107900: 	0.019959029284725288	13.01
# episode 108000: 	0.029669451299323794	19.33
# episode 108100: 	0.023636253827978838	15.11
# episode 108200: 	0.027101494945945884	14.76
# episode 108300: 	0.02602332553825935	15.39
# episode 108400: 	0.025061736970874347	18.45
# episode 108500: 	0.02516442633132836	17.34
# episode 108600: 	0.02965753031676589	16.55
# episode 108700: 	0.031229393431523454	18.11
# episode 108800: 	0.032038002927013406	18.4
# episode 108900: 	0.030038454803960276	18.2
# episode 109000: 	0.02560609687094486	14.53
# episode 109100: 	0.02197101671499581	14.61
# episode 109200: 	0.027513959304223352	14.29
# episode 109300: 	0.023362013928797106	16.47
# episode 109400: 	0.029565756950728956	16.41
# episode 109500: 	0.028605090547167037	18.77
# episode 109600: 	0.026918663781978443	16.97
# episode 109700: 	0.02784570158986824	15.63
# episode 109800: 	0.028654125537804394	14.63
# episode 109900: 	0.027216525671239458	16.48
# episode 110000: 	0.027128457160688235	16.16
# #Average reward per episode 110000: 0.02727294476137857
# episode 110100: 	0.026763240503167966	15.97
# episode 110200: 	0.021867484084480502	16.08
# episode 110300: 	0.028010343318353514	18.86
# episode 110400: 	0.02864597236021906	16.62
# episode 110500: 	0.029718311892537402	20.78
# episode 110600: 	0.01947157228189183	14.63
# episode 110700: 	0.026608176281719454	16.35
# episode 110800: 	0.029283445045424506	15.86
# episode 110900: 	0.023910320152325477	15.9
# episode 111000: 	0.027911281225314326	17.04
# episode 111100: 	0.026474922824426733	13.78
# episode 111200: 	0.030416332552330578	18.32
# episode 111300: 	0.023612299790290763	16.64
# episode 111400: 	0.027797561636619554	17.4
# episode 111500: 	0.02871537471762068	18.49
# episode 111600: 	0.02065240248880954	13.82
# episode 111700: 	0.03660659052095767	19.37
# episode 111800: 	0.021715252355247298	15.04
# episode 111900: 	0.027633279226815265	18.02
# episode 112000: 	0.024440315764611628	15.73
# episode 112100: 	0.02473654698760529	15.03
# episode 112200: 	0.026700633498921978	19.12
# episode 112300: 	0.03225351305610224	17.83
# episode 112400: 	0.030800762488829726	17.73
# episode 112500: 	0.02802970611410955	18.09
# episode 112600: 	0.029805550375365572	18.61
# episode 112700: 	0.026658695961588753	15.7
# episode 112800: 	0.02707986138511214	15.79
# episode 112900: 	0.022428350992993566	14.75
# episode 113000: 	0.025532120897780328	15.22
# episode 113100: 	0.02894593498888103	19.66
# episode 113200: 	0.03323324062088213	19.32
# episode 113300: 	0.03214657510599934	20.06
# episode 113400: 	0.01773794535031865	14.02
# episode 113500: 	0.03463307955304737	18.73
# episode 113600: 	0.025738102467229497	19.04
# episode 113700: 	0.028517425009906464	17.39
# episode 113800: 	0.02835286884536126	18.24
# episode 113900: 	0.027191125353599882	17.73
# episode 114000: 	0.026622611065781107	16.51
# episode 114100: 	0.03128668871164503	16.59
# episode 114200: 	0.025737077826803095	18.81
# episode 114300: 	0.027025097957717726	16.64
# episode 114400: 	0.02280479213587997	15.23
# episode 114500: 	0.028072036831032304	16.72
# episode 114600: 	0.0226186824166432	17.45
# episode 114700: 	0.028524383900058653	19.12
# episode 114800: 	0.029057379669302674	19.3
# episode 114900: 	0.032551799417514383	19.13
# episode 115000: 	0.02467665121892721	15.21
# #Average reward per episode 115000: 0.027269559092821305
# episode 115100: 	0.0292136325038419	17.02
# episode 115200: 	0.023921203011709316	17.79
# episode 115300: 	0.0359401578222226	20.97
# episode 115400: 	0.027332681918558078	17.56
# episode 115500: 	0.023794062790618825	19.2
# episode 115600: 	0.029296730153812893	18.7
# episode 115700: 	0.02697731434651653	16.66
# episode 115800: 	0.026962907025404655	19.18
# episode 115900: 	0.026554292745119876	16.95
# episode 116000: 	0.024192960806071192	13.42
# episode 116100: 	0.029509000126956564	18.62
# episode 116200: 	0.021285427159298712	14.42
# episode 116300: 	0.02665172238730865	16.49
# episode 116400: 	0.024999416811084176	15.62
# episode 116500: 	0.017838181974602046	13.16
# episode 116600: 	0.022714874043351593	15.41
# episode 116700: 	0.030290900048099267	15.23
# episode 116800: 	0.03173173013127865	18.55
# episode 116900: 	0.023370304781186676	16.19
# episode 117000: 	0.02010296042342021	14.26
# episode 117100: 	0.034767042185722165	19.5
# episode 117200: 	0.029418583481750776	18.44
# episode 117300: 	0.025698923608979053	13.89
# episode 117400: 	0.0235884041512912	16.42
# episode 117500: 	0.02487852917868282	16.99
# episode 117600: 	0.019313107058101013	13.28
# episode 117700: 	0.026403646030342624	17.37
# episode 117800: 	0.027575671540008072	17.44
# episode 117900: 	0.02657948935874556	17.71
# episode 118000: 	0.025262179284902084	15.79
# episode 118100: 	0.025858442741610276	15.65
# episode 118200: 	0.022790334860022344	16.35
# episode 118300: 	0.03423997205273111	17.91
# episode 118400: 	0.032877593260607706	18.43
# episode 118500: 	0.03087941901165199	19.55
# episode 118600: 	0.020284558560008454	14.04
# episode 118700: 	0.027700549723941013	15.53
# episode 118800: 	0.03097986053849474	19.37
# episode 118900: 	0.032485090372514805	16.09
# episode 119000: 	0.02260230559516971	15.56
# episode 119100: 	0.02175684987154336	16.2
# episode 119200: 	0.02795653805351947	17.04
# episode 119300: 	0.02605681544092428	16.2
# episode 119400: 	0.024349900533131016	18.67
# episode 119500: 	0.02881486686308098	16.98
# episode 119600: 	0.032932557585954536	18.87
# episode 119700: 	0.03711803190744956	16.44
# episode 119800: 	0.031106389523014064	19.02
# episode 119900: 	0.031236594751070577	18.14
# episode 120000: 	0.024263717746538335	16.12
# #Average reward per episode 120000: 0.02726037448552198
# episode 120100: 	0.026950850617373106	17.41
# episode 120200: 	0.03515922142248469	18.57
# episode 120300: 	0.025777377452104955	15.8
# episode 120400: 	0.028162425520372406	16.48
# episode 120500: 	0.024571169028052585	15.49
# episode 120600: 	0.03572132300157467	18.5
# episode 120700: 	0.019140955678937345	12.71
# episode 120800: 	0.028173576247718365	16.47
# episode 120900: 	0.0241241972302855	16.16
# episode 121000: 	0.026090049396544836	19.67
# episode 121100: 	0.02340655476288579	17.16
# episode 121200: 	0.03142172076304241	19.6
# episode 121300: 	0.02386055179768681	16.65
# episode 121400: 	0.02531996630873525	19.68
# episode 121500: 	0.023541266495822985	16.43
# episode 121600: 	0.022067435860830265	15.63
# episode 121700: 	0.024666850065760287	17.17
# episode 121800: 	0.02578965730647052	17.94
# episode 121900: 	0.024970557790019447	15.75
# episode 122000: 	0.023226197481943222	15.75
# episode 122100: 	0.025657525347892098	17.48
# episode 122200: 	0.025949476919466807	15.56
# episode 122300: 	0.025648477088312797	14.45
# episode 122400: 	0.026070895794075077	17.07
# episode 122500: 	0.021559025133463437	17.13
# episode 122600: 	0.028988538648881193	16.74
# episode 122700: 	0.02348196866259611	12.3
# episode 122800: 	0.029197233621483524	16.63
# episode 122900: 	0.031482479406135716	17.31
# episode 123000: 	0.03201081227466444	17.22
# episode 123100: 	0.03214765152101567	17.3
# episode 123200: 	0.030152721773244618	20.98
# episode 123300: 	0.01799677305926089	14.27
# episode 123400: 	0.02347686005042369	15.73
# episode 123500: 	0.02278481650574722	14.47
# episode 123600: 	0.02602384014300717	19.06
# episode 123700: 	0.03041124537824351	17.03
# episode 123800: 	0.028475307410077703	15.26
# episode 123900: 	0.03136011235507492	17.23
# episode 124000: 	0.025393137441469527	18.57
# episode 124100: 	0.022614897581708135	15.8
# episode 124200: 	0.03303009980998151	20.32
# episode 124300: 	0.025910579349984638	14.33
# episode 124400: 	0.027404422563966153	17.91
# episode 124500: 	0.023599125908558508	15.56
# episode 124600: 	0.023105172458786415	17.07
# episode 124700: 	0.02627395627031898	17.23
# episode 124800: 	0.026094756481279013	17.11
# episode 124900: 	0.024808108587662126	15.01
# episode 125000: 	0.026010675314243628	17.56
# #Average reward per episode 125000: 0.027225369583772783
# episode 125100: 	0.026372978377608738	16.92
# episode 125200: 	0.030239772833911913	18.23
# episode 125300: 	0.0234220774255253	15.57
# episode 125400: 	0.02477669700303986	15.92
# episode 125500: 	0.030392186910230812	16.91
# episode 125600: 	0.024231213212843307	16.58
# episode 125700: 	0.032081142901742014	18.89
# episode 125800: 	0.027268854047249488	17.13
# episode 125900: 	0.028765186785881084	18.38
# episode 126000: 	0.03288657630771304	19.01
# episode 126100: 	0.029086166999328616	18.7
# episode 126200: 	0.02866058733571724	18.96
# episode 126300: 	0.03143309939821954	17.94
# episode 126400: 	0.023711038794735954	14.72
# episode 126500: 	0.030868094791351493	17.11
# episode 126600: 	0.02535292941311643	16.64
# episode 126700: 	0.033151848262254556	19.89
# episode 126800: 	0.02616384285328288	17.52
# episode 126900: 	0.030655496359395466	15.53
# episode 127000: 	0.027263633971926673	16.66
# episode 127100: 	0.0360023329235336	21.03
# episode 127200: 	0.029617964013265583	18.89
# episode 127300: 	0.023465454261645324	17.07
# episode 127400: 	0.02797769637167453	17.94
# episode 127500: 	0.028071013825928703	17.31
# episode 127600: 	0.0373941584024635	23.34
# episode 127700: 	0.020910771298149812	18.07
# episode 127800: 	0.01898582759086033	13.69
# episode 127900: 	0.023549435980266292	15.11
# episode 128000: 	0.02349815715634327	14.29
# episode 128100: 	0.0248218321231527	16.47
# episode 128200: 	0.03498358741242478	20.25
# episode 128300: 	0.028711689107534976	17.24
# episode 128400: 	0.030789656074443998	18.13
# episode 128500: 	0.03184199841773877	18.03
# episode 128600: 	0.03049663764667725	18.42
# episode 128700: 	0.025251109559629722	17.41
# episode 128800: 	0.02340309745567011	13.64
# episode 128900: 	0.02115027788761426	15.01
# episode 129000: 	0.024358879849536993	16.2
# episode 129100: 	0.028570303574137656	16.87
# episode 129200: 	0.03236483409635025	19.42
# episode 129300: 	0.025924390149248352	16.0
# episode 129400: 	0.02645566401761736	18.85
# episode 129500: 	0.021094597284508278	18.63
# episode 129600: 	0.026039631353707172	16.46
# episode 129700: 	0.025248876593477167	19.84
# episode 129800: 	0.029093114072843995	17.23
# episode 129900: 	0.028096762337328468	17.12
# episode 130000: 	0.01738305208845027	14.35
# #Average reward per episode 130000: 0.027233883235867166
# episode 130100: 	0.022926553659490444	13.66
# episode 130200: 	0.021103595808126405	13.36
# episode 130300: 	0.025825785276632665	17.63
# episode 130400: 	0.02897653927113311	20.11
# episode 130500: 	0.029177578358096676	16.99
# episode 130600: 	0.033381427715682414	17.92
# episode 130700: 	0.03381878172028117	17.22
# episode 130800: 	0.02754898114195048	15.34
# episode 130900: 	0.023335027315409797	15.44
# episode 131000: 	0.022891184902887537	16.49
# episode 131100: 	0.02614387434906014	17.35
# episode 131200: 	0.024388301484082758	16.81
# episode 131300: 	0.02251565901065652	15.49
# episode 131400: 	0.03160800153070543	19.15
# episode 131500: 	0.027701335401515058	17.19
# episode 131600: 	0.02780663740471472	19.23
# episode 131700: 	0.02576900032018879	18.01
# episode 131800: 	0.030405815175147816	18.12
# episode 131900: 	0.022882839049421674	17.51
# episode 132000: 	0.029525215904504406	16.3
# episode 132100: 	0.025275073854119704	15.42
# episode 132200: 	0.03219444642864	19.58
# episode 132300: 	0.025203514949625618	13.71
# episode 132400: 	0.03320335184668341	18.95
# episode 132500: 	0.028653124966011558	18.8
# episode 132600: 	0.025836389798794643	18.58
# episode 132700: 	0.03412189083251127	19.32
# episode 132800: 	0.023166880271953016	14.83
# episode 132900: 	0.024049426173620225	13.99
# episode 133000: 	0.033183010864816585	18.98
# episode 133100: 	0.02573917137040449	17.5
# episode 133200: 	0.02234518850806342	16.47
# episode 133300: 	0.02825751205873909	18.18
# episode 133400: 	0.0206900999397299	15.67
# episode 133500: 	0.027484464026862998	17.39
# episode 133600: 	0.02843692669454543	18.15
# episode 133700: 	0.02635557163737066	16.58
# episode 133800: 	0.023031217333671562	16.19
# episode 133900: 	0.026170181225100016	18.31
# episode 134000: 	0.02585668390832564	15.99
# episode 134100: 	0.02499666090349724	15.53
# episode 134200: 	0.03704581698248554	20.21
# episode 134300: 	0.027996034126031064	17.03
# episode 134400: 	0.02849257063614936	17.46
# episode 134500: 	0.03214183431946601	17.03
# episode 134600: 	0.024524524878512807	16.76
# episode 134700: 	0.02982379428242946	15.69
# episode 134800: 	0.028324989542473387	17.24
# episode 134900: 	0.02841535803377209	15.46
# episode 135000: 	0.03429786968767032	16.88
# #Average reward per episode 135000: 0.027242291793710464
# episode 135100: 	0.030125172603187887	18.29
# episode 135200: 	0.028166979081825798	18.74
# episode 135300: 	0.028002741889199524	17.85
# episode 135400: 	0.028355699130566885	18.39
# episode 135500: 	0.024714744248925603	17.7
# episode 135600: 	0.027509648904890036	18.7
# #Total average reward per episode: 0.027244814828442293
# #Max possible average reward per episode: 0.050020918386702876
# #Confidence Interval with prob of 90%: 0.0001722837012742409
# #Confidence Interval with prob of 95%: 0.00020528869200756657
# #Sell time entropy: 1.6698848809795537
# #Percentage of stock returns (Normalized): 0.02958725989953881
# #Percentage of stock returns (Real values): 0.02958725989953881
# #Percentage of option returns (Normalized): 0.12068279974832564
# #Percentage of option returns (Real values): 0.1206827997483257
# #Max possible average stock percentage return per episode: 0.05026535393226427
# #Max possible average real stock percentage return per episode: 0.05026535393226427
# #Max possible average option percentage return per episode: 0.9052905274556888
# #Max possible average real option percentage return per episode: 0.9052905274556889
# #Confidence Interval of Percentage of returns (Normalized) with prob of 90%: 0.00016799750480531178
# #Confidence Interval of Percentage of returns (Normalized) with prob of 95%: 0.00020018137390210474
# #Confidence Interval of Percentage of returns (Real values) with prob of 90%: 0.00016799750480531178
# #Confidence Interval of Percentage of returns (Real values) with prob of 95%: 0.00020018137390210474
# #Confidence Interval of Percentage of option returns (Normalized) with prob of 90%: 0.006503349132739881
# #Confidence Interval of Percentage of option returns (Normalized) with prob of 95%: 0.007749218453366986
# #Confidence Interval of Percentage of option returns (Real values) with prob of 90%: 0.006503349132739881
# #Confidence Interval of Percentage of option returns (Real values) with prob of 95%: 0.007749218453366986
# #Time to execute: 422.6705299178759min

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, AvgrList, color='red', label='Episode reward')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward / Ep Length')
plt.legend(loc='best');

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, np.array(AvgrList)*20, color='red', label='Episode reward x20')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward x20 / Ep Length')
plt.legend(loc='best');

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(AvgEpisodeList, np.array(AvgrList)*100, color='red', label='Episode reward x100')
plt.plot(AvgEpisodeList, AvgsTimeList, color='blue', label='Episode Length')
plt.title('Average metrics over time')
plt.xlabel('episodes')
plt.ylabel('Reward x100 / Ep Length')
plt.legend(loc='best');

# %%
# show evolution of metrics over time
plt.figure(figsize=(15, 10));
plt.plot(range(len(sTimeList)), sTimeList, color='blue', label='Sell time')
plt.title('Sell time over time')
plt.xlabel('episodes')
plt.ylabel('Sell time')
plt.legend(loc='best');

# %% [markdown]
# # Print size of remaining objects

# %%
import sys

# These are the usual ipython objects, including this one you are creating
ipython_vars = ['In', 'Out', 'exit', 'quit', 'get_ipython', 'ipython_vars']

# Get a sorted list of the objects and their sizes
list_objects = sorted([(x, sys.getsizeof(globals().get(x))) for x in dir() if not x.startswith('_') and x not in sys.modules and x not in ipython_vars], key=lambda x: x[1], reverse=True)
#print(list_objects)
for x,y in list_objects:
    print(str(x)+": "+str(y))
    del x
# Out:
# jList: 1174056
# maxPossibleOptionP_returnList: 1174056
# maxPossibleOptionR_P_returnList: 1174056
# maxPossibleP_returnList: 1174056
# maxPossibleR_P_returnList: 1174056
# maxPossiblerList: 1174056
# option_percentage_rList: 1174056
# option_real_percentage_rList: 1174056
# percentage_rList: 1174056
# rList: 1174056
# real_percentage_rList: 1174056
# sTimeList: 1174056
# AvgEpisodeList: 11528
# AvgrList: 11528
# AvgsTimeList: 11528
# stock_data: 7992
# real_train_data: 6040
# train_data: 6040
# Qnetwork: 2008
# real_stocks_test_data: 1680
# real_stocks_train_data: 1680
# stocks_data: 1680
# stocks_test_data: 1680
# stocks_train_data: 1680
# real_test_data: 1576
# test_data: 1576
# AmericanOptionPricing: 1064
# GBM: 1064
# MinMaxScaler: 1064
# experience_buffer: 1064
# episodeBuffer: 536
# final_trained_model_name: 343
# trained_model_name: 337
# s1P: 232
# sP: 232
# path: 169
# scriptDirectory: 158
# build_data: 144
# leaky_relu: 144
# length: 144
# normalize_data: 144
# prepare_company_stock: 144
# prepare_data: 144
# processState: 144
# set_seed: 144
# updateTarget: 144
# updateTargetGraph: 144
# s: 96
# s1: 96
# np: 88
# pd: 88
# plt: 88
# slim: 88
# tf: 88
# state: 80
# state1: 80
# gauss: 72
# env: 64
# init: 64
# mainQN: 64
# myBuffer: 64
# saver: 64
# sess: 64
# targetQN: 64
# mask_type: 56
# test: 56
# exploration_type: 55
# optimizer_type: 53
# paddingType: 53
# dueling_type: 52
# AvgR: 32
# AvgsT: 32
# best_reward: 32
# gamma: 32
# option_percentage_return: 32
# option_real_percentage_return: 32
# stock_percentage_return: 32
# stock_real_percentage_return: 32
# a: 28
# annealing_episodes: 28
# annealing_exploitation_episodes: 28
# apply_dropout: 28
# apply_grad_clipping: 28
# batch_size: 28
# build_warm_up_state_t: 28
# grad_clipping: 28
# h_size: 28
# history_t: 28
# huber_loss: 28
# i: 28
# input_size: 28
# j: 28
# load_model: 28
# max_epLength: 28
# memory_capacity: 28
# nbFilters: 28
# num_actions: 28
# num_atoms: 28
# num_batch_episodes_per_epoch: 28
# num_episodes: 28
# num_epochs: 28
# num_layers: 28
# num_seeds: 28
# option_T: 28
# pre_exploitation_episodes: 28
# pre_train_episodes: 28
# save_model_freq: 28
# seed: 28
# sell_time: 28
# startE: 28
# summaryAverageReward: 28
# summaryEpoch: 28
# summaryLength: 28
# trace_length: 28
# update_freq: 28
# update_online_freq: 28
# update_target_freq: 28
# Colab: 24
# Normalization: 24
# Window_Normalization: 24
# architecture: 24
# begin_time: 24
# d: 24
# delta_z: 24
# dropout: 24
# e: 24
# endE: 24
# end_time: 24
# exploitationE: 24
# is_training: 24
# keep_prob: 24
# learning_rate: 24
# mu: 24
# r: 24
# rAll: 24
# risk_free_rate: 24
# sigma: 24
# softUpdate: 24
# tau: 24
# test_data_ratio: 24
# vmax: 24
# vmin: 24
